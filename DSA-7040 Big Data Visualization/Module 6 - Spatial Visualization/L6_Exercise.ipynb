# %% [markdown]
# # Module 6 Exercise
#
# **In these exercises, you will create map visualizations using ggmap and ggplot2.**
#
#
# Let's start with a simple data set first; number of visitors to United Stated from 2006 to 2015.

# %%
# First, read the data and make sure the first column is character and the rest is numeric
vis <- read.csv("/dsa/data/all_datasets/spatial/US_visitors.csv",colClasses=c("character",rep("numeric",10)))

head(vis)
# Out:
#   Region        X2006    X2007    X2008    X2009    X2010    X2011    X2012
# 1 Africa          394163   426922   474160   452693   485110   508489   573184
# 2 Asia           8371244  8781480  8795236  7820986  9404375 10027386 11062760
# 3 Europe        12792122 13993051 15931641 14559083 14692093 15481558 15710015
# 4 North America  8491307  9963858  9832557  8963282 16449861 20940354 19996738
# 5 Oceania        1039872  1067258  1127444  1065909  1290993  1513963  1618337
# 6 South America  2432010  2763355  3039883  3075013  3587883  4126385  4651162
#   X2013    X2014    X2015
# 1   645919   757181   792026
# 2 12230911 13307053 14025173
# 3 16167460 17376449 17340542
# 4 24561055 35589531 36312759
# 5  1770569  1822066  1859507
# 6  5511558  6052610  6256760

# %% [markdown]
# **We will create a flow map to visualize number of visitors from different continents.**
#
# **For that, we'll need coordinates**. `ggmap` library has functions to look up for **geocodes** of locations; these locations can be addresses, city names, or even continent names.
#
#
# Let's lookup continents' coordinates information by using `mutate_geocode` function that will augment our data frame with the coordinates (longitude, latitude).

# %%
library(ggplot2)
library(ggmap)

apikey <- scan("/dsa/data/all_datasets/ggmap_api_key.txt", what="character")
register_google(key = apikey)

# get geo COORDINATES for the place names and put them in the Region attribute 
vis <- mutate_geocode(vis, Region)
head(vis)
# get the map 
world <- map_data("world")
# Out:
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Africa&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Asia&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Europe&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=North+America&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Oceania&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=South+America&key=xxx
#   Region        X2006    X2007    X2008    X2009    X2010    X2011    X2012
# 1 Africa          394163   426922   474160   452693   485110   508489   573184
# 2 Asia           8371244  8781480  8795236  7820986  9404375 10027386 11062760
# 3 Europe        12792122 13993051 15931641 14559083 14692093 15481558 15710015
# 4 North America  8491307  9963858  9832557  8963282 16449861 20940354 19996738
# 5 Oceania        1039872  1067258  1127444  1065909  1290993  1513963  1618337
# 6 South America  2432010  2763355  3039883  3075013  3587883  4126385  4651162
#   X2013    X2014    X2015    lon        lat
# 1   645919   757181   792026   34.50852  -8.783195
# 2 12230911 13307053 14025173  100.61966  34.047863
# 3 16167460 17376449 17340542   15.25512  54.525961
# 4 24561055 35589531 36312759 -105.25512  54.525961
# 5  1770569  1822066  1859507  140.01877 -22.735910
# 6  5511558  6052610  6256760  -55.49148  -8.783195

# %%
# get coordinates for US 
us <- geocode("United States")
us
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=United+States&key=xxx
#   lon       lat
# 1 -95.71289 37.09024

# %% [markdown]
# **Exercise 1:** **Create a flow map that shows the number of visitors from different continents to US in 2015**.
#
# Make sure **color channel encodes ```Region``` , and size channel encodes number of visitors in 2015** (```X2015``` attribute).

# %%
# Now first plot the world map 
ggplot() + 

geom_map(data = world, map = world, aes(map_id = region, group = group), fill="#e6ef86", color="black", size=0.1) +

# then plot the flow curves from continents to the same point in US. 

geom_curve(data = vis, aes(x = lon, y = lat, xend = us$lon, yend = us$lat, color = Region, size = X2015), 
           curvature = 0.1, arrow = arrow(length = unit(0.05, "npc"))) +

# add coords themes etc. 
coord_equal() +

xlim(c(-165,173)) + ylim(c(-77,77)) + 

theme_void() + 

theme(legend.position = "None")
# Out:
# plot without title

# %% [markdown]
# **Exercise 2:** All flow curves end at the **same** point in US and get superposed. Instead of using a single endpoint, **let's use multiple endpoints of arrows in US** to make it look better.
#
# **Go to [latlong.net](http://www.latlong.net/) and choose good endpoints for each continent**, and then **add** their coordinates to your data frame as `ENDLON` and `ENDLAT` attributes and **redraw**.
#
# ---
#
# Your plot should look similar to this:
#
# <img src="../images/ex2.png">
#
# ---

# %%
# Create a list of lon and lat with hardcoded coordinates in them.
# Make sure they are in the SAME order as the continents they correspond to.

ENDLON <- c(-80.193433, -71.013149, -92.204646, -111.979573, -84.428762, -95.277098)
ENDLAT <- c(25.773537, 42.362857, 46.841877, 40.789900, 33.638347, 29.646661)
vis2 <- cbind(vis, ENDLON, ENDLAT)
#head(vis2)

ggplot() + 
    geom_map(data = world, map = world, aes(map_id = region), fill="#e6ef86", color="black", size=0.1) +
    geom_curve(data = vis2, aes(x = lon, y = lat, xend = ENDLON, yend = ENDLAT, color = Region, size = X2015), 
                curvature = 0.1, arrow = arrow(length = unit(0.05, "npc"))) +
    coord_equal() +
    xlim(c(-165,173)) + ylim(c(-77,77)) + 
    theme_void() + 
    theme(legend.position = "None")
# Out:
# plot without title

# %% [markdown]
# ---
#
# **Now, we will work on the flight data from the L6_Projections_Practice. We will visualize flights. Let's get the data first.**

# %%
library(dplyr)
library(sp)
library(geosphere)

# airport codes and coordinates 
airports <- read.csv("/dsa/data/all_datasets/spatial/airports.csv", as.is=TRUE, header=TRUE)
# flight destinations and counts 
flights <- read.csv("/dsa/data/all_datasets/spatial/flights.csv", as.is=TRUE, header=TRUE)

airports$lat <- as.numeric(airports$lat)
airports$long <- as.numeric(airports$long)

# get airport locations
airport_locs <- airports[, c("iata","long", "lat")]

# Link airport lat long to origin and destination
OD <- left_join(flights, airport_locs, by=c("airport1"="iata"))
OD <- left_join(OD, airport_locs, by=c("airport2"="iata"))
head(OD)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
#   airline airport1 airport2 cnt long.x     lat.x    long.y    lat.y
# 1 AA      DFW      SJU      120  -97.03720 32.89595 -66.00183 18.43942
# 2 AA      MSP      DFW      326  -93.21692 44.88055 -97.03720 32.89595
# 3 AA      LGA      ORD      860  -73.87261 40.77724 -87.90446 41.97960
# 4 AA      TPA      JFK       56  -82.53325 27.97547 -73.77893 40.63975
# 5 AA      STT      BOS       44  -64.97336 18.33731 -71.00518 42.36435
# 6 AA      PHX      DFW      550 -112.00806 33.43417 -97.03720 32.89595

# %% [markdown]
# **Exercise 3:** **Add another attribute** to the `OD` data frame that shows the **distance between two airports** and **visualize only those routes that are longer than 1500 miles**.

# %%
# This is how we find the geodesic distance between two pairs of coordinates using geosphere library:

# Compute the geodesic distance between airports 
dd <- data.frame(Distance=distGeo(matrix(c(OD$long.x, OD$lat.x), ncol = 2), matrix(c(OD$long.y, OD$lat.y), ncol = 2)))

# convert meters to miles 
dd <- dd*0.000621371 

# Now ADD THIS to the OD data frame as another attribute and visualize only those routes that are longer than 1500 miles. 
#head(dd)


# <- YOUR CODE HERE ->
OD$distance <- dd$Distance
#head(OD)
ODlong <- subset(OD, distance > 1500)
#ODlong

ggplot() + 
geom_map(data = world, map = world, aes(map_id = region), fill = "#e6ef86", color = "black", size = 0.1) +
geom_curve(data = ODlong, aes(x = long.x, y = lat.x, xend = long.y, yend = lat.y, color = cnt), size = 0.1,
                 curvature = -0.2, arrow = arrow(length = unit(0.01, "npc"))) +
scale_colour_distiller(palette = "Blues", guide = "none") +
coord_equal() + 
xlim(c(-172,-57)) + ylim(c(12,72)) + 
theme_void()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_curve).”
# plot without title

# %% [markdown]
# **Exercise 4:** Let's read the Missouri County population data set and **create a choropleth map that shows the population in year 2000 county by county**.
#
#
# Make sure that **darker** shades represent **larger** populations.

# %%
moco <- read.csv("/dsa/data/all_datasets/spatial/MO_2009_County.csv")

head(moco)
# Out:
#   COUNTYNAME COUNTYFIPS COUNTYGNIS POP_1990 POP_2000 ACRES    SQ_MILES
# 1 Clark       45        758477      7547     7416    327632.4 511.9257
# 2 Atchison     5        758457      7457     6430    351990.5 549.9852
# 3 Scotland   199        758552      4822     4983    280949.0 438.9828
# 4 Schuyler   197        758551      4236     4170    197084.7 307.9449
# 5 Nodaway    147        758528     21709    21912    561734.1 877.7095
# 6 Putnam     171        758540      5079     5223    332103.3 518.9114
#   CNTY_SEAT
# 1 Kahoka
# 2 Rock Port
# 3 Memphis
# 4 Lancaster
# 5 Maryville
# 6 Unionville

# %% [markdown]
#  (**Hint:** Look at the Counties_Choropleth practice notebook to figure out how to modify the map data.)

# %%
# Get the Missouri counties map
mo_map <- map_data("county","missouri")
head(mo_map)


# make the county names lowercase in the data frame 
library(dplyr)
moco <- mutate(moco, county = tolower(COUNTYNAME))
head(moco)
# Out:
#   long      lat      group order region   subregion
# 1 -92.67592 40.35342 1     1     missouri adair
# 2 -92.33215 40.35342 1     2     missouri adair
# 3 -92.33215 40.35342 1     3     missouri adair
# 4 -92.33215 40.31331 1     4     missouri adair
# 5 -92.33215 40.04402 1     5     missouri adair
# 6 -92.84208 40.03829 1     6     missouri adair
#   COUNTYNAME COUNTYFIPS COUNTYGNIS POP_1990 POP_2000 ACRES    SQ_MILES
# 1 Clark       45        758477      7547     7416    327632.4 511.9257
# 2 Atchison     5        758457      7457     6430    351990.5 549.9852
# 3 Scotland   199        758552      4822     4983    280949.0 438.9828
# 4 Schuyler   197        758551      4236     4170    197084.7 307.9449
# 5 Nodaway    147        758528     21709    21912    561734.1 877.7095
# 6 Putnam     171        758540      5079     5223    332103.3 518.9114
#   CNTY_SEAT  county
# 1 Kahoka     clark
# 2 Rock Port  atchison
# 3 Memphis    scotland
# 4 Lancaster  schuyler
# 5 Maryville  nodaway
# 6 Unionville putnam

# %%
mapdata
# Out:
# Error in eval(expr, envir, enclos): object 'mapdata' not found
# Traceback:

# %%
#mmdf <- data.frame(county=as.character(unique(mo_map$subregion)), pop = seq(1,115),  stringsAsFactors = FALSE)
mo_map$region = mo_map$subregion
#colorCount = length(unique(moco$POP_2000))
#myPalette <- colorRampPalette(scale_color_hue(direction = -1, h.start = 90)(colorCount))

ggplot(data = moco, aes(fill = POP_2000)) +
geom_map(map = mo_map, aes(map_id = county), color="white", size=0.1) +
#scale_fill_gradientn(colours = c("#56B1F7", "#132B43"), values = scales::rescale(c(0, 10000, 50000, 600000, 1000000))) +
#scale_fill_continuous(name="Population", trans = "reverse") + 
scale_fill_continuous(name="Population", low = "#56B1F7", high = "#132B43", trans =  "log10") + 

# mapping stuff
expand_limits(x = mo_map$long, y = mo_map$lat) +
coord_map() + 
theme_void()
# Out:
# plot without title

# %% [markdown]
# **Exercise 5:** Let's read the Walmart store opening data, and **create a density map** out of it.
#
# Get a **Texas map from Google Maps**, then **create a density plot** and its **borders as layers** on the map. Finally **add store locations as another layer** encoded by **blue** dots.

# %%
df <- read.csv('https://raw.githubusercontent.com/plotly/datasets/master/1962_2006_walmart_store_openings.csv')
df
# Out:
#      storenum OPENDATE date_super conversion st county
# 1     1       7/1/62   3/1/97      1          5   7
# 2     2       8/1/64   3/1/96      1          5   9
# 3     4       8/1/65   3/1/02      1          5   7
# 4     8       10/1/67  3/1/93      1          5  29
# 5     7       10/1/67             NA          5 119
# 6    10       7/1/68   3/1/98      1         40  21
# 7    13       11/1/68  3/1/96      1         29  97
# 8    12       7/1/68   3/1/94      1         40 131
# 9    11       3/1/68   2/20/02     1          5   5
# 10    9       3/1/68   3/1/00      1         29 143
# 11   15       5/1/69   3/1/95      1         29  91
# 12   17       5/1/69   3/1/93      1         29 145
# 13   16       4/1/69   3/1/00      1          5  33
# 14   18       11/1/69             NA          5  67
# 15   14       4/1/69   3/1/99      1         29 105
# 16   20       10/1/70  3/1/99      1         29  83
# 17   22       10/1/70  5/18/05     1         40  97
# 18   21       3/1/70   8/22/01     1         29 169
# 19   23       11/1/70  3/1/94      1         22  61
# 20   26       11/1/70             NA         20 103
# 21   30       11/1/71  5/18/05     1         29 207
# 22   27       2/1/71   3/1/99      1         29  65
# 23   33       6/1/71   9/17/03     1          5  61
# 24   32       6/1/71              NA         29 213
# 25   29       8/1/71   3/1/89      1         29  51
# 26   31       6/1/71   3/1/95      1         40  79
# 27   24       4/1/71   3/1/99      1          5 119
# 28   25       2/1/71   5/18/05     1         29   7
# 29   34       11/1/71  5/21/03     1         29 217
# 30   35       10/1/71  3/17/04     1         20 161
# ⋮    ⋮        ⋮        ⋮          ⋮          ⋮  ⋮
# 2963 3380     1/23/06  1/23/06     0         53  21
# 2964 3403     1/27/06  1/27/06     0         13 223
# 2965 3729     1/23/06  1/23/06     0         32  31
# 2966 3734     1/27/06  1/27/06     0         46  27
# 2967 5436     1/31/06             NA         10   3
# 2968 3389     1/25/06  1/25/06     0         13 135
# 2969 3765     1/27/06  1/27/06     0         39 109
# 2970 5131     1/25/06             NA         42  17
# 2971 3838     1/31/06  1/31/06     0         42   3
# 2972 3386     1/25/06  1/25/06     0          1 115
# 2973 5497     1/31/06  1/31/06     0         36  45
# 2974 3726     1/27/06  1/27/06     0         26  49
# 2975 3660     1/31/06  1/31/06     0         47  65
# 2976 2695     1/27/06  1/27/06     0         12  69
# 2977 5487     1/23/06  1/23/06     0         45  45
# 2978 3305     1/31/06  1/31/06     0         37 157
# 2979 3523     1/27/06  1/27/06     0          6  37
# 2980 3630     1/23/06  1/23/06     0         19 113
# 2981 2852     1/31/06  1/31/06     0         54  51
# 2982 5370     1/31/06  1/31/06     0          8  13
# 2983 3608     1/31/06  1/31/06     0         39  85
# 2984 5253     1/31/06  1/31/06     0         51 550
# 2985 5471     1/31/06  1/31/06     0         39 139
# 2986 5346     1/23/06  1/23/06     0         37   1
# 2987 5313     1/23/06  1/23/06     0         29 183
# 2988 5403     1/27/06  1/27/06     0         17  19
# 2989 3347     1/23/06  1/23/06     0         12 105
# 2990 5485     1/27/06             NA         17  31
# 2991 3425     1/27/06  1/27/06     0         48 201
# 2992 5193     1/31/06             NA          6  65
#      STREETADDR                   STRCITY           STRSTATE ZIPCODE
# 1    2110 WEST WALNUT             Rogers            AR       72756
# 2    1417 HWY 62/65 N             Harrison          AR       72601
# 3    2901 HWY 412 EAST            Siloam Springs    AR       72761
# 4    1621 NORTH BUSINESS 9        Morrilton         AR       72110
# 5    3801 CAMP ROBINSON RD.       North Little Rock AR       72118
# 6    2020 SOUTH MUSKOGEE          Tahlequah         OK       74464
# 7    2705 GRAND AVE               Carthage          MO       64836
# 8    1500 LYNN RIGGS BLVD         Claremore         OK       74017
# 9    65 WAL-MART DRIVE            Mountain Home     AR       72653
# 10   1303 SOUTH MAIN              Sikeston          MO       63801
# 11   1310 PREACHER RD/HGWY 160    West Plains       MO       65775
# 12   3200 LUSK DRIVE              Neosho            MO       64850
# 13   2214 FAYETTEVILLE RD         Van Buren         AR       72956
# 14   2500 MALCOLM ST/HWY 67 NORTH Newport           AR       72112
# 15   1800 S JEFFERSON             Lebanon           MO       65536
# 16   1712 EAST OHIO               Clinton           MO       64735
# 17   4901 SO. MILL ROAD           Pryor             OK       74361
# 18   185 ST ROBERT BLVD           St. Robert        MO       65584
# 19   1201 N SERVICE ROAD EAST     Ruston            LA       71270
# 20   3450 S. 4TH TRAFFICWAY       Leavenworth       KS       66048
# 21   2025 BUS. HWY 60 WEST        Dexter            MO       63841
# 22   1101 HWY 32 WEST             Salem             MO       65560
# 23   1710 SO. 4TH ST              Nashville         AR       71852
# 24   2050 WEST HWY 76             Branson           MO       65616
# 25   724 STADIUM WEST BLVD        Jefferson City    MO       65109
# 26   3108 N BROADWAY              Poteau            OK       74953
# 27   2000 JOHN HARDEN DR          Jacksonville      AR       72076
# 28   4820 SO. CLARK ST            Mexico            MO       65265
# 29   2250 LINCOLN AVENUE          Nevada            MO       64772
# 30   101 EAST BLUEMONT AVENUE     Manhattan         KS       66502
# ⋮    ⋮                            ⋮                 ⋮        ⋮
# 2963 4820 North Road 68           Pasco             WA       99301
# 2964 3615 Marietta Hwy            Dallas            GA       30157
# 2965 5065 Pyramid Lake Rd         Sparks            NV       89436
# 2966 1207 Princeton St            Vermillion        SD       57069
# 2967 1251 Centerville Rd          Wilmington        DE       19808
# 2968 3435 Centerville Hwy         Snellville        GA       30039
# 2969 1300 E Ash St                Piqua             OH       45356
# 2970 3461 Horizon Blvd            Bensalem          PA       19020
# 2971 2010 Village Center Dr       Tarentum          PA       15084
# 2972 160 Springville Station Blvd Springville       AL       35146
# 2973 25737 US Rte 11              Evans Mills       NY       13637
# 2974 6170 S Saginaw Rd            Grand Blanc       MI       48439
# 2975 3428 Cummings Hwy            Chattanooga       TN       37419
# 2976 1450 Johns Lake Rd           Clermont          FL       34711
# 2977 9 Benton Rd                  Travelers Rest    SC       29690
# 2978 6711 St Hwy 135              Mayodan           NC       27027
# 2979 26471 Carl Boyer Dr          Santa Clarita     CA       91350
# 2980 5491 Bus Hwy 51              Marion            IA       52302
# 2981 240 N Lafayette Ave          Moundsville       WV       26041
# 2982 2514 Main St                 Longmont          CO       80504
# 2983 6067 N Ridge Rd              Madison           OH       44057
# 2984 632 Grass Field Pkwy         Chesapeake        VA       23322
# 2985 2485 Possum Run Rd           Mansfield         OH       44903
# 2986 1318 Mebane Oaks Rd          Mebane            NC       27302
# 2987 6100 Ronald Reagan Blvd      Lake Saint Louis  MO       63367
# 2988 100 S High Cross Rd          Urbana            IL       61802
# 2989 7450 Cypress Gardens Blvd    Winter Haven      FL       33884
# 2990 2500 W 95th St               Evergreen Park    IL       60805
# 2991 9598 Rowlett Rd              Houston           TX       77034
# 2992 12721 Moreno Beach Dr        Moreno Valley     CA       92555
#      type_store  LAT      LON        MONTH DAY YEAR
# 1    Supercenter 36.34224 -94.07141   7    1   1962
# 2    Supercenter 36.23698 -93.09345   8    1   1964
# 3    Supercenter 36.17990 -94.50208   8    1   1965
# 4    Supercenter 35.15649 -92.75858  10    1   1967
# 5    Wal-Mart    34.81327 -92.30229  10    1   1967
# 6    Supercenter 35.92366 -94.97185   7    1   1968
# 7    Supercenter 37.16898 -94.31164  11    1   1968
# 8    Supercenter 36.32714 -95.61192   7    1   1968
# 9    Supercenter 36.32903 -92.35781   3    1   1968
# 10   Supercenter 36.89116 -89.58355   3    1   1968
# 11   Supercenter 36.71914 -91.87408   5    1   1969
# 12   Supercenter 36.86429 -94.39016   5    1   1969
# 13   Supercenter 35.45654 -94.34581   4    1   1969
# 14   Wal-Mart    35.58606 -91.24695  11    1   1969
# 15   Supercenter 37.67853 -92.64733   4    1   1969
# 16   Supercenter 38.36421 -93.76042  10    1   1970
# 17   Supercenter 36.29417 -95.30295  10    1   1970
# 18   Supercenter 37.82742 -92.13574   3    1   1970
# 19   Supercenter 32.52476 -92.64696  11    1   1970
# 20   Wal-Mart    39.29878 -94.93555  11    1   1970
# 21   Supercenter 36.78445 -89.97428  11    1   1971
# 22   Supercenter 37.63090 -91.51423   2    1   1971
# 23   Supercenter 33.98561 -93.85214   6    1   1971
# 24   Wal-Mart    36.64417 -93.25668   6    1   1971
# 25   Supercenter 38.56829 -92.25329   8    1   1971
# 26   Supercenter 35.05279 -94.61829   6    1   1971
# 27   Supercenter 34.87942 -92.12244   4    1   1971
# 28   Supercenter 39.17932 -91.88404   2    1   1971
# 29   Supercenter 37.83856 -94.35075  11    1   1971
# 30   Supercenter 39.18499 -96.56932  10    1   1971
# ⋮    ⋮           ⋮        ⋮          ⋮     ⋮   ⋮
# 2963 Supercenter 46.27025 -119.09462 1     23  2006
# 2964 Supercenter 33.89250  -84.83460 1     27  2006
# 2965 Supercenter 39.62470 -119.70585 1     23  2006
# 2966 Supercenter 42.81266  -96.94651 1     27  2006
# 2967 Wal-Mart    39.73428  -75.66310 1     31  2006
# 2968 Supercenter 33.82220  -84.03707 1     25  2006
# 2969 Supercenter 40.15651  -84.24213 1     27  2006
# 2970 Wal-Mart    40.10386  -74.93734 1     25  2006
# 2971 Supercenter 40.61357  -79.78095 1     31  2006
# 2972 Supercenter 33.78113  -86.45052 1     25  2006
# 2973 Supercenter 44.09149  -75.82694 1     31  2006
# 2974 Supercenter 42.92568  -83.63585 1     27  2006
# 2975 Supercenter 35.03167  -85.37276 1     31  2006
# 2976 Supercenter 28.54574  -81.74805 1     27  2006
# 2977 Supercenter 35.01851  -82.43224 1     23  2006
# 2978 Supercenter 36.42145  -79.97458 1     31  2006
# 2979 Supercenter 34.48117 -118.42821 1     27  2006
# 2980 Supercenter 42.04265  -91.58262 1     23  2006
# 2981 Supercenter 39.91292  -80.73701 1     31  2006
# 2982 Supercenter 40.16014 -105.01772 1     31  2006
# 2983 Supercenter 41.80063  -81.06021 1     31  2006
# 2984 Supercenter 36.68754  -76.22905 1     31  2006
# 2985 Supercenter 40.76659  -82.51869 1     31  2006
# 2986 Supercenter 36.11145  -79.27142 1     23  2006
# 2987 Supercenter 38.79660  -90.78525 1     23  2006
# 2988 Supercenter 40.12165  -88.17649 1     27  2006
# 2989 Supercenter 27.99739  -81.68256 1     23  2006
# 2990 Wal-Mart    41.71993  -87.70249 1     27  2006
# 2991 Supercenter 29.63643  -95.21789 1     27  2006
# 2992 Wal-Mart    33.92282 -117.16837 1     31  2006

# %%
# Get the Google Map tile at zoom level 7 for Fort Worth, Texas

TX <- suppressMessages(get_map("fort worth, texas", zoom = 7))



# Create a map from it, slightly whiten it. 

TXmap <- ggmap(TX, extent = "device", darken = c(.2,"white"))

# %%
# Draw the map first 
TXmap +

# add levels 
geom_density2d(data = df, aes(x = LON, y = LAT), size = 0.3) + 

# add density heat map
stat_density2d(data = df, aes(x = LON, y = LAT, fill = ..level.., alpha = ..level..), 
               size = 0.01, bins = 16, geom = "polygon") + 

# color scale 
scale_fill_gradient("Store\nDensity", low = "green", high = "red", na.value = "grey50",) + 

scale_alpha(range = c(0.05, 0.2), guide = FALSE) + 

# add store locations here so that they are on top 
geom_point(data = df, aes(x = LON, y = LAT), color = "#0072CE") + 

# remove the legend 
theme(legend.position = NULL) + 

# add title
ggtitle("Walmart Stores in the Fort Worth Region")
# Out:
# Warning message:
# “Removed 2733 rows containing non-finite values (stat_density2d).”Warning message:
# “Removed 2733 rows containing non-finite values (stat_density2d).”Warning message:
# “Removed 2733 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# **Exercise 6:** **Do the same exercise above** for **motor vehicle theft** data except the point layer.
#
# **Plot the densities of all data points for all years on the same map.**

# %%
df <-read.csv("/dsa/data/all_datasets/motor_vehicle_thefts/mvt.csv")
head(df)
# Out:
#   ID      Date             LocationDescription           Arrest Domestic Beat
# 1 8951354 12/31/2012 23:15 STREET                        FALSE  FALSE     623
# 2 8951141 12/31/2012 22:00 STREET                        FALSE  FALSE    1213
# 3 8952745 12/31/2012 22:00 RESIDENTIAL YARD (FRONT/BACK) FALSE  FALSE    1622
# 4 8952223 12/31/2012 22:00 STREET                        FALSE  FALSE     724
# 5 8951608 12/31/2012 21:30 STREET                        FALSE  FALSE     211
# 6 8950793 12/31/2012 20:30 STREET                         TRUE  FALSE    2521
#   District CommunityArea Year Latitude Longitude
# 1  6       69            2012 41.75628 -87.62164
# 2 12       24            2012 41.89879 -87.66130
# 3 16       11            2012 41.96919 -87.76767
# 4  7       67            2012 41.76933 -87.65773
# 5  2       35            2012 41.83757 -87.62176
# 6 25       19            2012 41.92856 -87.75400

# %%
# Get the Google Map tile at zoom level 11 for Chicago
chi <- suppressMessages(get_map("chicago, illinois", zoom = 11))
chiMap <- ggmap(chi, extent = "device", darken = c(.2,"white"))

map <- chiMap +
    geom_density2d(data = df, aes(x = Longitude, y = Latitude), size = 0.3) + 
    stat_density2d(data = df, aes(x = Longitude, y = Latitude, fill = ..level.., alpha = ..level..), 
                   size = 0.01, bins = 16, geom = "polygon") + 
    scale_fill_gradient("Car\nThefts", low = "green", high = "red", na.value = "grey50",) + 
    scale_alpha(range = c(0.05, 0.2), guide = FALSE) + 
    theme(legend.position = NULL) + 
    ggtitle("Auto Thefts in Chicago", subtitle = "2001-2012")

map
# Out:
# Warning message:
# “Removed 13308 rows containing non-finite values (stat_density2d).”Warning message:
# “Removed 13308 rows containing non-finite values (stat_density2d).”
# plot without title

# %% [markdown]
# **Exercise 7:** **Repeat** exercise 6 for **small multiples of years**. (hint: use the same ggplot object you createad above and add code for small multiples.)

# %%
maps <- map + facet_wrap(~Year) + 
    ggtitle("Auto Thefts in Chicago by Year")

maps
# Out:
# Warning message:
# “Removed 13308 rows containing non-finite values (stat_density2d).”Warning message:
# “Removed 13308 rows containing non-finite values (stat_density2d).”
# plot without title
