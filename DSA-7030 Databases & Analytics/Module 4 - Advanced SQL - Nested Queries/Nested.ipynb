# %% [markdown]
# # Nested Query Exercise
#
# Please remember to use the `EXPLAIN` before you execute a query to help avoid unnecessary load on the DBMS and indefinite waits by you for results.
#
# Therefore, for each question, we are providing a cell for the `EXPLAIN` as well as the final SQL.
#
#
# ## Our practice schema:
#
# We will be using the DVD rental schema for this exercise.
#
# The ERD is available [here](../images/ERD-Rental.pdf).
# Printing is recommended.
#
#
# <span style="font-weight:900; background:yellow">Each query should be implemented with at least one nested query.</span>

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# # 1
#
# ### Which films have no rentals on the date of 2005-05-31
#
# **HINT:** PostgreSQL can cast a _timestamp_ to a _date_ as so: `rental.rental_date::date`.

# %%
# %%sql
# EXPLAIN
# SELECT  DISTINCT title
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
# WHERE   i.inventory_id NOT IN (
#             SELECT  inventory_id
#             FROM    rental
#             WHERE   rental_date::date = '2005-05-31'
#         );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 11 rows affected.
# [('HashAggregate  (cost=561.38..571.38 rows=1000 width=15)',),
#  ('  Group Key: f.title',),
#  ('  ->  Hash Join  (cost=467.36..555.66 rows=2290 width=15)',),
#  ('        Hash Cond: (i.film_id = f.film_id)',),
#  ('        ->  Seq Scan on inventory i  (cost=390.86..473.12 rows=2290 width=2)',),
#  ('              Filter: (NOT (hashed SubPlan 1))',),
#  ('              SubPlan 1',),
#  ('                ->  Seq Scan on rental  (cost=0.00..390.66 rows=80 width=4)',),
#  ("                      Filter: ((rental_date)::date = '2005-05-31'::date)",),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT  DISTINCT title
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
# WHERE   i.inventory_id NOT IN (
#             SELECT  inventory_id
#             FROM    rental
#             WHERE   rental_date::date = '2005-05-31'
#         )
# ORDER BY title;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 957 rows affected.
# [('Academy Dinosaur',),
#  ('Ace Goldfinger',),
#  ('Adaptation Holes',),
#  ('Affair Prejudice',),
#  ('African Egg',),
#  ('Agent Truman',),
#  ('Airplane Sierra',),
#  ('Airport Pollock',),
#  ('Alabama Devil',),
#  ('Aladdin Calendar',),
#  ('Alamo Videotape',),
#  ('Alaska Phantom',),
#  ('Alien Center',),
#  ('Ali Forever',),
#  ('Alley Evolution',),
#  ('Alone Trip',),
#  ('Alter Victory',),
#  ('Amadeus Holy',),
#  ('Amelie Hellfighters',),
#  ('American Circus',),
#  ('Amistad Midsummer',),
#  ('Anaconda Confessions',),
#  ('Analyze Hoosiers',),
#  ('Angels Life',),
#  ('Annie Identity',),
#  ('Anonymous Human',),
#  ('Anthem Luke',),
#  ('Anything Savannah',),
#  ('Apache Divine',),
#  ('Apocalypse Flamingos',),
#  ('Arabia Dogma',),
#  ('Arachnophobia Rollercoaster',),
#  ('Arizona Bang',),
#  ('Armageddon Lost',),
#  ('Army Flintstones',),
#  ('Artist Coldblooded',),
#  ('Atlantis Cause',),
#  ('Attacks Hate',),
#  ('Attraction Newton',),
#  ('Autumn Crow',),
#  ('Baby Hall',),
#  ('Backlash Undefeated',),
#  ('Badman Dawn',),
#  ('Baked Cleopatra',),
#  ('Balloon Homeward',),
#  ('Ballroom Mockingbird',),
#  ('Banger Pinocchio',),
#  ('Bang Kwai',),
#  ('Barbarella Streetcar',),
#  ('Barefoot Manchurian',),
#  ('Basic Easy',),
#  ('Beach Heartbreakers',),
#  ('Bear Graceland',),
#  ('Beast Hunchback',),
#  ('Beauty Grease',),
#  ('Bedazzled Married',),
#  ('Bed Highball',),
#  ('Beethoven Exorcist',),
#  ('Behavior Runaway',),
#  ('Beneath Rush',),
#  ('Berets Agent',),
#  ('Betrayed Rear',),
#  ('Beverly Outlaw',),
#  ('Bikini Borrowers',),
#  ('Bilko Anonymous',),
#  ('Bill Others',),
#  ('Bingo Talented',),
#  ('Birch Antitrust',),
#  ('Birdcage Casper',),
#  ('Bird Independence',),
#  ('Birds Perdition',),
#  ('Blackout Private',),
#  ('Blade Polish',),
#  ('Blanket Beverly',),
#  ('Blindness Gun',),
#  ('Blood Argonauts',),
#  ('Blues Instinct',),
#  ('Boiled Dares',),
#  ('Bonnie Holocaust',),
#  ('Boogie Amelie',),
#  ('Born Spinal',),
#  ('Borrowers Bedazzled',),
#  ('Boulevard Mob',),
#  ('Bound Cheaper',),
#  ('Bowfinger Gables',),
#  ('Brannigan Sunrise',),
#  ('Braveheart Human',),
#  ('Breakfast Goldfinger',),
#  ('Breaking Home',),
#  ('Bride Intrigue',),
#  ('Bright Encounters',),
#  ('Bringing Hysterical',),
#  ('Brooklyn Desert',),
#  ('Brotherhood Blanket',),
#  ('Bubble Grosse',),
#  ('Bucket Brotherhood',),
#  ('Bugsy Song',),
#  ('Bull Shawshank',),
#  ('Bulworth Commandments',),
#  ('Bunch Minds',),
#  ('Butterfly Chocolat',),
#  ('Cabin Flash',),
#  ('Caddyshack Jedi',),
#  ('Calendar Gunfight',),
#  ('California Birds',),
#  ('Camelot Vacation',),
#  ('Campus Remember',),
#  ('Candidate Perdition',),
#  ('Candles Grapes',),
#  ('Canyon Stock',),
#  ('Caper Motions',),
#  ('Caribbean Liberty',),
#  ('Carol Texas',),
#  ('Carrie Bunch',),
#  ('Casablanca Super',),
#  ('Casper Dragonfly',),
#  ('Cassidy Wyoming',),
#  ('Casualties Encino',),
#  ('Cat Coneheads',),
#  ('Cause Date',),
#  ('Celebrity Horn',),
#  ('Center Dinosaur',),
#  ('Chainsaw Uptown',),
#  ('Chamber Italian',),
#  ('Champion Flatliners',),
#  ('Chance Resurrection',),
#  ('Chaplin License',),
#  ('Charade Duffel',),
#  ('Chariots Conspiracy',),
#  ('Chasing Fight',),
#  ('Cheaper Clyde',),
#  ('Chicago North',),
#  ('Chicken Hellfighters',),
#  ('Chill Luck',),
#  ('Chisum Behavior',),
#  ('Chitty Lock',),
#  ('Chocolat Harry',),
#  ('Christmas Moonshine',),
#  ('Cider Desire',),
#  ('Cincinatti Whisperer',),
#  ('Circus Youth',),
#  ('Citizen Shrek',),
#  ('Clash Freddy',),
#  ('Cleopatra Devil',),
#  ('Clerks Angels',),
#  ('Clockwork Paradise',),
#  ('Clones Pinocchio',),
#  ('Closer Bang',),
#  ('Club Graffiti',),
#  ('Clue Grail',),
#  ('Clueless Bucket',),
#  ('Clyde Theory',),
#  ('Coast Rainbow',),
#  ('Coldblooded Darling',),
#  ('Color Philadelphia',),
#  ('Coma Head',),
#  ('Comancheros Enemy',),
#  ('Comforts Rush',),
#  ('Command Darling',),
#  ('Coneheads Smoochy',),
#  ('Confessions Maguire',),
#  ('Confidential Interview',),
#  ('Confused Candles',),
#  ('Congeniality Quest',),
#  ('Connecticut Tramp',),
#  ('Connection Microcosmos',),
#  ('Conquerer Nuts',),
#  ('Conspiracy Spirit',),
#  ('Contact Anonymous',),
#  ('Control Anthem',),
#  ('Conversation Downhill',),
#  ('Core Suit',),
#  ('Cowboy Doom',),
#  ('Craft Outfield',),
#  ('Cranes Reservoir',),
#  ('Crazy Home',),
#  ('Creatures Shakespeare',),
#  ('Creepers Kane',),
#  ('Crooked Frogmen',),
#  ('Crossroads Casualties',),
#  ('Crow Grease',),
#  ('Cruelty Unforgiven',),
#  ('Crusade Honey',),
#  ('Cupboard Sinners',),
#  ('Curtain Videotape',),
#  ('Cyclone Family',),
#  ('Daddy Pittsburgh',),
#  ('Daisy Menagerie',),
#  ('Dalmations Sweden',),
#  ('Dances None',),
#  ('Dancing Fever',),
#  ('Dangerous Uptown',),
#  ('Dares Pluto',),
#  ('Darkness War',),
#  ('Darko Dorado',),
#  ('Darling Breaking',),
#  ('Darn Forrester',),
#  ('Date Speed',),
#  ('Daughter Madigan',),
#  ('Dawn Pond',),
#  ('Day Unfaithful',),
#  ('Deceiver Betrayed',),
#  ('Deep Crusade',),
#  ('Deer Virginian',),
#  ('Desert Poseidon',),
#  ('Desire Alien',),
#  ('Desperate Trainspotting',),
#  ('Destination Jerk',),
#  ('Destiny Saturday',),
#  ('Details Packer',),
#  ('Detective Vision',),
#  ('Devil Desire',),
#  ('Diary Panic',),
#  ('Dinosaur Secretary',),
#  ('Dirty Ace',),
#  ('Disciple Mother',),
#  ('Disturbing Scarface',),
#  ('Divide Monster',),
#  ('Divine Resurrection',),
#  ('Divorce Shining',),
#  ('Doctor Grail',),
#  ('Dogma Family',),
#  ('Dolls Rage',),
#  ('Donnie Alley',),
#  ('Doom Dancing',),
#  ('Doors President',),
#  ('Dorado Notting',),
#  ('Double Wrath',),
#  ('Doubtfire Labyrinth',),
#  ('Downhill Enough',),
#  ('Dozen Lion',),
#  ('Dracula Crystal',),
#  ('Dragonfly Strangers',),
#  ('Dragon Squad',),
#  ('Dream Pickup',),
#  ('Drifter Commandments',),
#  ('Driver Annie',),
#  ('Driving Polish',),
#  ('Drop Waterfront',),
#  ('Drumline Cyclone',),
#  ('Drums Dynamite',),
#  ('Duck Racer',),
#  ('Dude Blindness',),
#  ('Duffel Apocalypse',),
#  ('Dumbo Lust',),
#  ('Durham Panky',),
#  ('Dwarfs Alter',),
#  ('Dying Maker',),
#  ('Dynamite Tarzan',),
#  ('Eagles Panky',),
#  ('Early Home',),
#  ('Earring Instinct',),
#  ('Earth Vision',),
#  ('Easy Gladiator',),
#  ('Edge Kissing',),
#  ('Effect Gladiator',),
#  ('Egg Igby',),
#  ('Egypt Tenenbaums',),
#  ('Element Freddy',),
#  ('Elephant Trojan',),
#  ('Elf Murder',),
#  ('Elizabeth Shane',),
#  ('Empire Malkovich',),
#  ('Encino Elf',),
#  ('Encounters Curtain',),
#  ('Ending Crowds',),
#  ('Enemy Odds',),
#  ('English Bulworth',),
#  ('Enough Raging',),
#  ('Entrapment Satisfaction',),
#  ('Escape Metropolis',),
#  ('Eve Resurrection',),
#  ('Everyone Craft',),
#  ('Evolution Alter',),
#  ('Excitement Eve',),
#  ('Exorcist Sting',),
#  ('Expecations Natural',),
#  ('Expendable Stallion',),
#  ('Express Lonely',),
#  ('Extraordinary Conquerer',),
#  ('Eyes Driving',),
#  ('Factory Dragon',),
#  ('Falcon Volume',),
#  ('Family Sweet',),
#  ('Fantasia Park',),
#  ('Fantasy Troopers',),
#  ('Fargo Gandhi',),
#  ('Fatal Haunted',),
#  ('Feathers Metal',),
#  ('Fellowship Autumn',),
#  ('Ferris Mother',),
#  ('Feud Frogmen',),
#  ('Fever Empire',),
#  ('Fiction Christmas',),
#  ('Fiddler Lost',),
#  ('Fidelity Devil',),
#  ('Fight Jawbreaker',),
#  ('Finding Anaconda',),
#  ('Fireball Philadelphia',),
#  ('Fire Wolves',),
#  ('Fish Opus',),
#  ('Flamingos Connecticut',),
#  ('Flash Wars',),
#  ('Flatliners Killer',),
#  ('Flight Lies',),
#  ('Flintstones Happiness',),
#  ('Flying Hook',),
#  ('Fool Mockingbird',),
#  ('Forever Candidate',),
#  ('Forrester Comancheros',),
#  ('Forrest Sons',),
#  ('Forward Temple',),
#  ('Freaky Pocus',),
#  ('Freddy Storm',),
#  ('Freedom Cleopatra',),
#  ('French Holiday',),
#  ('Frida Slipper',),
#  ('Frisco Forrest',),
#  ('Frogmen Breaking',),
#  ('Frontier Cabin',),
#  ('Frost Head',),
#  ('Fugitive Maguire',),
#  ('Full Flatliners',),
#  ('Fury Murder',),
#  ('Gables Metropolis',),
#  ('Galaxy Sweethearts',),
#  ('Games Bowfinger',),
#  ('Gandhi Kwai',),
#  ('Gangs Pride',),
#  ('Garden Island',),
#  ('Gaslight Crusade',),
#  ('Gathering Calendar',),
#  ('Gentlemen Stage',),
#  ('Ghostbusters Elf',),
#  ('Ghost Groundhog',),
#  ('Giant Troopers',),
#  ('Gilbert Pelican',),
#  ('Gilmore Boiled',),
#  ('Glass Dying',),
#  ('Gleaming Jawbreaker',),
#  ('Glory Tracy',),
#  ('Godfather Diary',),
#  ('Goldfinger Sensibility',),
#  ('Goldmine Tycoon',),
#  ('Gold River',),
#  ('Gone Trouble',),
#  ('Goodfellas Salute',),
#  ('Go Purple',),
#  ('Gorgeous Bingo',),
#  ('Gosford Donnie',),
#  ('Graceland Dynamite',),
#  ('Graduate Lord',),
#  ('Graffiti Love',),
#  ('Grail Frankenstein',),
#  ('Grapes Fury',),
#  ('Grease Youth',),
#  ('Greatest North',),
#  ('Greedy Roots',),
#  ('Greek Everyone',),
#  ('Grinch Massage',),
#  ('Grit Clockwork',),
#  ('Groove Fiction',),
#  ('Grosse Wonderful',),
#  ('Groundhog Uncut',),
#  ('Gun Bonnie',),
#  ('Gunfighter Mussolini',),
#  ('Gunfight Moon',),
#  ('Guys Falcon',),
#  ('Half Outfield',),
#  ('Hall Cassidy',),
#  ('Halloween Nuts',),
#  ('Hamlet Wisdom',),
#  ('Handicap Boondock',),
#  ('Hanging Deep',),
#  ('Hanky October',),
#  ('Hanover Galaxy',),
#  ('Happiness United',),
#  ('Hardly Robbers',),
#  ('Harold French',),
#  ('Harper Dying',),
#  ('Harry Idaho',),
#  ('Haunted Antitrust',),
#  ('Haunting Pianist',),
#  ('Hawk Chill',),
#  ('Head Stranger',),
#  ('Heartbreakers Bright',),
#  ('Heaven Freedom',),
#  ('Heavenly Gun',),
#  ('Heavyweights Beast',),
#  ('Hedwig Alter',),
#  ('Hellfighters Sierra',),
#  ('Highball Potter',),
#  ('High Encino',),
#  ('Hills Neighbors',),
#  ('Hobbit Alien',),
#  ('Holes Brannigan',),
#  ('Holiday Games',),
#  ('Hollow Jeopardy',),
#  ('Hollywood Anonymous',),
#  ('Holocaust Highball',),
#  ('Holy Tadpole',),
#  ('Home Pity',),
#  ('Homeward Cider',),
#  ('Homicide Peach',),
#  ('Honey Ties',),
#  ('Hook Chariots',),
#  ('Hoosiers Birdcage',),
#  ('Hope Tootsie',),
#  ('Horn Working',),
#  ('Horror Reign',),
#  ('Hotel Happiness',),
#  ('Hours Rage',),
#  ('House Dynamite',),
#  ('Human Graffiti',),
#  ('Hunchback Impossible',),
#  ('Hunger Roof',),
#  ('Hunter Alter',),
#  ('Hunting Musketeers',),
#  ('Hurricane Affair',),
#  ('Hustler Party',),
#  ('Hyde Doctor',),
#  ('Hysterical Grail',),
#  ('Ice Crossing',),
#  ('Idaho Love',),
#  ('Identity Lover',),
#  ('Idols Snatchers',),
#  ('Igby Maker',),
#  ('Illusion Amelie',),
#  ('Image Princess',),
#  ('Impact Aladdin',),
#  ('Impossible Prejudice',),
#  ('Inch Jet',),
#  ('Independence Hotel',),
#  ('Indian Love',),
#  ('Informer Double',),
#  ('Innocent Usual',),
#  ('Insects Stone',),
#  ('Insider Arizona',),
#  ('Instinct Airport',),
#  ('Intentions Empire',),
#  ('Interview Liaisons',),
#  ('Intolerable Intentions',),
#  ('Intrigue Worst',),
#  ('Invasion Cyclone',),
#  ('Iron Moon',),
#  ('Ishtar Rocketeer',),
#  ('Island Exorcist',),
#  ('Italian African',),
#  ('Jacket Frisco',),
#  ('Jade Bunch',),
#  ('Japanese Run',),
#  ('Jason Trap',),
#  ('Jawbreaker Brooklyn',),
#  ('Jaws Harry',),
#  ('Jedi Beneath',),
#  ('Jeepers Wedding',),
#  ('Jekyll Frogmen',),
#  ('Jeopardy Encino',),
#  ('Jericho Mulan',),
#  ('Jerk Paycheck',),
#  ('Jersey Sassy',),
#  ('Jet Neighbors',),
#  ('Jingle Sagebrush',),
#  ('Joon Northwest',),
#  ('Juggler Hardly',),
#  ('Jumanji Blade',),
#  ('Jumping Wrath',),
#  ('Jungle Closer',),
#  ('Kane Exorcist',),
#  ('Karate Moon',),
#  ('Kick Savannah',),
#  ('Killer Innocent',),
#  ('King Evolution',),
#  ('Kiss Glory',),
#  ('Kissing Dolls',),
#  ('Knock Warlock',),
#  ('Kramer Chocolate',),
#  ('Kwai Homeward',),
#  ('Labyrinth League',),
#  ('Ladybugs Armageddon',),
#  ('Lady Stage',),
#  ('Lambs Cincinatti',),
#  ('Language Cowboy',),
#  ('Lawless Vision',),
#  ('Lawrence Love',),
#  ('League Hellfighters',),
#  ('Leathernecks Dwarfs',),
#  ('Lebowski Soldiers',),
#  ('Legally Secretary',),
#  ('Legend Jedi',),
#  ('Lesson Cleopatra',),
#  ('Liaisons Sweet',),
#  ('Liberty Magnificent',),
#  ('License Weekend',),
#  ('Lies Treatment',),
#  ('Life Twisted',),
#  ('Lights Deer',),
#  ('Lion Uncut',),
#  ('Loathing Legally',),
#  ('Lock Rear',),
#  ('Lola Agent',),
#  ('Lolita World',),
#  ('Lonely Elephant',),
#  ('Lord Arizona',),
#  ('Lose Inch',),
#  ('Loser Hustler',),
#  ('Lost Bird',),
#  ('Louisiana Harry',),
#  ('Lovely Jingle',),
#  ('Loverboy Attacks',),
#  ('Lover Truman',),
#  ('Love Suicides',),
#  ('Luck Opus',),
#  ('Lucky Flying',),
#  ('Luke Mummy',),
#  ('Lust Lock',),
#  ('Madigan Dorado',),
#  ('Madison Trap',),
#  ('Madness Attacks',),
#  ('Madre Gables',),
#  ('Magic Mallrats',),
#  ('Magnificent Chitty',),
#  ('Magnolia Forrester',),
#  ('Maguire Apache',),
#  ('Maiden Home',),
#  ('Majestic Floats',),
#  ('Maker Gables',),
#  ('Malkovich Pet',),
#  ('Mallrats United',),
#  ('Maltese Hope',),
#  ('Manchurian Curtain',),
#  ('Mannequin Worst',),
#  ('Married Go',),
#  ('Mars Roman',),
#  ('Masked Bubble',),
#  ('Mask Peach',),
#  ('Massacre Usual',),
#  ('Massage Image',),
#  ('Matrix Snowman',),
#  ('Maude Mod',),
#  ('Meet Chocolate',),
#  ('Memento Zoolander',),
#  ('Menagerie Rushmore',),
#  ('Mermaid Insects',),
#  ('Metal Armageddon',),
#  ('Metropolis Coma',),
#  ('Microcosmos Paradise',),
#  ('Midnight Westward',),
#  ('Midsummer Groundhog',),
#  ('Mighty Luck',),
#  ('Mile Mulan',),
#  ('Million Ace',),
#  ('Minds Truman',),
#  ('Mine Titans',),
#  ('Minority Kiss',),
#  ('Miracle Virtual',),
#  ('Mission Zoolander',),
#  ('Mixed Doors',),
#  ('Mob Duffel',),
#  ('Mockingbird Hollywood',),
#  ('Model Fish',),
#  ('Modern Dorado',),
#  ('Mod Secretary',),
#  ('Money Harold',),
#  ('Monsoon Cause',),
#  ('Monster Spartacus',),
#  ('Monterey Labyrinth',),
#  ('Montezuma Command',),
#  ('Moon Bunch',),
#  ('Moonshine Cabin',),
#  ('Moonwalker Fool',),
#  ('Mosquito Armageddon',),
#  ('Mother Oleander',),
#  ('Motions Details',),
#  ('Moulin Wake',),
#  ('Mourning Purple',),
#  ('Movie Shakespeare',),
#  ('Mulan Moon',),
#  ('Mulholland Beast',),
#  ('Mummy Creatures',),
#  ('Murder Antitrust',),
#  ('Muscle Bright',),
#  ('Music Boondock',),
#  ('Musketeers Wait',),
#  ('Mussolini Spoilers',),
#  ('Mystic Truman',),
#  ('Name Detective',),
#  ('Nash Chocolat',),
#  ('National Story',),
#  ('Natural Stock',),
#  ('Necklace Outbreak',),
#  ('Neighbors Charade',),
#  ('Nemo Campus',),
#  ('Network Peak',),
#  ('Newsies Story',),
#  ('Newton Labyrinth',),
#  ('Nightmare Chill',),
#  ('None Spiking',),
#  ('Noon Papi',),
#  ('North Tequila',),
#  ('Northwest Polish',),
#  ('Notorious Reunion',),
#  ('Notting Speakeasy',),
#  ('Novocaine Flight',),
#  ('Nuts Ties',),
#  ('October Submarine',),
#  ('Odds Boogie',),
#  ('Oklahoma Jumanji',),
#  ('Oleander Clue',),
#  ('Open African',),
#  ('Operation Operation',),
#  ('Opposite Necklace',),
#  ('Opus Ice',),
#  ('Orange Grapes',),
#  ('Orient Closer',),
#  ('Oscar Gold',),
#  ('Others Soup',),
#  ('Outbreak Divine',),
#  ('Outfield Massacre',),
#  ('Outlaw Hanky',),
#  ('Oz Liaisons',),
#  ('Pacific Amistad',),
#  ('Packer Madigan',),
#  ('Pajama Jawbreaker',),
#  ('Panic Club',),
#  ('Panky Submarine',),
#  ('Panther Reds',),
#  ('Papi Necklace',),
#  ('Paradise Sabrina',),
#  ('Paris Weekend',),
#  ('Park Citizen',),
#  ('Party Knock',),
#  ('Past Suicides',),
#  ('Paths Control',),
#  ('Patient Sister',),
#  ('Patriot Roman',),
#  ('Patton Interview',),
#  ('Paycheck Wait',),
#  ('Peach Innocent',),
#  ('Peak Forever',),
#  ('Pelican Comforts',),
#  ('Perfect Groove',),
#  ('Personal Ladybugs',),
#  ('Pet Haunting',),
#  ('Phantom Glory',),
#  ('Philadelphia Wife',),
#  ('Pianist Outfield',),
#  ('Pickup Driving',),
#  ('Pilot Hoosiers',),
#  ('Pinocchio Simon',),
#  ('Pirates Roxanne',),
#  ('Pittsburgh Hunchback',),
#  ('Pity Bound',),
#  ('Pizza Jumanji',),
#  ('Platoon Instinct',),
#  ('Pluto Oleander',),
#  ('Pocus Pulp',),
#  ('Polish Brooklyn',),
#  ('Pollock Deliverance',),
#  ('Pond Seattle',),
#  ('Poseidon Forever',),
#  ('Potluck Mixed',),
#  ('Potter Connecticut',),
#  ('Prejudice Oleander',),
#  ('President Bang',),
#  ('Pride Alamo',),
#  ('Primary Glass',),
#  ('Princess Giant',),
#  ('Private Drop',),
#  ('Prix Undefeated',),
#  ('Pulp Beverly',),
#  ('Punk Divorce',),
#  ('Pure Runner',),
#  ('Purple Movie',),
#  ('Queen Luke',),
#  ('Quest Mussolini',),
#  ('Quills Bull',),
#  ('Racer Egg',),
#  ('Rage Games',),
#  ('Raging Airplane',),
#  ('Random Go',),
#  ('Range Moonwalker',),
#  ('Reap Unfaithful',),
#  ('Rear Trading',),
#  ('Rebel Airport',),
#  ('Records Zorro',),
#  ('Redemption Comforts',),
#  ('Reds Pocus',),
#  ('Reef Salute',),
#  ('Reign Gentlemen',),
#  ('Remember Diary',),
#  ('Requiem Tycoon',),
#  ('Reservoir Adaptation',),
#  ('Resurrection Silverado',),
#  ('Reunion Witches',),
#  ('Rider Caddyshack',),
#  ('Ridgemont Submarine',),
#  ('Right Cranes',),
#  ('Rings Heartbreakers',),
#  ('River Outlaw',),
#  ('Road Roxanne',),
#  ('Robbers Joon',),
#  ('Robbery Bright',),
#  ('Rocketeer Mother',),
#  ('Rock Instinct',),
#  ('Rocky War',),
#  ('Rollercoaster Bringing',),
#  ('Roman Punk',),
#  ('Room Roman',),
#  ('Roots Remember',),
#  ('Roses Treasure',),
#  ('Rouge Squad',),
#  ('Roxanne Rebel',),
#  ('Rugrats Shakespeare',),
#  ('Rules Human',),
#  ('Runaway Tenenbaums',),
#  ('Runner Madigan',),
#  ('Run Pacific',),
#  ('Rush Goodfellas',),
#  ('Rushmore Mermaid',),
#  ('Sabrina Midnight',),
#  ('Saddle Antitrust',),
#  ('Sagebrush Clueless',),
#  ('Saints Bride',),
#  ('Salute Apollo',),
#  ('Samurai Lion',),
#  ('Santa Paris',),
#  ('Sassy Packer',),
#  ('Satisfaction Confidential',),
#  ('Saturday Lambs',),
#  ('Saturn Name',),
#  ('Savannah Town',),
#  ('Scalawag Duck',),
#  ('Scarface Bang',),
#  ('School Jacket',),
#  ('Scissorhands Slums',),
#  ('Scorpion Apollo',),
#  ('Seabiscuit Punk',),
#  ('Searchers Wait',),
#  ('Seattle Expecations',),
#  ('Sea Virgin',),
#  ('Secretary Rouge',),
#  ('Secret Groundhog',),
#  ('Secrets Paradise',),
#  ('Sense Greek',),
#  ('Sensibility Rear',),
#  ('Seven Swarm',),
#  ('Shakespeare Saddle',),
#  ('Shane Darkness',),
#  ('Shanghai Tycoon',),
#  ('Shawshank Bubble',),
#  ('Shepherd Midsummer',),
#  ('Shining Roses',),
#  ('Ship Wonderland',),
#  ('Shock Cabin',),
#  ('Shootist Superfly',),
#  ('Show Lord',),
#  ('Shrek License',),
#  ('Shrunk Divine',),
#  ('Side Ark',),
#  ('Siege Madre',),
#  ('Sierra Divide',),
#  ('Silence Kane',),
#  ('Silverado Goldfinger',),
#  ('Simon North',),
#  ('Sinners Atlantis',),
#  ('Slacker Liaisons',),
#  ('Sleeping Suspects',),
#  ('Sleepless Monsoon',),
#  ('Sleepy Japanese',),
#  ('Sleuth Orient',),
#  ('Sling Luke',),
#  ('Slipper Fidelity',),
#  ('Slums Duck',),
#  ('Smile Earring',),
#  ('Smoking Barbarella',),
#  ('Smoochy Control',),
#  ('Snatchers Montezuma',),
#  ('Snatch Slipper',),
#  ('Snowman Rollercoaster',),
#  ('Soldiers Evolution',),
#  ('Something Duck',),
#  ('Song Hedwig',),
#  ('Sons Interview',),
#  ('Sorority Queen',),
#  ('Soup Wisdom',),
#  ('South Wait',),
#  ('Spartacus Cheaper',),
#  ('Speakeasy Date',),
#  ('Speed Suit',),
#  ('Spice Sorority',),
#  ('Spiking Element',),
#  ('Spinal Rocky',),
#  ('Spirited Casualties',),
#  ('Spirit Flintstones',),
#  ('Splash Gump',),
#  ('Splendor Patton',),
#  ('Spoilers Hellfighters',),
#  ('Spy Mile',),
#  ('Squad Fish',),
#  ('Stagecoach Armageddon',),
#  ('Stage World',),
#  ('Stallion Sundance',),
#  ('Stampede Disturbing',),
#  ('Star Operation',),
#  ('State Wasteland',),
#  ('Steel Santa',),
#  ('Steers Armageddon',),
#  ('Stepmom Dream',),
#  ('Sting Personal',),
#  ('Stock Glass',),
#  ('Stone Fire',),
#  ('Storm Happiness',),
#  ('Story Side',),
#  ('Straight Hours',),
#  ('Strangelove Desire',),
#  ('Strangers Graffiti',),
#  ('Stranger Strangers',),
#  ('Streak Ridgemont',),
#  ('Streetcar Intentions',),
#  ('Strictly Scarface',),
#  ('Submarine Bed',),
#  ('Sugar Wonka',),
#  ('Suit Walls',),
#  ('Summer Scarface',),
#  ('Sun Confessions',),
#  ('Sundance Invasion',),
#  ('Sunrise League',),
#  ('Sunset Racer',),
#  ('Superfly Trip',),
#  ('Super Wyoming',),
#  ('Suspects Quills',),
#  ('Swarm Gold',),
#  ('Sweden Shining',),
#  ('Sweet Brotherhood',),
#  ('Sweethearts Suspects',),
#  ('Talented Homicide',),
#  ('Tarzan Videotape',),
#  ('Taxi Kick',),
#  ('Teen Apollo',),
#  ('Telegraph Voyage',),
#  ('Telemark Heartbreakers',),
#  ('Temple Attraction',),
#  ('Tenenbaums Command',),
#  ('Tequila Past',),
#  ('Terminator Club',),
#  ('Texas Watch',),
#  ('Theory Mermaid',),
#  ('Thief Pelican',),
#  ('Thin Sagebrush',),
#  ('Ties Hunger',),
#  ('Tights Dawn',),
#  ('Timberland Sky',),
#  ('Titanic Boondock',),
#  ('Titans Jerk',),
#  ('Tomatoes Hellfighters',),
#  ('Tomorrow Hustler',),
#  ('Tootsie Pilot',),
#  ('Torque Bound',),
#  ('Tourist Pelican',),
#  ('Towers Hurricane',),
#  ('Town Ark',),
#  ('Tracy Cider',),
#  ('Trading Pinocchio',),
#  ('Traffic Hobbit',),
#  ('Train Bunch',),
#  ('Trainspotting Strangers',),
#  ('Tramp Others',),
#  ('Translation Summer',),
#  ('Trap Guys',),
#  ('Treatment Jekyll',),
#  ('Trip Newton',),
#  ('Trojan Tomorrow',),
#  ('Troopers Metal',),
#  ('Trouble Date',),
#  ('Truman Crazy',),
#  ('Turn Star',),
#  ('Tuxedo Mile',),
#  ('Twisted Pirates',),
#  ('Tycoon Gathering',),
#  ('Unbreakable Karate',),
#  ('Uncut Suicides',),
#  ('Undefeated Dalmations',),
#  ('Unfaithful Kill',),
#  ('Unforgiven Zoolander',),
#  ('United Pilot',),
#  ('Untouchables Sunrise',),
#  ('Uprising Uptown',),
#  ('Uptown Young',),
#  ('Usual Untouchables',),
#  ('Vacation Boondock',),
#  ('Valentine Vanishing',),
#  ('Valley Packer',),
#  ('Vampire Whale',),
#  ('Vanilla Day',),
#  ('Vanished Garden',),
#  ('Vanishing Rocky',),
#  ('Varsity Trip',),
#  ('Velvet Terminator',),
#  ('Vertigo Northwest',),
#  ('Victory Academy',),
#  ('Videotape Arsenic',),
#  ('Vietnam Smoochy',),
#  ('Virgin Daisy',),
#  ('Virginian Pluto',),
#  ('Virtual Spoilers',),
#  ('Vision Torque',),
#  ('Voice Peach',),
#  ('Volcano Texas',),
#  ('Voyage Legally',),
#  ('Wagon Jaws',),
#  ('Wait Cider',),
#  ('Wanda Chamber',),
#  ('Wardrobe Phantom',),
#  ('Warlock Werewolf',),
#  ('War Notting',),
#  ('Wars Pluto',),
#  ('Wash Heavenly',),
#  ('Wasteland Divine',),
#  ('Watch Tracy',),
#  ('Waterfront Deliverance',),
#  ('Watership Frontier',),
#  ('Wedding Apollo',),
#  ('Weekend Personal',),
#  ('Werewolf Lola',),
#  ('West Lion',),
#  ('Westward Seabiscuit',),
#  ('Whale Bikini',),
#  ('Whisperer Giant',),
#  ('Wife Turn',),
#  ('Wild Apollo',),
#  ('Willow Tracy',),
#  ('Window Side',),
#  ('Wind Phantom',),
#  ('Wisdom Worker',),
#  ('Witches Panic',),
#  ('Wizard Coldblooded',),
#  ('Wolves Desire',),
#  ('Women Dorado',),
#  ('Won Dares',),
#  ('Wonderful Drop',),
#  ('Wonderland Christmas',),
#  ('Wonka Sea',),
#  ('Words Hunter',),
#  ('Worker Tarzan',),
#  ('Working Microcosmos',),
#  ('World Leathernecks',),
#  ('Worst Banger',),
#  ('Wrath Mile',),
#  ('Wrong Behavior',),
#  ('Wyoming Storm',),
#  ('Yentl Idaho',),
#  ('Young Language',),
#  ('Youth Kick',),
#  ('Zhivago Core',),
#  ('Zoolander Fiction',),
#  ('Zorro Ark',)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/MWpp2ioeAb8)
#
#
# ---
#
# # 2
#
# ### Which customers (name, phone number) have outstanding rentals (film name, rental_date)?

# %%
# %%sql
# EXPLAIN
# SELECT  c.first_name
#         ,c.last_name
#         ,a.phone
#         ,f.title
#         ,rentals.rental_date
#         ,rentals.return_date
# FROM    customer AS c JOIN address AS a
#         ON c.address_id = a.address_id
#         INNER JOIN (
#             SELECT  rental_date
#                     ,return_date
#                     ,inventory_id
#                     ,customer_id
#             FROM    rental
#             WHERE   return_date IS NULL
#         ) AS rentals
#         ON c.customer_id = rentals.customer_id
#         JOIN inventory AS i
#         ON rentals.inventory_id = i.inventory_id
#         JOIN film AS f
#         ON f.film_id = i.film_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 17 rows affected.
# [('Nested Loop  (cost=357.05..533.41 rows=183 width=56)',),
#  ('  ->  Hash Join  (cost=356.77..470.46 rows=183 width=43)',),
#  ('        Hash Cond: (c.address_id = a.address_id)',),
#  ('        ->  Hash Join  (cost=335.21..448.41 rows=183 width=33)',),
#  ('              Hash Cond: (rental.customer_id = c.customer_id)',),
#  ('              ->  Hash Join  (cost=312.73..425.45 rows=183 width=20)',),
#  ('                    Hash Cond: (i.inventory_id = rental.inventory_id)',),
#  ('                    ->  Seq Scan on inventory i  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('                    ->  Hash  (cost=310.44..310.44 rows=183 width=22)',),
#  ('                          ->  Seq Scan on rental  (cost=0.00..310.44 rows=183 width=22)',),
#  ('                                Filter: (return_date IS NULL)',),
#  ('              ->  Hash  (cost=14.99..14.99 rows=599 width=19)',),
#  ('                    ->  Seq Scan on customer c  (cost=0.00..14.99 rows=599 width=19)',),
#  ('        ->  Hash  (cost=14.03..14.03 rows=603 width=16)',),
#  ('              ->  Seq Scan on address a  (cost=0.00..14.03 rows=603 width=16)',),
#  ('  ->  Index Scan using film_pkey on film f  (cost=0.28..0.34 rows=1 width=19)',),
#  ('        Index Cond: (film_id = i.film_id)',)]

# %%
# %%sql
# SELECT  c.first_name
#         ,c.last_name
#         ,a.phone
#         ,f.title
#         ,rentals.rental_date
#         ,rentals.return_date
# FROM    customer AS c JOIN address AS a
#         ON c.address_id = a.address_id
#         INNER JOIN (
#             SELECT  rental_date
#                     ,return_date
#                     ,inventory_id
#                     ,customer_id
#             FROM    rental
#             WHERE   return_date IS NULL
#         ) AS rentals
#         ON c.customer_id = rentals.customer_id
#         JOIN inventory AS i
#         ON rentals.inventory_id = i.inventory_id
#         JOIN film AS f
#         ON f.film_id = i.film_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 183 rows affected.
# [('Dwayne', 'Olvera', '62127829280', 'Academy Dinosaur', datetime.datetime(2005, 8, 21, 0, 30, 32), None),
#  ('Brandon', 'Huey', '99883471275', 'Ace Goldfinger', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Carmen', 'Owens', '272234298332', 'Affair Prejudice', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Seth', 'Hannon', '864392582257', 'African Egg', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Tracy', 'Cole', '371490777743', 'Ali Forever', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Marcia', 'Dean', '727785483194', 'Alone Trip', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Cecil', 'Vines', '879347453467', 'Amadeus Holy', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Marie', 'Turner', '177727722820', 'American Circus', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Joe', 'Gilliland', '53912826864', 'Amistad Midsummer', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Edward', 'Baugh', '46568045367', 'Armageddon Lost', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Beth', 'Franklin', '470884141195', 'Baked Cleopatra', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gina', 'Williamson', '584316724815', 'Bang Kwai', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Melvin', 'Ellington', '368284120423', 'Basic Easy', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Sonia', 'Gregory', '195003555232', 'Berets Agent', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Florence', 'Woods', '330838016880', 'Blade Polish', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Tyler', 'Wren', '211256301880', 'Blanket Beverly', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Mildred', 'Bailey', '250767749542', 'Boogie Amelie', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Anna', 'Hill', '911872220378', 'Boulevard Mob', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Robin', 'Hayes', '942570536750', 'Bound Cheaper', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lois', 'Butler', '345679835036', 'Bubble Grosse', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lisa', 'Anderson', '635297277345', 'Bull Shawshank', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Sergio', 'Stanfield', '387448063440', 'Camelot Vacation', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Helen', 'Harris', '990911107354', 'Candidate Perdition', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Angela', 'Hernandez', '18461860151', 'Canyon Stock', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Dianne', 'Shelton', '117592274996', 'Cat Coneheads', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Willie', 'Markham', '296394569728', 'Center Dinosaur', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Mildred', 'Bailey', '250767749542', 'Chamber Italian', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gail', 'Knight', '904253967161', 'Chasing Fight', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gary', 'Coy', '168884817145', 'Chitty Lock', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Chris', 'Brothers', '537374465982', 'Cincinatti Whisperer', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Bill', 'Gavin', '924663855568', 'Cleopatra Devil', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Peggy', 'Myers', '196568435814', 'Club Graffiti', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Florence', 'Woods', '330838016880', 'Club Graffiti', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Emily', 'Diaz', '333339908719', 'Connection Microcosmos', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Rafael', 'Abney', '82671830126', 'Conversation Downhill', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Barry', 'Lovelace', '689681677428', 'Creatures Shakespeare', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Ivan', 'Cromwell', '203804046132', 'Creatures Shakespeare', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Dustin', 'Gillette', '131912793873', 'Crooked Frogmen', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lucy', 'Wheeler', '49677664184', 'Curtain Videotape', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Allison', 'Stanley', '594319417514', 'Cyclone Family', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Kyle', 'Spurlock', '736517327853', 'Dances None', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jessie', 'Banks', '352679173732', 'Dances None', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Yolanda', 'Weaver', '352469351088', 'Day Unfaithful', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Margaret', 'Moore', '380657522649', 'Deep Crusade', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Annette', 'Olson', '230250973122', 'Deer Virginian', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Stacey', 'Montgomery', '408304391718', 'Details Packer', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lee', 'Hawks', '270456873752', 'Detective Vision', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Perry', 'Swafford', '914466027044', 'Devil Desire', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Milton', 'Howland', '441628280920', 'Disciple Mother', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Sarah', 'Lewis', '902731229323', 'Divine Resurrection', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Judith', 'Cox', '333489324603', 'Doors President', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Wanda', 'Patterson', '198123170793', 'Doors President', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Grace', 'Ellis', '886636413768', 'Dragonfly Strangers', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Mattie', 'Hoffman', '246810237916', 'Drifter Commandments', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Courtney', 'Day', '890289150158', 'Driver Annie', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Michelle', 'Clark', '892775750063', 'Dwarfs Alter', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Mario', 'Cheatham', '406784385440', 'Eagles Panky', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Hilda', 'Hopkins', '322888976727', 'Earth Vision', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jeanette', 'Greene', '812824036424', 'Effect Gladiator', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Claudia', 'Fuller', '630424482919', 'Encino Elf', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Guy', 'Brownlee', '978430786151', 'Enough Raging', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Elmer', 'Noe', '448876499197', 'Falcon Volume', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Terry', 'Grissom', '142596392389', 'Family Sweet', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Miguel', 'Betancourt', '72524459905', 'Family Sweet', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Leonard', 'Schofield', '779461480495', 'Fight Jawbreaker', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gwendolyn', 'May', '303967439816', 'Flying Hook', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Marion', 'Snyder', '391065549876', 'Forrester Comancheros', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Sonia', 'Gregory', '195003555232', 'Frida Slipper', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Louise', 'Jenkins', '800716535041', 'Frisco Forrest', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Zachary', 'Hite', '191958435142', 'Frost Head', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Elizabeth', 'Brown', '10655648674', 'Gables Metropolis', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Freddie', 'Duggan', '644021380889', 'Ghost Groundhog', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Bill', 'Gavin', '924663855568', 'Gleaming Jawbreaker', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Curtis', 'Irby', '615964523510', 'Gorgeous Bingo', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Scott', 'Shelley', '165450987037', 'Grail Frankenstein', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Allison', 'Stanley', '594319417514', 'Grapes Fury', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Betty', 'White', '517338314235', 'Groundhog Uncut', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jerry', 'Jordon', '647899404952', 'Gunfight Moon', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Enrique', 'Forsythe', '199514580428', 'Gunfight Moon', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Christian', 'Jung', '122981120653', 'Half Outfield', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lawrence', 'Lawton', '845378657301', 'Half Outfield', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Ana', 'Bradley', '72136330362', 'Happiness United', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Norman', 'Currier', '598912394463', 'Harry Idaho', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Laurie', 'Lawrence', '956188728558', 'Haunted Antitrust', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Cathy', 'Spencer', '819416131190', 'Holes Brannigan', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Tom', 'Milner', '985109775584', 'Hunchback Impossible', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gregory', 'Mauldin', '80303246192', 'Hunger Roof', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gail', 'Knight', '904253967161', 'Hyde Doctor', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gloria', 'Cook', '347487831378', 'Igby Maker', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lawrence', 'Lawton', '845378657301', 'Insects Stone', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Ramona', 'Hale', '429925609431', 'Insider Arizona', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jessie', 'Milam', '383353187467', 'Insider Arizona', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Melanie', 'Armstrong', '650752094490', 'Intentions Empire', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Marilyn', 'Ross', '701457319790', 'Intentions Empire', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jay', 'Robb', '834061016202', 'Intrigue Worst', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Cory', 'Meehan', '338244023543', 'Jason Trap', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Joshua', 'Mark', '869507847714', 'Juggler Hardly', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Terrance', 'Roush', '437829801725', 'Kick Savannah', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Felix', 'Gaffney', '107092893983', 'Lady Stage', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Heather', 'Morris', '697760867968', 'Lawless Vision', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Tamara', 'Nguyen', '22326410776', 'Loathing Legally', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Brent', 'Harkins', '854259976812', 'Lord Arizona', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Joel', 'Francisco', '82619513349', 'Lovely Jingle', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Margie', 'Wade', '192459639410', 'Lust Lock', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Tammy', 'Sanders', '251164340471', 'Lust Lock', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lauren', 'Hudson', '168476538960', 'Midnight Westward', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Elmer', 'Noe', '448876499197', 'Minority Kiss', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Ian', 'Still', '239357986667', 'Mockingbird Hollywood', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Katie', 'Elliott', '940830176580', 'Monster Spartacus', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Colleen', 'Burton', '669828224459', 'Moonwalker Fool', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Derrick', 'Bourque', '856872225376', 'Mosquito Armageddon', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Christine', 'Roberts', '539758313890', 'Motions Details', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jordan', 'Archuleta', '817740355461', 'Movie Shakespeare', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Allen', 'Butterfield', '129953030512', 'Mulan Moon', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jeanne', 'Lawson', '764477681869', 'Mulholland Beast', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Craig', 'Morrell', '426255288071', 'Mummy Creatures', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Stacy', 'Cunningham', '104150372603', 'Name Detective', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Juanita', 'Mason', '90921003005', 'None Spiking', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Kenneth', 'Gooden', '508800331065', 'Operation Operation', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Sylvia', 'Ortiz', '765345144779', 'Opposite Necklace', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('April', 'Burns', '581174211853', 'Outfield Massacre', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('John', 'Farnsworth', '51917807050', 'Outlaw Hanky', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Heather', 'Morris', '697760867968', 'Peach Innocent', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Margie', 'Wade', '192459639410', 'Philadelphia Wife', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jordan', 'Archuleta', '817740355461', 'Pianist Outfield', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Annette', 'Olson', '230250973122', 'Pirates Roxanne', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Christine', 'Roberts', '539758313890', 'Pollock Deliverance', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Daisy', 'Bates', '816436065431', 'Pride Alamo', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Cassandra', 'Walters', '685010736240', 'Princess Giant', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Larry', 'Thrasher', '834418779292', 'Pulp Beverly', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Darryl', 'Ashcraft', '717566026669', 'Pure Runner', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Bernard', 'Colby', '82088937724', 'Queen Luke', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jean', 'Bell', '212869228936', 'Ridgemont Submarine', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Carolyn', 'Perez', '471675840679', 'River Outlaw', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Clinton', 'Buford', '484500282381', 'Scarface Bang', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Travis', 'Estep', '214976066017', 'Seabiscuit Punk', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Lucy', 'Wheeler', '49677664184', 'Seattle Expecations', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Viola', 'Hanson', '569868543137', 'Shawshank Bubble', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Adrian', 'Clary', '182059202712', 'Shock Cabin', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Stephanie', 'Mitchell', '42384721397', 'Shock Cabin', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Beverly', 'Brooks', '427454485876', 'Shrek License', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Gilbert', 'Sledge', '959467760895', 'Silverado Goldfinger', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Norma', 'Gonzales', '835433605312', 'Sleeping Suspects', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Alicia', 'Mills', '761379480249', 'Sleepless Monsoon', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Tammy', 'Sanders', '251164340471', 'Sleepy Japanese', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Helen', 'Harris', '990911107354', 'Smoking Barbarella', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Raymond', 'Mcwhorter', '834626715837', 'Smoochy Control', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Charlie', 'Bess', '962020153680', 'Song Hedwig', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Cathy', 'Spencer', '819416131190', 'Sons Interview', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Wendy', 'Harrison', '867546627903', 'Sons Interview', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Holly', 'Fox', '760171523969', 'South Wait', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Kristin', 'Johnston', '785881412500', 'Star Operation', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Miguel', 'Betancourt', '72524459905', 'State Wasteland', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Daryl', 'Larue', '954786054144', 'Streak Ridgemont', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Roland', 'South', '25865528181', 'Suit Walls', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Laura', 'Rodriguez', '161968374323', 'Suit Walls', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Judy', 'Gray', '107137400143', 'Summer Scarface', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Allan', 'Cornish', '50898428626', 'Sundance Invasion', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Cynthia', 'Young', '678220867005', 'Suspects Quills', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Vickie', 'Brewer', '567359279425', 'Swarm Gold', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Natalie', 'Meyer', '873492228462', 'Sweden Shining', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Fred', 'Wheat', '561729882725', 'Sweethearts Suspects', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Cassandra', 'Walters', '685010736240', 'Theory Mermaid', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Morris', 'Mccarter', '278669994384', 'Titanic Boondock', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Justin', 'Ngo', '764680915323', 'Titanic Boondock', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Willie', 'Howell', '991802825778', 'Titans Jerk', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Carolyn', 'Perez', '471675840679', 'Torque Bound', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Julie', 'Sanchez', '680428310138', 'Trading Pinocchio', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Justin', 'Ngo', '764680915323', 'Trojan Tomorrow', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Tammy', 'Sanders', '251164340471', 'Trouble Date', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Andy', 'Vanhorn', '995527378381', 'Tuxedo Mile', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Morris', 'Mccarter', '278669994384', 'Vanished Garden', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Alberto', 'Henning', '618156722572', 'Vanishing Rocky', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Albert', 'Crouse', '256546485220', 'Varsity Trip', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Becky', 'Miles', '648482415405', 'Virginian Pluto', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jenny', 'Castro', '62781725285', 'Volcano Texas', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Greg', 'Robins', '206060652238', 'Wanda Chamber', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Regina', 'Berry', '201705577290', 'Wedding Apollo', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Naomi', 'Jennings', '959949395183', 'Wild Apollo', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Jeremy', 'Hurtado', '600264533987', 'Window Side', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Natalie', 'Meyer', '873492228462', 'Women Dorado', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Neil', 'Renner', '478380208348', 'World Leathernecks', datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  ('Louis', 'Leone', '45554316010', 'Zhivago Core', datetime.datetime(2006, 2, 14, 15, 16, 3), None)]

# %% [markdown]
# # 3
#
# ### List the movies that are not categorized as children's movies.

# %%
# %%sql
# EXPLAIN
# SELECT  title
# FROM    film
# WHERE   film_id NOT IN (
#             SELECT  DISTINCT film_id
#             FROM    film_category AS fc
#                     JOIN category AS c
#                     ON fc.category_id = c.category_id
#             WHERE   name = 'Children'
#         )
# ORDER BY title;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 13 rows affected.
# [('Sort  (cost=110.37..111.62 rows=500 width=15)',),
#  ('  Sort Key: film.title',),
#  ('  ->  Seq Scan on film  (cost=21.46..87.96 rows=500 width=15)',),
#  ('        Filter: (NOT (hashed SubPlan 1))',),
#  ('        SubPlan 1',),
#  ('          ->  HashAggregate  (cost=20.68..21.30 rows=62 width=2)',),
#  ('                Group Key: fc.film_id',),
#  ('                ->  Hash Join  (cost=1.21..20.53 rows=62 width=2)',),
#  ('                      Hash Cond: (fc.category_id = c.category_id)',),
#  ('                      ->  Seq Scan on film_category fc  (cost=0.00..16.00 rows=1000 width=4)',),
#  ('                      ->  Hash  (cost=1.20..1.20 rows=1 width=4)',),
#  ('                            ->  Seq Scan on category c  (cost=0.00..1.20 rows=1 width=4)',),
#  ("                                  Filter: ((name)::text = 'Children'::text)",)]

# %%
# %%sql
# SELECT  title
# FROM    film
# WHERE   film_id NOT IN (
#             SELECT  DISTINCT film_id
#             FROM    film_category AS fc
#                     JOIN category AS c
#                     ON fc.category_id = c.category_id
#             WHERE   name = 'Children'
#         )
# ORDER BY title;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 940 rows affected.
# [('Academy Dinosaur',),
#  ('Ace Goldfinger',),
#  ('Adaptation Holes',),
#  ('Affair Prejudice',),
#  ('African Egg',),
#  ('Agent Truman',),
#  ('Airplane Sierra',),
#  ('Airport Pollock',),
#  ('Alabama Devil',),
#  ('Aladdin Calendar',),
#  ('Alamo Videotape',),
#  ('Alaska Phantom',),
#  ('Alice Fantasia',),
#  ('Alien Center',),
#  ('Ali Forever',),
#  ('Alley Evolution',),
#  ('Alone Trip',),
#  ('Alter Victory',),
#  ('Amadeus Holy',),
#  ('Amelie Hellfighters',),
#  ('American Circus',),
#  ('Amistad Midsummer',),
#  ('Anaconda Confessions',),
#  ('Analyze Hoosiers',),
#  ('Angels Life',),
#  ('Annie Identity',),
#  ('Anonymous Human',),
#  ('Anthem Luke',),
#  ('Antitrust Tomatoes',),
#  ('Anything Savannah',),
#  ('Apache Divine',),
#  ('Apocalypse Flamingos',),
#  ('Apollo Teen',),
#  ('Arabia Dogma',),
#  ('Arachnophobia Rollercoaster',),
#  ('Argonauts Town',),
#  ('Arizona Bang',),
#  ('Ark Ridgemont',),
#  ('Armageddon Lost',),
#  ('Army Flintstones',),
#  ('Arsenic Independence',),
#  ('Artist Coldblooded',),
#  ('Atlantis Cause',),
#  ('Attacks Hate',),
#  ('Attraction Newton',),
#  ('Autumn Crow',),
#  ('Baby Hall',),
#  ('Badman Dawn',),
#  ('Baked Cleopatra',),
#  ('Balloon Homeward',),
#  ('Ballroom Mockingbird',),
#  ('Banger Pinocchio',),
#  ('Bang Kwai',),
#  ('Barbarella Streetcar',),
#  ('Barefoot Manchurian',),
#  ('Basic Easy',),
#  ('Beach Heartbreakers',),
#  ('Beast Hunchback',),
#  ('Beauty Grease',),
#  ('Bedazzled Married',),
#  ('Bed Highball',),
#  ('Beethoven Exorcist',),
#  ('Behavior Runaway',),
#  ('Berets Agent',),
#  ('Beverly Outlaw',),
#  ('Bikini Borrowers',),
#  ('Bilko Anonymous',),
#  ('Bill Others',),
#  ('Bingo Talented',),
#  ('Birch Antitrust',),
#  ('Birdcage Casper',),
#  ('Bird Independence',),
#  ('Birds Perdition',),
#  ('Blackout Private',),
#  ('Blade Polish',),
#  ('Blanket Beverly',),
#  ('Blindness Gun',),
#  ('Blood Argonauts',),
#  ('Blues Instinct',),
#  ('Boiled Dares',),
#  ('Bonnie Holocaust',),
#  ('Boogie Amelie',),
#  ('Boondock Ballroom',),
#  ('Born Spinal',),
#  ('Borrowers Bedazzled',),
#  ('Boulevard Mob',),
#  ('Bound Cheaper',),
#  ('Bowfinger Gables',),
#  ('Brannigan Sunrise',),
#  ('Braveheart Human',),
#  ('Breakfast Goldfinger',),
#  ('Breaking Home',),
#  ('Bride Intrigue',),
#  ('Bright Encounters',),
#  ('Bringing Hysterical',),
#  ('Brooklyn Desert',),
#  ('Brotherhood Blanket',),
#  ('Bubble Grosse',),
#  ('Bucket Brotherhood',),
#  ('Bugsy Song',),
#  ('Bull Shawshank',),
#  ('Bulworth Commandments',),
#  ('Bunch Minds',),
#  ('Butch Panther',),
#  ('Butterfly Chocolat',),
#  ('Caddyshack Jedi',),
#  ('Calendar Gunfight',),
#  ('California Birds',),
#  ('Camelot Vacation',),
#  ('Campus Remember',),
#  ('Candidate Perdition',),
#  ('Candles Grapes',),
#  ('Canyon Stock',),
#  ('Caper Motions',),
#  ('Caribbean Liberty',),
#  ('Carol Texas',),
#  ('Carrie Bunch',),
#  ('Casablanca Super',),
#  ('Cassidy Wyoming',),
#  ('Casualties Encino',),
#  ('Catch Amistad',),
#  ('Cat Coneheads',),
#  ('Cause Date',),
#  ('Celebrity Horn',),
#  ('Center Dinosaur',),
#  ('Chainsaw Uptown',),
#  ('Chamber Italian',),
#  ('Champion Flatliners',),
#  ('Chance Resurrection',),
#  ('Chaplin License',),
#  ('Charade Duffel',),
#  ('Chariots Conspiracy',),
#  ('Chasing Fight',),
#  ('Cheaper Clyde',),
#  ('Chicago North',),
#  ('Chicken Hellfighters',),
#  ('Chill Luck',),
#  ('Chinatown Gladiator',),
#  ('Chisum Behavior',),
#  ('Chitty Lock',),
#  ('Chocolate Duck',),
#  ('Chocolat Harry',),
#  ('Cider Desire',),
#  ('Cincinatti Whisperer',),
#  ('Citizen Shrek',),
#  ('Clash Freddy',),
#  ('Cleopatra Devil',),
#  ('Clerks Angels',),
#  ('Clones Pinocchio',),
#  ('Closer Bang',),
#  ('Club Graffiti',),
#  ('Clue Grail',),
#  ('Clueless Bucket',),
#  ('Clyde Theory',),
#  ('Coast Rainbow',),
#  ('Coldblooded Darling',),
#  ('Color Philadelphia',),
#  ('Coma Head',),
#  ('Comforts Rush',),
#  ('Command Darling',),
#  ('Commandments Express',),
#  ('Coneheads Smoochy',),
#  ('Confessions Maguire',),
#  ('Confidential Interview',),
#  ('Confused Candles',),
#  ('Congeniality Quest',),
#  ('Connecticut Tramp',),
#  ('Connection Microcosmos',),
#  ('Conquerer Nuts',),
#  ('Conspiracy Spirit',),
#  ('Contact Anonymous',),
#  ('Control Anthem',),
#  ('Conversation Downhill',),
#  ('Core Suit',),
#  ('Cowboy Doom',),
#  ('Craft Outfield',),
#  ('Cranes Reservoir',),
#  ('Crazy Home',),
#  ('Creatures Shakespeare',),
#  ('Creepers Kane',),
#  ('Crossing Divorce',),
#  ('Crossroads Casualties',),
#  ('Crowds Telemark',),
#  ('Crow Grease',),
#  ('Cruelty Unforgiven',),
#  ('Crusade Honey',),
#  ('Crystal Breaking',),
#  ('Cupboard Sinners',),
#  ('Curtain Videotape',),
#  ('Cyclone Family',),
#  ('Daddy Pittsburgh',),
#  ('Daisy Menagerie',),
#  ('Dalmations Sweden',),
#  ('Dances None',),
#  ('Dancing Fever',),
#  ('Dangerous Uptown',),
#  ('Dares Pluto',),
#  ('Darkness War',),
#  ('Darko Dorado',),
#  ('Darling Breaking',),
#  ('Darn Forrester',),
#  ('Date Speed',),
#  ('Dawn Pond',),
#  ('Day Unfaithful',),
#  ('Dazed Punk',),
#  ('Deceiver Betrayed',),
#  ('Deep Crusade',),
#  ('Deer Virginian',),
#  ('Deliverance Mulholland',),
#  ('Desert Poseidon',),
#  ('Desire Alien',),
#  ('Desperate Trainspotting',),
#  ('Destination Jerk',),
#  ('Destiny Saturday',),
#  ('Details Packer',),
#  ('Detective Vision',),
#  ('Devil Desire',),
#  ('Diary Panic',),
#  ('Dinosaur Secretary',),
#  ('Dirty Ace',),
#  ('Disciple Mother',),
#  ('Disturbing Scarface',),
#  ('Divide Monster',),
#  ('Divine Resurrection',),
#  ('Divorce Shining',),
#  ('Dogma Family',),
#  ('Dolls Rage',),
#  ('Donnie Alley',),
#  ('Doom Dancing',),
#  ('Doors President',),
#  ('Dorado Notting',),
#  ('Double Wrath',),
#  ('Doubtfire Labyrinth',),
#  ('Downhill Enough',),
#  ('Dozen Lion',),
#  ('Dracula Crystal',),
#  ('Dragonfly Strangers',),
#  ('Dragon Squad',),
#  ('Dream Pickup',),
#  ('Drifter Commandments',),
#  ('Driver Annie',),
#  ('Driving Polish',),
#  ('Drop Waterfront',),
#  ('Drumline Cyclone',),
#  ('Drums Dynamite',),
#  ('Duck Racer',),
#  ('Dude Blindness',),
#  ('Duffel Apocalypse',),
#  ('Dumbo Lust',),
#  ('Durham Panky',),
#  ('Dwarfs Alter',),
#  ('Dying Maker',),
#  ('Dynamite Tarzan',),
#  ('Eagles Panky',),
#  ('Early Home',),
#  ('Earring Instinct',),
#  ('Earth Vision',),
#  ('Easy Gladiator',),
#  ('Edge Kissing',),
#  ('Effect Gladiator',),
#  ('Egg Igby',),
#  ('Egypt Tenenbaums',),
#  ('Element Freddy',),
#  ('Elephant Trojan',),
#  ('Elf Murder',),
#  ('Elizabeth Shane',),
#  ('Encino Elf',),
#  ('Encounters Curtain',),
#  ('Ending Crowds',),
#  ('Enemy Odds',),
#  ('English Bulworth',),
#  ('Enough Raging',),
#  ('Entrapment Satisfaction',),
#  ('Escape Metropolis',),
#  ('Eve Resurrection',),
#  ('Everyone Craft',),
#  ('Evolution Alter',),
#  ('Excitement Eve',),
#  ('Exorcist Sting',),
#  ('Expecations Natural',),
#  ('Expendable Stallion',),
#  ('Express Lonely',),
#  ('Extraordinary Conquerer',),
#  ('Eyes Driving',),
#  ('Factory Dragon',),
#  ('Falcon Volume',),
#  ('Family Sweet',),
#  ('Fantasia Park',),
#  ('Fantasy Troopers',),
#  ('Fatal Haunted',),
#  ('Feathers Metal',),
#  ('Fellowship Autumn',),
#  ('Ferris Mother',),
#  ('Feud Frogmen',),
#  ('Fever Empire',),
#  ('Fiction Christmas',),
#  ('Fiddler Lost',),
#  ('Fidelity Devil',),
#  ('Fight Jawbreaker',),
#  ('Finding Anaconda',),
#  ('Fireball Philadelphia',),
#  ('Firehouse Vietnam',),
#  ('Fire Wolves',),
#  ('Fish Opus',),
#  ('Flamingos Connecticut',),
#  ('Flash Wars',),
#  ('Flatliners Killer',),
#  ('Flight Lies',),
#  ('Flintstones Happiness',),
#  ('Floats Garden',),
#  ('Flying Hook',),
#  ('Fool Mockingbird',),
#  ('Forrester Comancheros',),
#  ('Forrest Sons',),
#  ('Forward Temple',),
#  ('Frankenstein Stranger',),
#  ('Freaky Pocus',),
#  ('Freddy Storm',),
#  ('Freedom Cleopatra',),
#  ('French Holiday',),
#  ('Frida Slipper',),
#  ('Frisco Forrest',),
#  ('Frogmen Breaking',),
#  ('Frontier Cabin',),
#  ('Frost Head',),
#  ('Fugitive Maguire',),
#  ('Gables Metropolis',),
#  ('Galaxy Sweethearts',),
#  ('Games Bowfinger',),
#  ('Gandhi Kwai',),
#  ('Gangs Pride',),
#  ('Garden Island',),
#  ('Gaslight Crusade',),
#  ('Gathering Calendar',),
#  ('Gentlemen Stage',),
#  ('Ghostbusters Elf',),
#  ('Gilbert Pelican',),
#  ('Gilmore Boiled',),
#  ('Gladiator Westward',),
#  ('Glass Dying',),
#  ('Gleaming Jawbreaker',),
#  ('Glory Tracy',),
#  ('Godfather Diary',),
#  ('Goldfinger Sensibility',),
#  ('Goldmine Tycoon',),
#  ('Gold River',),
#  ('Gone Trouble',),
#  ('Goodfellas Salute',),
#  ('Go Purple',),
#  ('Gosford Donnie',),
#  ('Graceland Dynamite',),
#  ('Graffiti Love',),
#  ('Grail Frankenstein',),
#  ('Grapes Fury',),
#  ('Grease Youth',),
#  ('Greatest North',),
#  ('Greedy Roots',),
#  ('Greek Everyone',),
#  ('Grinch Massage',),
#  ('Grit Clockwork',),
#  ('Groove Fiction',),
#  ('Grosse Wonderful',),
#  ('Groundhog Uncut',),
#  ('Gump Date',),
#  ('Gun Bonnie',),
#  ('Gunfighter Mussolini',),
#  ('Gunfight Moon',),
#  ('Guys Falcon',),
#  ('Half Outfield',),
#  ('Halloween Nuts',),
#  ('Hamlet Wisdom',),
#  ('Handicap Boondock',),
#  ('Hanging Deep',),
#  ('Hanky October',),
#  ('Hanover Galaxy',),
#  ('Happiness United',),
#  ('Hardly Robbers',),
#  ('Harold French',),
#  ('Harper Dying',),
#  ('Harry Idaho',),
#  ('Hate Handicap',),
#  ('Haunted Antitrust',),
#  ('Haunting Pianist',),
#  ('Hawk Chill',),
#  ('Head Stranger',),
#  ('Heaven Freedom',),
#  ('Heavenly Gun',),
#  ('Heavyweights Beast',),
#  ('Hedwig Alter',),
#  ('Hellfighters Sierra',),
#  ('Highball Potter',),
#  ('High Encino',),
#  ('Hills Neighbors',),
#  ('Hobbit Alien',),
#  ('Hocus Frida',),
#  ('Holes Brannigan',),
#  ('Holiday Games',),
#  ('Hollow Jeopardy',),
#  ('Holy Tadpole',),
#  ('Home Pity',),
#  ('Homeward Cider',),
#  ('Homicide Peach',),
#  ('Honey Ties',),
#  ('Hook Chariots',),
#  ('Hoosiers Birdcage',),
#  ('Hope Tootsie',),
#  ('Horn Working',),
#  ('Horror Reign',),
#  ('Hotel Happiness',),
#  ('Hours Rage',),
#  ('House Dynamite',),
#  ('Human Graffiti',),
#  ('Hunchback Impossible',),
#  ('Hunger Roof',),
#  ('Hunter Alter',),
#  ('Hunting Musketeers',),
#  ('Hurricane Affair',),
#  ('Hustler Party',),
#  ('Hyde Doctor',),
#  ('Hysterical Grail',),
#  ('Ice Crossing',),
#  ('Idaho Love',),
#  ('Identity Lover',),
#  ('Igby Maker',),
#  ('Illusion Amelie',),
#  ('Image Princess',),
#  ('Impact Aladdin',),
#  ('Impossible Prejudice',),
#  ('Inch Jet',),
#  ('Independence Hotel',),
#  ('Indian Love',),
#  ('Informer Double',),
#  ('Innocent Usual',),
#  ('Insects Stone',),
#  ('Insider Arizona',),
#  ('Instinct Airport',),
#  ('Intentions Empire',),
#  ('Interview Liaisons',),
#  ('Intolerable Intentions',),
#  ('Intrigue Worst',),
#  ('Iron Moon',),
#  ('Ishtar Rocketeer',),
#  ('Island Exorcist',),
#  ('Italian African',),
#  ('Jacket Frisco',),
#  ('Jade Bunch',),
#  ('Japanese Run',),
#  ('Jason Trap',),
#  ('Jawbreaker Brooklyn',),
#  ('Jaws Harry',),
#  ('Jedi Beneath',),
#  ('Jeepers Wedding',),
#  ('Jekyll Frogmen',),
#  ('Jeopardy Encino',),
#  ('Jericho Mulan',),
#  ('Jerk Paycheck',),
#  ('Jet Neighbors',),
#  ('Jingle Sagebrush',),
#  ('Joon Northwest',),
#  ('Juggler Hardly',),
#  ('Jumanji Blade',),
#  ('Jungle Closer',),
#  ('Kane Exorcist',),
#  ('Karate Moon',),
#  ('Kentuckian Giant',),
#  ('Kick Savannah',),
#  ('Kill Brotherhood',),
#  ('Killer Innocent',),
#  ('King Evolution',),
#  ('Kiss Glory',),
#  ('Kissing Dolls',),
#  ('Knock Warlock',),
#  ('Kramer Chocolate',),
#  ('Kwai Homeward',),
#  ('Ladybugs Armageddon',),
#  ('Lady Stage',),
#  ('Lambs Cincinatti',),
#  ('Lawless Vision',),
#  ('Lawrence Love',),
#  ('League Hellfighters',),
#  ('Leathernecks Dwarfs',),
#  ('Lebowski Soldiers',),
#  ('Legend Jedi',),
#  ('Lesson Cleopatra',),
#  ('Liaisons Sweet',),
#  ('Liberty Magnificent',),
#  ('License Weekend',),
#  ('Lies Treatment',),
#  ('Life Twisted',),
#  ('Lights Deer',),
#  ('Lion Uncut',),
#  ('Loathing Legally',),
#  ('Lock Rear',),
#  ('Lola Agent',),
#  ('Lolita World',),
#  ('Lonely Elephant',),
#  ('Lord Arizona',),
#  ('Lose Inch',),
#  ('Loser Hustler',),
#  ('Lost Bird',),
#  ('Louisiana Harry',),
#  ('Lovely Jingle',),
#  ('Loverboy Attacks',),
#  ('Lover Truman',),
#  ('Love Suicides',),
#  ('Luck Opus',),
#  ('Lucky Flying',),
#  ('Luke Mummy',),
#  ('Lust Lock',),
#  ('Madigan Dorado',),
#  ('Madison Trap',),
#  ('Madness Attacks',),
#  ('Madre Gables',),
#  ('Magnificent Chitty',),
#  ('Magnolia Forrester',),
#  ('Maguire Apache',),
#  ('Maiden Home',),
#  ('Majestic Floats',),
#  ('Malkovich Pet',),
#  ('Mallrats United',),
#  ('Maltese Hope',),
#  ('Manchurian Curtain',),
#  ('Mannequin Worst',),
#  ('Married Go',),
#  ('Mars Roman',),
#  ('Masked Bubble',),
#  ('Mask Peach',),
#  ('Massacre Usual',),
#  ('Massage Image',),
#  ('Matrix Snowman',),
#  ('Maude Mod',),
#  ('Meet Chocolate',),
#  ('Memento Zoolander',),
#  ('Menagerie Rushmore',),
#  ('Mermaid Insects',),
#  ('Metal Armageddon',),
#  ('Metropolis Coma',),
#  ('Midnight Westward',),
#  ('Midsummer Groundhog',),
#  ('Mighty Luck',),
#  ('Mile Mulan',),
#  ('Million Ace',),
#  ('Minds Truman',),
#  ('Mine Titans',),
#  ('Minority Kiss',),
#  ('Miracle Virtual',),
#  ('Mission Zoolander',),
#  ('Mixed Doors',),
#  ('Mob Duffel',),
#  ('Mockingbird Hollywood',),
#  ('Modern Dorado',),
#  ('Mod Secretary',),
#  ('Money Harold',),
#  ('Monsoon Cause',),
#  ('Monster Spartacus',),
#  ('Monterey Labyrinth',),
#  ('Montezuma Command',),
#  ('Moon Bunch',),
#  ('Moonshine Cabin',),
#  ('Moonwalker Fool',),
#  ('Mosquito Armageddon',),
#  ('Mother Oleander',),
#  ('Motions Details',),
#  ('Moulin Wake',),
#  ('Mourning Purple',),
#  ('Movie Shakespeare',),
#  ('Mulan Moon',),
#  ('Mulholland Beast',),
#  ('Mummy Creatures',),
#  ('Muppet Mile',),
#  ('Muscle Bright',),
#  ('Music Boondock',),
#  ('Musketeers Wait',),
#  ('Mussolini Spoilers',),
#  ('Mystic Truman',),
#  ('Name Detective',),
#  ('Nash Chocolat',),
#  ('National Story',),
#  ('Natural Stock',),
#  ('Necklace Outbreak',),
#  ('Neighbors Charade',),
#  ('Nemo Campus',),
#  ('Network Peak',),
#  ('Newsies Story',),
#  ('Newton Labyrinth',),
#  ('Nightmare Chill',),
#  ('None Spiking',),
#  ('North Tequila',),
#  ('Northwest Polish',),
#  ('Notorious Reunion',),
#  ('Notting Speakeasy',),
#  ('Novocaine Flight',),
#  ('Nuts Ties',),
#  ('October Submarine',),
#  ('Odds Boogie',),
#  ('Oklahoma Jumanji',),
#  ('Oleander Clue',),
#  ('Open African',),
#  ('Operation Operation',),
#  ('Opposite Necklace',),
#  ('Opus Ice',),
#  ('Orange Grapes',),
#  ('Order Betrayed',),
#  ('Orient Closer',),
#  ('Oscar Gold',),
#  ('Others Soup',),
#  ('Outbreak Divine',),
#  ('Outfield Massacre',),
#  ('Outlaw Hanky',),
#  ('Oz Liaisons',),
#  ('Pacific Amistad',),
#  ('Packer Madigan',),
#  ('Pajama Jawbreaker',),
#  ('Panic Club',),
#  ('Panky Submarine',),
#  ('Panther Reds',),
#  ('Papi Necklace',),
#  ('Paradise Sabrina',),
#  ('Paris Weekend',),
#  ('Park Citizen',),
#  ('Party Knock',),
#  ('Past Suicides',),
#  ('Paths Control',),
#  ('Patient Sister',),
#  ('Patriot Roman',),
#  ('Patton Interview',),
#  ('Paycheck Wait',),
#  ('Peach Innocent',),
#  ('Peak Forever',),
#  ('Pearl Destiny',),
#  ('Pelican Comforts',),
#  ('Perdition Fargo',),
#  ('Perfect Groove',),
#  ('Personal Ladybugs',),
#  ('Pet Haunting',),
#  ('Phantom Glory',),
#  ('Philadelphia Wife',),
#  ('Pianist Outfield',),
#  ('Pickup Driving',),
#  ('Pilot Hoosiers',),
#  ('Pinocchio Simon',),
#  ('Pirates Roxanne',),
#  ('Pittsburgh Hunchback',),
#  ('Pity Bound',),
#  ('Pizza Jumanji',),
#  ('Platoon Instinct',),
#  ('Pluto Oleander',),
#  ('Pocus Pulp',),
#  ('Pollock Deliverance',),
#  ('Pond Seattle',),
#  ('Poseidon Forever',),
#  ('Potluck Mixed',),
#  ('Potter Connecticut',),
#  ('Prejudice Oleander',),
#  ('President Bang',),
#  ('Pride Alamo',),
#  ('Primary Glass',),
#  ('Princess Giant',),
#  ('Private Drop',),
#  ('Prix Undefeated',),
#  ('Psycho Shrunk',),
#  ('Pulp Beverly',),
#  ('Punk Divorce',),
#  ('Pure Runner',),
#  ('Purple Movie',),
#  ('Queen Luke',),
#  ('Quest Mussolini',),
#  ('Quills Bull',),
#  ('Racer Egg',),
#  ('Rage Games',),
#  ('Raging Airplane',),
#  ('Raiders Antitrust',),
#  ('Rainbow Shock',),
#  ('Random Go',),
#  ('Range Moonwalker',),
#  ('Reap Unfaithful',),
#  ('Rear Trading',),
#  ('Rebel Airport',),
#  ('Records Zorro',),
#  ('Redemption Comforts',),
#  ('Reds Pocus',),
#  ('Reef Salute',),
#  ('Reign Gentlemen',),
#  ('Remember Diary',),
#  ('Requiem Tycoon',),
#  ('Reservoir Adaptation',),
#  ('Resurrection Silverado',),
#  ('Reunion Witches',),
#  ('Rider Caddyshack',),
#  ('Ridgemont Submarine',),
#  ('Right Cranes',),
#  ('Rings Heartbreakers',),
#  ('River Outlaw',),
#  ('Road Roxanne',),
#  ('Robbery Bright',),
#  ('Rocketeer Mother',),
#  ('Rock Instinct',),
#  ('Rocky War',),
#  ('Rollercoaster Bringing',),
#  ('Roman Punk',),
#  ('Roof Champion',),
#  ('Room Roman',),
#  ('Roots Remember',),
#  ('Roses Treasure',),
#  ('Rouge Squad',),
#  ('Roxanne Rebel',),
#  ('Rugrats Shakespeare',),
#  ('Rules Human',),
#  ('Runaway Tenenbaums',),
#  ('Runner Madigan',),
#  ('Run Pacific',),
#  ('Rush Goodfellas',),
#  ('Rushmore Mermaid',),
#  ('Saddle Antitrust',),
#  ('Sagebrush Clueless',),
#  ('Saints Bride',),
#  ('Salute Apollo',),
#  ('Samurai Lion',),
#  ('Sassy Packer',),
#  ('Satisfaction Confidential',),
#  ('Saturday Lambs',),
#  ('Saturn Name',),
#  ('Savannah Town',),
#  ('Scalawag Duck',),
#  ('School Jacket',),
#  ('Scissorhands Slums',),
#  ('Scorpion Apollo',),
#  ('Seabiscuit Punk',),
#  ('Searchers Wait',),
#  ('Seattle Expecations',),
#  ('Sea Virgin',),
#  ('Secretary Rouge',),
#  ('Secret Groundhog',),
#  ('Secrets Paradise',),
#  ('Sense Greek',),
#  ('Sensibility Rear',),
#  ('Seven Swarm',),
#  ('Shakespeare Saddle',),
#  ('Shane Darkness',),
#  ('Shanghai Tycoon',),
#  ('Shawshank Bubble',),
#  ('Shining Roses',),
#  ('Ship Wonderland',),
#  ('Shock Cabin',),
#  ('Shootist Superfly',),
#  ('Show Lord',),
#  ('Shrek License',),
#  ('Shrunk Divine',),
#  ('Side Ark',),
#  ('Siege Madre',),
#  ('Sierra Divide',),
#  ('Silence Kane',),
#  ('Silverado Goldfinger',),
#  ('Simon North',),
#  ('Sinners Atlantis',),
#  ('Sky Miracle',),
#  ('Slacker Liaisons',),
#  ('Sleeping Suspects',),
#  ('Sleepless Monsoon',),
#  ('Sleepy Japanese',),
#  ('Sleuth Orient',),
#  ('Sling Luke',),
#  ('Slipper Fidelity',),
#  ('Slums Duck',),
#  ('Smile Earring',),
#  ('Smoking Barbarella',),
#  ('Smoochy Control',),
#  ('Snatchers Montezuma',),
#  ('Snatch Slipper',),
#  ('Snowman Rollercoaster',),
#  ('Soldiers Evolution',),
#  ('Something Duck',),
#  ('Song Hedwig',),
#  ('Sons Interview',),
#  ('Sorority Queen',),
#  ('Soup Wisdom',),
#  ('South Wait',),
#  ('Spartacus Cheaper',),
#  ('Speakeasy Date',),
#  ('Speed Suit',),
#  ('Spice Sorority',),
#  ('Spiking Element',),
#  ('Spinal Rocky',),
#  ('Spirited Casualties',),
#  ('Spirit Flintstones',),
#  ('Splash Gump',),
#  ('Spoilers Hellfighters',),
#  ('Spy Mile',),
#  ('Squad Fish',),
#  ('Stagecoach Armageddon',),
#  ('Stage World',),
#  ('Stallion Sundance',),
#  ('Stampede Disturbing',),
#  ('Star Operation',),
#  ('State Wasteland',),
#  ('Steel Santa',),
#  ('Steers Armageddon',),
#  ('Stepmom Dream',),
#  ('Sting Personal',),
#  ('Stock Glass',),
#  ('Stone Fire',),
#  ('Storm Happiness',),
#  ('Story Side',),
#  ('Straight Hours',),
#  ('Strangers Graffiti',),
#  ('Streak Ridgemont',),
#  ('Streetcar Intentions',),
#  ('Strictly Scarface',),
#  ('Submarine Bed',),
#  ('Sugar Wonka',),
#  ('Suicides Silence',),
#  ('Suit Walls',),
#  ('Summer Scarface',),
#  ('Sun Confessions',),
#  ('Sunrise League',),
#  ('Sunset Racer',),
#  ('Superfly Trip',),
#  ('Super Wyoming',),
#  ('Suspects Quills',),
#  ('Swarm Gold',),
#  ('Sweden Shining',),
#  ('Sweet Brotherhood',),
#  ('Tadpole Park',),
#  ('Talented Homicide',),
#  ('Tarzan Videotape',),
#  ('Taxi Kick',),
#  ('Teen Apollo',),
#  ('Telegraph Voyage',),
#  ('Telemark Heartbreakers',),
#  ('Temple Attraction',),
#  ('Tenenbaums Command',),
#  ('Terminator Club',),
#  ('Texas Watch',),
#  ('Theory Mermaid',),
#  ('Thief Pelican',),
#  ('Thin Sagebrush',),
#  ('Tights Dawn',),
#  ('Timberland Sky',),
#  ('Titanic Boondock',),
#  ('Titans Jerk',),
#  ('Tomatoes Hellfighters',),
#  ('Tomorrow Hustler',),
#  ('Torque Bound',),
#  ('Tourist Pelican',),
#  ('Towers Hurricane',),
#  ('Town Ark',),
#  ('Tracy Cider',),
#  ('Trading Pinocchio',),
#  ('Traffic Hobbit',),
#  ('Train Bunch',),
#  ('Trainspotting Strangers',),
#  ('Tramp Others',),
#  ('Translation Summer',),
#  ('Trap Guys',),
#  ('Treasure Command',),
#  ('Treatment Jekyll',),
#  ('Trip Newton',),
#  ('Trojan Tomorrow',),
#  ('Troopers Metal',),
#  ('Trouble Date',),
#  ('Truman Crazy',),
#  ('Turn Star',),
#  ('Tuxedo Mile',),
#  ('Tycoon Gathering',),
#  ('Unbreakable Karate',),
#  ('Uncut Suicides',),
#  ('Undefeated Dalmations',),
#  ('Unfaithful Kill',),
#  ('Unforgiven Zoolander',),
#  ('United Pilot',),
#  ('Untouchables Sunrise',),
#  ('Uprising Uptown',),
#  ('Usual Untouchables',),
#  ('Vacation Boondock',),
#  ('Valentine Vanishing',),
#  ('Valley Packer',),
#  ('Vampire Whale',),
#  ('Vanilla Day',),
#  ('Vanished Garden',),
#  ('Vanishing Rocky',),
#  ('Varsity Trip',),
#  ('Velvet Terminator',),
#  ('Vertigo Northwest',),
#  ('Victory Academy',),
#  ('Videotape Arsenic',),
#  ('Vietnam Smoochy',),
#  ('Villain Desperate',),
#  ('Virgin Daisy',),
#  ('Virginian Pluto',),
#  ('Virtual Spoilers',),
#  ('Vision Torque',),
#  ('Voice Peach',),
#  ('Volcano Texas',),
#  ('Volume House',),
#  ('Voyage Legally',),
#  ('Wagon Jaws',),
#  ('Wait Cider',),
#  ('Wake Jaws',),
#  ('Wanda Chamber',),
#  ('Wardrobe Phantom',),
#  ('War Notting',),
#  ('Wars Pluto',),
#  ('Wash Heavenly',),
#  ('Wasteland Divine',),
#  ('Watch Tracy',),
#  ('Waterfront Deliverance',),
#  ('Watership Frontier',),
#  ('Wedding Apollo',),
#  ('Weekend Personal',),
#  ('Werewolf Lola',),
#  ('West Lion',),
#  ('Westward Seabiscuit',),
#  ('Whale Bikini',),
#  ('Whisperer Giant',),
#  ('Wife Turn',),
#  ('Wild Apollo',),
#  ('Willow Tracy',),
#  ('Window Side',),
#  ('Wind Phantom',),
#  ('Wisdom Worker',),
#  ('Witches Panic',),
#  ('Wizard Coldblooded',),
#  ('Wolves Desire',),
#  ('Women Dorado',),
#  ('Won Dares',),
#  ('Wonderful Drop',),
#  ('Wonderland Christmas',),
#  ('Wonka Sea',),
#  ('Words Hunter',),
#  ('Worker Tarzan',),
#  ('Working Microcosmos',),
#  ('World Leathernecks',),
#  ('Worst Banger',),
#  ('Wrath Mile',),
#  ('Wyoming Storm',),
#  ('Yentl Idaho',),
#  ('Young Language',),
#  ('Youth Kick',),
#  ('Zhivago Core',),
#  ('Zorro Ark',)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/9WR0ByMn__E)
#
#
# ---
#
# # 4
#
# ### List the names of the customers who have rented the 5 least popular movies.
#
# **The five least popular movies are those movies with the least film rentals**
#
# (Do not include movies that have never been rented, also do not worry about ties go with the 5 even though there may be other movies rented the same number of times as some in the 5 least popular.)

# %%
# %%sql
# EXPLAIN
# SELECT  title
#         ,rentals.cnt AS rentals
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
#         INNER JOIN (
#             SELECT  COUNT(*) as cnt
#                     ,inventory_id
#             FROM    rental
#             WHERE   rental_date IS NOT NULL
#             GROUP BY inventory_id
#         ) AS rentals
#         ON i.inventory_id = rentals.inventory_id
# ORDER BY rentals.cnt
# LIMIT 5;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 15 rows affected.
# [('Limit  (cost=787.02..787.03 rows=5 width=23)',),
#  ('  ->  Sort  (cost=787.02..798.47 rows=4580 width=23)',),
#  ('        Sort Key: (count(*))',),
#  ('        ->  Hash Join  (cost=595.23..710.94 rows=4580 width=23)',),
#  ('              Hash Cond: (i.film_id = f.film_id)',),
#  ('              ->  Hash Join  (cost=518.73..622.37 rows=4580 width=10)',),
#  ('                    Hash Cond: (rental.inventory_id = i.inventory_id)',),
#  ('                    ->  HashAggregate  (cost=390.66..436.46 rows=4580 width=12)',),
#  ('                          Group Key: rental.inventory_id',),
#  ('                          ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=4)',),
#  ('                                Filter: (rental_date IS NOT NULL)',),
#  ('                    ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                          ->  Seq Scan on inventory i  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('              ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('                    ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT  title, rentals.cnt AS rentals
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
#         INNER JOIN (
#             SELECT  COUNT(*) as cnt
#                     ,inventory_id
#             FROM    rental
#             WHERE   rental_date IS NOT NULL
#             GROUP BY inventory_id
#         ) AS rentals
#         ON i.inventory_id = rentals.inventory_id
# ORDER BY rentals.cnt
# LIMIT 5;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 5 rows affected.
# [('Mixed Doors', 1),
#  ('Rocky War', 1),
#  ('Galaxy Sweethearts', 1),
#  ('Musketeers Wait', 1),
#  ('Encino Elf', 2)]

# %% [markdown]
# # 5
#
# ### List the movies that have been rented by the top ten renters.

# %%
# %%sql
# EXPLAIN
# SELECT  DISTINCT f.title
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
#         JOIN rental AS r
#         ON i.inventory_id = r.inventory_id
# WHERE   r.customer_id IN (
#             SELECT  customer_id
#             FROM    rental
#             GROUP BY customer_id
#             ORDER BY COUNT(*) DESC
#             LIMIT   10
#         );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 18 rows affected.
# [('Hash Join  (cost=486.63..922.98 rows=268 width=15)',),
#  ('  Hash Cond: (i.film_id = f.film_id)',),
#  ('  ->  Nested Loop  (cost=410.13..845.77 rows=268 width=2)',),
#  ('        ->  Hash Join  (cost=409.84..762.70 rows=268 width=4)',),
#  ('              Hash Cond: (r.customer_id = "ANY_subquery".customer_id)',),
#  ('              ->  Seq Scan on rental r  (cost=0.00..310.44 rows=16044 width=6)',),
#  ('              ->  Hash  (cost=409.72..409.72 rows=10 width=2)',),
#  ('                    ->  Subquery Scan on "ANY_subquery"  (cost=409.59..409.72 rows=10 width=2)',),
#  ('                          ->  Limit  (cost=409.59..409.62 rows=10 width=10)',),
#  ('                                ->  Sort  (cost=409.59..411.09 rows=599 width=10)',),
#  ('                                      Sort Key: (count(*)) DESC',),
#  ('                                      ->  HashAggregate  (cost=390.66..396.65 rows=599 width=10)',),
#  ('                                            Group Key: rental.customer_id',),
#  ('                                            ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=2)',),
#  ('        ->  Index Scan using inventory_pkey on inventory i  (cost=0.28..0.31 rows=1 width=6)',),
#  ('              Index Cond: (inventory_id = r.inventory_id)',),
#  ('  ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('        ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT  DISTINCT f.title
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
#         JOIN rental AS r
#         ON i.inventory_id = r.inventory_id
# WHERE   r.customer_id IN (
#             SELECT  customer_id
#             FROM    rental
#             GROUP BY customer_id
#             ORDER BY COUNT(*) DESC
#             LIMIT   10
#         );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 324 rows affected.
# [('Adaptation Holes',),
#  ('Affair Prejudice',),
#  ('Airport Pollock',),
#  ('Alabama Devil',),
#  ('Ali Forever',),
#  ('Alone Trip',),
#  ('Alter Victory',),
#  ('American Circus',),
#  ('Amistad Midsummer',),
#  ('Anaconda Confessions',),
#  ('Analyze Hoosiers',),
#  ('Anthem Luke',),
#  ('Arabia Dogma',),
#  ('Arizona Bang',),
#  ('Armageddon Lost',),
#  ('Artist Coldblooded',),
#  ('Attraction Newton',),
#  ('Badman Dawn',),
#  ('Baked Cleopatra',),
#  ('Beach Heartbreakers',),
#  ('Betrayed Rear',),
#  ('Bikini Borrowers',),
#  ('Bill Others',),
#  ('Bird Independence',),
#  ('Birds Perdition',),
#  ('Blues Instinct',),
#  ('Boiled Dares',),
#  ('Boulevard Mob',),
#  ('Brannigan Sunrise',),
#  ('Bringing Hysterical',),
#  ('Brotherhood Blanket',),
#  ('Bucket Brotherhood',),
#  ('Butterfly Chocolat',),
#  ('Cabin Flash',),
#  ('Carol Texas',),
#  ('Cause Date',),
#  ('Celebrity Horn',),
#  ('Chamber Italian',),
#  ('Champion Flatliners',),
#  ('Chance Resurrection',),
#  ('Chariots Conspiracy',),
#  ('Chisum Behavior',),
#  ('Chocolat Harry',),
#  ('Christmas Moonshine',),
#  ('Cider Desire',),
#  ('Closer Bang',),
#  ('Clyde Theory',),
#  ('Coast Rainbow',),
#  ('Color Philadelphia',),
#  ('Coma Head',),
#  ('Comancheros Enemy',),
#  ('Coneheads Smoochy',),
#  ('Confidential Interview',),
#  ('Confused Candles',),
#  ('Congeniality Quest',),
#  ('Connection Microcosmos',),
#  ('Contact Anonymous',),
#  ('Conversation Downhill',),
#  ('Cowboy Doom',),
#  ('Creatures Shakespeare',),
#  ('Crow Grease',),
#  ('Curtain Videotape',),
#  ('Cyclone Family',),
#  ('Daisy Menagerie',),
#  ('Dares Pluto',),
#  ('Darko Dorado',),
#  ('Darn Forrester',),
#  ('Date Speed',),
#  ('Dawn Pond',),
#  ('Deer Virginian',),
#  ('Desire Alien',),
#  ('Destiny Saturday',),
#  ('Details Packer',),
#  ('Detective Vision',),
#  ('Dinosaur Secretary',),
#  ('Disciple Mother',),
#  ('Dogma Family',),
#  ('Double Wrath',),
#  ('Dragonfly Strangers',),
#  ('Driving Polish',),
#  ('Dumbo Lust',),
#  ('Durham Panky',),
#  ('Dying Maker',),
#  ('Earth Vision',),
#  ('Effect Gladiator',),
#  ('Egypt Tenenbaums',),
#  ('Encino Elf',),
#  ('Encounters Curtain',),
#  ('English Bulworth',),
#  ('Entrapment Satisfaction',),
#  ('Everyone Craft',),
#  ('Family Sweet',),
#  ('Fantasy Troopers',),
#  ('Fargo Gandhi',),
#  ('Fatal Haunted',),
#  ('Feud Frogmen',),
#  ('Fidelity Devil',),
#  ('Fight Jawbreaker',),
#  ('Fool Mockingbird',),
#  ('Forrester Comancheros',),
#  ('Forward Temple',),
#  ('Freedom Cleopatra',),
#  ('French Holiday',),
#  ('Frontier Cabin',),
#  ('Full Flatliners',),
#  ('Fury Murder',),
#  ('Gables Metropolis',),
#  ('Galaxy Sweethearts',),
#  ('Games Bowfinger',),
#  ('Gangs Pride',),
#  ('Garden Island',),
#  ('Gathering Calendar',),
#  ('Goldfinger Sensibility',),
#  ('Goldmine Tycoon',),
#  ('Goodfellas Salute',),
#  ('Graceland Dynamite',),
#  ('Graffiti Love',),
#  ('Greek Everyone',),
#  ('Grit Clockwork',),
#  ('Groove Fiction',),
#  ('Groundhog Uncut',),
#  ('Gun Bonnie',),
#  ('Half Outfield',),
#  ('Hanging Deep',),
#  ('Harry Idaho',),
#  ('Haunting Pianist',),
#  ('Head Stranger',),
#  ('Heavenly Gun',),
#  ('Heavyweights Beast',),
#  ('Hellfighters Sierra',),
#  ('Highball Potter',),
#  ('High Encino',),
#  ('Holes Brannigan',),
#  ('Holiday Games',),
#  ('Hollow Jeopardy',),
#  ('Hollywood Anonymous',),
#  ('Holocaust Highball',),
#  ('Honey Ties',),
#  ('Horror Reign',),
#  ('Hurricane Affair',),
#  ('Hustler Party',),
#  ('Ice Crossing',),
#  ('Illusion Amelie',),
#  ('Impossible Prejudice',),
#  ('Inch Jet',),
#  ('Innocent Usual',),
#  ('Insects Stone',),
#  ('Instinct Airport',),
#  ('Interview Liaisons',),
#  ('Intolerable Intentions',),
#  ('Invasion Cyclone',),
#  ('Island Exorcist',),
#  ('Jade Bunch',),
#  ('Jason Trap',),
#  ('Jaws Harry',),
#  ('Jedi Beneath',),
#  ('Jerk Paycheck',),
#  ('Juggler Hardly',),
#  ('Karate Moon',),
#  ('Labyrinth League',),
#  ('Ladybugs Armageddon',),
#  ('Lady Stage',),
#  ('League Hellfighters',),
#  ('Lebowski Soldiers',),
#  ('Liaisons Sweet',),
#  ('Lion Uncut',),
#  ('Lola Agent',),
#  ('Lonely Elephant',),
#  ('Lose Inch',),
#  ('Loser Hustler',),
#  ('Lover Truman',),
#  ('Lust Lock',),
#  ('Madigan Dorado',),
#  ('Madness Attacks',),
#  ('Madre Gables',),
#  ('Majestic Floats',),
#  ('Malkovich Pet',),
#  ('Married Go',),
#  ('Mask Peach',),
#  ('Massage Image',),
#  ('Maude Mod',),
#  ('Mermaid Insects',),
#  ('Metal Armageddon',),
#  ('Midsummer Groundhog',),
#  ('Million Ace',),
#  ('Minds Truman',),
#  ('Mission Zoolander',),
#  ('Moon Bunch',),
#  ('Moonshine Cabin',),
#  ('Moonwalker Fool',),
#  ('Moulin Wake',),
#  ('Movie Shakespeare',),
#  ('Mulholland Beast',),
#  ('Mummy Creatures',),
#  ('Muscle Bright',),
#  ('Music Boondock',),
#  ('Name Detective',),
#  ('Nash Chocolat',),
#  ('National Story',),
#  ('Natural Stock',),
#  ('Neighbors Charade',),
#  ('Network Peak',),
#  ('Northwest Polish',),
#  ('Novocaine Flight',),
#  ('Opposite Necklace',),
#  ('Oscar Gold',),
#  ('Others Soup',),
#  ('Outbreak Divine',),
#  ('Outfield Massacre',),
#  ('Outlaw Hanky',),
#  ('Oz Liaisons',),
#  ('Panther Reds',),
#  ('Paris Weekend',),
#  ('Park Citizen',),
#  ('Patriot Roman',),
#  ('Pelican Comforts',),
#  ('Phantom Glory',),
#  ('Philadelphia Wife',),
#  ('Pickup Driving',),
#  ('Pinocchio Simon',),
#  ('Pittsburgh Hunchback',),
#  ('Pollock Deliverance',),
#  ('Pond Seattle',),
#  ('Poseidon Forever',),
#  ('Prejudice Oleander',),
#  ('Princess Giant',),
#  ('Pulp Beverly',),
#  ('Pure Runner',),
#  ('Purple Movie',),
#  ('Queen Luke',),
#  ('Quest Mussolini',),
#  ('Quills Bull',),
#  ('Racer Egg',),
#  ('Rage Games',),
#  ('Random Go',),
#  ('Range Moonwalker',),
#  ('Reap Unfaithful',),
#  ('Rear Trading',),
#  ('Records Zorro',),
#  ('Reef Salute',),
#  ('Reign Gentlemen',),
#  ('Remember Diary',),
#  ('Requiem Tycoon',),
#  ('Reservoir Adaptation',),
#  ('Ridgemont Submarine',),
#  ('River Outlaw',),
#  ('Robbery Bright',),
#  ('Room Roman',),
#  ('Roots Remember',),
#  ('Rouge Squad',),
#  ('Roxanne Rebel',),
#  ('Sabrina Midnight',),
#  ('Sagebrush Clueless',),
#  ('Salute Apollo',),
#  ('Santa Paris',),
#  ('School Jacket',),
#  ('Scissorhands Slums',),
#  ('Seattle Expecations',),
#  ('Secret Groundhog',),
#  ('Shepherd Midsummer',),
#  ('Shootist Superfly',),
#  ('Sinners Atlantis',),
#  ('Sleeping Suspects',),
#  ('Sleepy Japanese',),
#  ('Slums Duck',),
#  ('Snatchers Montezuma',),
#  ('Snowman Rollercoaster',),
#  ('Soldiers Evolution',),
#  ('Something Duck',),
#  ('South Wait',),
#  ('Spice Sorority',),
#  ('Spirited Casualties',),
#  ('Splash Gump',),
#  ('Splendor Patton',),
#  ('Spy Mile',),
#  ('Stagecoach Armageddon',),
#  ('State Wasteland',),
#  ('Steers Armageddon',),
#  ('Stepmom Dream',),
#  ('Sting Personal',),
#  ('Stone Fire',),
#  ('Storm Happiness',),
#  ('Straight Hours',),
#  ('Strangelove Desire',),
#  ('Stranger Strangers',),
#  ('Strictly Scarface',),
#  ('Sun Confessions',),
#  ('Sunset Racer',),
#  ('Suspects Quills',),
#  ('Swarm Gold',),
#  ('Sweethearts Suspects',),
#  ('Terminator Club',),
#  ('Thief Pelican',),
#  ('Tights Dawn',),
#  ('Timberland Sky',),
#  ('Tomorrow Hustler',),
#  ('Tourist Pelican',),
#  ('Train Bunch',),
#  ('Translation Summer',),
#  ('Trap Guys',),
#  ('Troopers Metal',),
#  ('Trouble Date',),
#  ('Untouchables Sunrise',),
#  ('Uprising Uptown',),
#  ('Vietnam Smoochy',),
#  ('Virtual Spoilers',),
#  ('Wait Cider',),
#  ('Wardrobe Phantom',),
#  ('War Notting',),
#  ('Wash Heavenly',),
#  ('Wasteland Divine',),
#  ('Watch Tracy',),
#  ('Wedding Apollo',),
#  ('Westward Seabiscuit',),
#  ('Whale Bikini',),
#  ('Whisperer Giant',),
#  ('Wife Turn',),
#  ('Window Side',),
#  ('Wizard Coldblooded',),
#  ('Wolves Desire',),
#  ('Won Dares',),
#  ('Wonderful Drop',),
#  ('Words Hunter',),
#  ('Working Microcosmos',)]

# %% [markdown]
# # 6
#
# ### Consider the previous question and the answer SQL.  Now add a column to the result that is the total number of movie rentals for the _top-ten renters_ per film.

# %%
# %%sql
# EXPLAIN
# SELECT  f.title
#         ,COUNT(f.title) AS rentals
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
#         JOIN rental AS r
#         ON i.inventory_id = r.inventory_id
# WHERE   r.customer_id IN (
#             SELECT  customer_id
#             FROM    rental
#             GROUP BY customer_id
#             ORDER BY COUNT(*) DESC
#             LIMIT   10
#         )
# GROUP BY f.title;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 20 rows affected.
# [('HashAggregate  (cost=924.32..927.00 rows=268 width=23)',),
#  ('  Group Key: f.title',),
#  ('  ->  Hash Join  (cost=486.63..922.98 rows=268 width=15)',),
#  ('        Hash Cond: (i.film_id = f.film_id)',),
#  ('        ->  Nested Loop  (cost=410.13..845.77 rows=268 width=2)',),
#  ('              ->  Hash Join  (cost=409.84..762.70 rows=268 width=4)',),
#  ('                    Hash Cond: (r.customer_id = "ANY_subquery".customer_id)',),
#  ('                    ->  Seq Scan on rental r  (cost=0.00..310.44 rows=16044 width=6)',),
#  ('                    ->  Hash  (cost=409.72..409.72 rows=10 width=2)',),
#  ('                          ->  Subquery Scan on "ANY_subquery"  (cost=409.59..409.72 rows=10 width=2)',),
#  ('                                ->  Limit  (cost=409.59..409.62 rows=10 width=10)',),
#  ('                                      ->  Sort  (cost=409.59..411.09 rows=599 width=10)',),
#  ('                                            Sort Key: (count(*)) DESC',),
#  ('                                            ->  HashAggregate  (cost=390.66..396.65 rows=599 width=10)',),
#  ('                                                  Group Key: rental.customer_id',),
#  ('                                                  ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=2)',),
#  ('              ->  Index Scan using inventory_pkey on inventory i  (cost=0.28..0.31 rows=1 width=6)',),
#  ('                    Index Cond: (inventory_id = r.inventory_id)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT  f.title
#         ,COUNT(f.title) AS rentals
# FROM    film AS f JOIN inventory AS i
#         ON f.film_id = i.film_id
#         JOIN rental AS r
#         ON i.inventory_id = r.inventory_id
# WHERE   r.customer_id IN (
#             SELECT  customer_id
#             FROM    rental
#             GROUP BY customer_id
#             ORDER BY COUNT(*) DESC
#             LIMIT   10
#         )
# GROUP BY f.title;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 324 rows affected.
# [('Graceland Dynamite', 1),
#  ('Spirited Casualties', 1),
#  ('War Notting', 1),
#  ('Northwest Polish', 1),
#  ('Instinct Airport', 1),
#  ('Bikini Borrowers', 1),
#  ('Wonderful Drop', 1),
#  ('Purple Movie', 2),
#  ('Beach Heartbreakers', 1),
#  ('Fantasy Troopers', 1),
#  ('Pelican Comforts', 1),
#  ('Madre Gables', 1),
#  ('Robbery Bright', 2),
#  ('Spy Mile', 1),
#  ('Sunset Racer', 1),
#  ('Destiny Saturday', 1),
#  ('Galaxy Sweethearts', 1),
#  ('Something Duck', 1),
#  ('Groundhog Uncut', 1),
#  ('Carol Texas', 1),
#  ('Groove Fiction', 2),
#  ('Window Side', 1),
#  ('Santa Paris', 1),
#  ('Minds Truman', 1),
#  ('Stepmom Dream', 1),
#  ('Arabia Dogma', 1),
#  ('Baked Cleopatra', 1),
#  ('Pittsburgh Hunchback', 1),
#  ('Closer Bang', 2),
#  ('Untouchables Sunrise', 1),
#  ('Natural Stock', 1),
#  ('Innocent Usual', 1),
#  ('Karate Moon', 1),
#  ('English Bulworth', 2),
#  ('Racer Egg', 3),
#  ('Trouble Date', 2),
#  ('Wizard Coldblooded', 1),
#  ('Lonely Elephant', 2),
#  ('Coast Rainbow', 1),
#  ('Hollywood Anonymous', 1),
#  ('Mummy Creatures', 1),
#  ('Roots Remember', 1),
#  ('Room Roman', 1),
#  ('Frontier Cabin', 1),
#  ('Sabrina Midnight', 1),
#  ('Roxanne Rebel', 2),
#  ('Garden Island', 1),
#  ('Airport Pollock', 1),
#  ('Fidelity Devil', 2),
#  ('Madness Attacks', 1),
#  ('Wasteland Divine', 1),
#  ('Dares Pluto', 1),
#  ('Patriot Roman', 1),
#  ('Date Speed', 1),
#  ('Novocaine Flight', 1),
#  ('Thief Pelican', 1),
#  ('Sleeping Suspects', 1),
#  ('Sweethearts Suspects', 2),
#  ('Lola Agent', 1),
#  ('Won Dares', 1),
#  ('Moonshine Cabin', 1),
#  ('Encino Elf', 1),
#  ('Pinocchio Simon', 1),
#  ('Insects Stone', 2),
#  ('Hustler Party', 1),
#  ('Loser Hustler', 1),
#  ('Details Packer', 1),
#  ('Heavyweights Beast', 1),
#  ('Entrapment Satisfaction', 1),
#  ('Butterfly Chocolat', 1),
#  ('Wolves Desire', 2),
#  ('Juggler Hardly', 1),
#  ('Malkovich Pet', 1),
#  ('Labyrinth League', 1),
#  ('Brotherhood Blanket', 1),
#  ('Heavenly Gun', 1),
#  ('Cabin Flash', 1),
#  ('Cyclone Family', 1),
#  ('Poseidon Forever', 1),
#  ('Queen Luke', 1),
#  ('Desire Alien', 1),
#  ('Outlaw Hanky', 1),
#  ('Jaws Harry', 3),
#  ('Strictly Scarface', 2),
#  ('Blues Instinct', 1),
#  ('Pollock Deliverance', 1),
#  ('Hellfighters Sierra', 1),
#  ('Bucket Brotherhood', 1),
#  ('Cowboy Doom', 1),
#  ('Prejudice Oleander', 5),
#  ('School Jacket', 1),
#  ('Bringing Hysterical', 1),
#  ('Haunting Pianist', 1),
#  ('Confidential Interview', 3),
#  ('Jedi Beneath', 1),
#  ('Armageddon Lost', 1),
#  ('Ridgemont Submarine', 1),
#  ('Chariots Conspiracy', 1),
#  ('Inch Jet', 2),
#  ('Double Wrath', 3),
#  ('Half Outfield', 2),
#  ('Tourist Pelican', 1),
#  ('Oscar Gold', 1),
#  ('Interview Liaisons', 2),
#  ('Invasion Cyclone', 1),
#  ('Steers Armageddon', 1),
#  ('Goodfellas Salute', 1),
#  ('Range Moonwalker', 2),
#  ('Chocolat Harry', 1),
#  ('Congeniality Quest', 1),
#  ('Remember Diary', 2),
#  ('Random Go', 1),
#  ('Reef Salute', 1),
#  ('French Holiday', 1),
#  ('Highball Potter', 1),
#  ('Opposite Necklace', 1),
#  ('Translation Summer', 1),
#  ('Illusion Amelie', 1),
#  ('Stagecoach Armageddon', 1),
#  ('American Circus', 3),
#  ('Rear Trading', 1),
#  ('Artist Coldblooded', 1),
#  ('Jerk Paycheck', 1),
#  ('Rouge Squad', 1),
#  ('Amistad Midsummer', 1),
#  ('Nash Chocolat', 2),
#  ('Sleepy Japanese', 2),
#  ('Pure Runner', 1),
#  ('Anthem Luke', 1),
#  ('Pulp Beverly', 1),
#  ('Champion Flatliners', 1),
#  ('League Hellfighters', 1),
#  ('Quills Bull', 1),
#  ('Dragonfly Strangers', 1),
#  ('Lady Stage', 1),
#  ('Reign Gentlemen', 1),
#  ('Impossible Prejudice', 1),
#  ('Moulin Wake', 2),
#  ('Storm Happiness', 1),
#  ('Princess Giant', 1),
#  ('Sinners Atlantis', 1),
#  ('Music Boondock', 1),
#  ('Driving Polish', 1),
#  ('Chisum Behavior', 1),
#  ('Daisy Menagerie', 1),
#  ('Conversation Downhill', 3),
#  ('Dumbo Lust', 1),
#  ('Wash Heavenly', 1),
#  ('Tights Dawn', 1),
#  ('Lebowski Soldiers', 1),
#  ('Chance Resurrection', 1),
#  ('South Wait', 1),
#  ('Fight Jawbreaker', 1),
#  ('Terminator Club', 1),
#  ('Deer Virginian', 2),
#  ('Alter Victory', 1),
#  ('Cider Desire', 1),
#  ('Wedding Apollo', 3),
#  ('Dawn Pond', 3),
#  ('Fargo Gandhi', 1),
#  ('Forrester Comancheros', 2),
#  ('Swarm Gold', 1),
#  ('Married Go', 1),
#  ('Coma Head', 2),
#  ('Disciple Mother', 1),
#  ('Badman Dawn', 1),
#  ('Graffiti Love', 3),
#  ('Pickup Driving', 1),
#  ('Paris Weekend', 2),
#  ('Bill Others', 1),
#  ('Forward Temple', 1),
#  ('Feud Frogmen', 1),
#  ('Timberland Sky', 1),
#  ('Reservoir Adaptation', 2),
#  ('Celebrity Horn', 1),
#  ('Goldmine Tycoon', 1),
#  ('Straight Hours', 1),
#  ('Harry Idaho', 1),
#  ('Network Peak', 2),
#  ('Jade Bunch', 1),
#  ('Name Detective', 3),
#  ('Outfield Massacre', 1),
#  ('Spice Sorority', 2),
#  ('Contact Anonymous', 1),
#  ('Massage Image', 1),
#  ('Liaisons Sweet', 1),
#  ('Others Soup', 2),
#  ('Mission Zoolander', 1),
#  ('Boulevard Mob', 1),
#  ('Alone Trip', 1),
#  ('Strangelove Desire', 1),
#  ('Metal Armageddon', 1),
#  ('Egypt Tenenbaums', 1),
#  ('Goldfinger Sensibility', 2),
#  ('Whisperer Giant', 2),
#  ('Sting Personal', 2),
#  ('Suspects Quills', 1),
#  ('Crow Grease', 1),
#  ('Sun Confessions', 2),
#  ('Oz Liaisons', 1),
#  ('Dogma Family', 1),
#  ('Salute Apollo', 1),
#  ('Whale Bikini', 1),
#  ('Moonwalker Fool', 1),
#  ('Watch Tracy', 2),
#  ('Lust Lock', 1),
#  ('Philadelphia Wife', 1),
#  ('Soldiers Evolution', 1),
#  ('Holes Brannigan', 1),
#  ('Wife Turn', 2),
#  ('Westward Seabiscuit', 1),
#  ('Durham Panky', 1),
#  ('Outbreak Divine', 2),
#  ('Horror Reign', 1),
#  ('Million Ace', 3),
#  ('Color Philadelphia', 2),
#  ('Movie Shakespeare', 1),
#  ('Requiem Tycoon', 1),
#  ('Coneheads Smoochy', 1),
#  ('Ali Forever', 1),
#  ('National Story', 1),
#  ('Madigan Dorado', 1),
#  ('Bird Independence', 2),
#  ('Mask Peach', 1),
#  ('Trap Guys', 1),
#  ('Neighbors Charade', 1),
#  ('Stranger Strangers', 1),
#  ('Scissorhands Slums', 1),
#  ('Boiled Dares', 1),
#  ('Majestic Floats', 1),
#  ('Connection Microcosmos', 1),
#  ('Grit Clockwork', 1),
#  ('State Wasteland', 1),
#  ('Sagebrush Clueless', 1),
#  ('Reap Unfaithful', 2),
#  ('Chamber Italian', 1),
#  ('Effect Gladiator', 1),
#  ('Vietnam Smoochy', 2),
#  ('Stone Fire', 1),
#  ('Confused Candles', 1),
#  ('Moon Bunch', 2),
#  ('Muscle Bright', 2),
#  ('Head Stranger', 2),
#  ('Hollow Jeopardy', 1),
#  ('Darn Forrester', 2),
#  ('Snowman Rollercoaster', 1),
#  ('Quest Mussolini', 1),
#  ('Honey Ties', 1),
#  ('Hurricane Affair', 3),
#  ('Splendor Patton', 1),
#  ('Fool Mockingbird', 2),
#  ('Panther Reds', 1),
#  ('Holocaust Highball', 3),
#  ('Shootist Superfly', 1),
#  ('Adaptation Holes', 1),
#  ('Fatal Haunted', 2),
#  ('Shepherd Midsummer', 1),
#  ('Mermaid Insects', 1),
#  ('Brannigan Sunrise', 1),
#  ('High Encino', 2),
#  ('Rage Games', 2),
#  ('Mulholland Beast', 1),
#  ('Family Sweet', 1),
#  ('Lose Inch', 2),
#  ('Uprising Uptown', 1),
#  ('Wait Cider', 1),
#  ('Everyone Craft', 1),
#  ('Jason Trap', 1),
#  ('Birds Perdition', 1),
#  ('Virtual Spoilers', 1),
#  ('Maude Mod', 2),
#  ('Encounters Curtain', 1),
#  ('Ice Crossing', 1),
#  ('Dying Maker', 2),
#  ('Tomorrow Hustler', 1),
#  ('Creatures Shakespeare', 1),
#  ('Snatchers Montezuma', 1),
#  ('Island Exorcist', 1),
#  ('Betrayed Rear', 1),
#  ('Phantom Glory', 1),
#  ('Arizona Bang', 2),
#  ('Seattle Expecations', 1),
#  ('Analyze Hoosiers', 1),
#  ('Park Citizen', 1),
#  ('Full Flatliners', 1),
#  ('Working Microcosmos', 1),
#  ('Gun Bonnie', 2),
#  ('Midsummer Groundhog', 1),
#  ('Alabama Devil', 1),
#  ('Train Bunch', 1),
#  ('Clyde Theory', 1),
#  ('Attraction Newton', 1),
#  ('Troopers Metal', 1),
#  ('Earth Vision', 1),
#  ('Splash Gump', 2),
#  ('Anaconda Confessions', 2),
#  ('Affair Prejudice', 2),
#  ('Fury Murder', 1),
#  ('Comancheros Enemy', 1),
#  ('Secret Groundhog', 1),
#  ('Dinosaur Secretary', 1),
#  ('Slums Duck', 1),
#  ('Freedom Cleopatra', 1),
#  ('Wardrobe Phantom', 1),
#  ('Cause Date', 2),
#  ('Gangs Pride', 1),
#  ('Games Bowfinger', 1),
#  ('Curtain Videotape', 1),
#  ('Intolerable Intentions', 1),
#  ('River Outlaw', 1),
#  ('Holiday Games', 1),
#  ('Detective Vision', 1),
#  ('Christmas Moonshine', 1),
#  ('Ladybugs Armageddon', 1),
#  ('Darko Dorado', 1),
#  ('Lover Truman', 1),
#  ('Greek Everyone', 1),
#  ('Gathering Calendar', 2),
#  ('Lion Uncut', 1),
#  ('Gables Metropolis', 1),
#  ('Pond Seattle', 2),
#  ('Hanging Deep', 1),
#  ('Words Hunter', 1),
#  ('Records Zorro', 1)]

# %% [markdown]
# # 7
#
# ### List the city of rental stores, `store_id` and the movies that have not been rented from that store.
#
# **Note:** A video walk through for this challenging SQL is provided below.

# %%
# %%sql
# EXPLAIN
# SELECT  c.city, s.store_id, f.title
# FROM    store AS s JOIN address AS a
#         ON s.address_id = a.address_id
#         JOIN city AS c
#         ON a.city_id = c.city_id
#         CROSS JOIN film AS f
# WHERE   NOT EXISTS (
#             SELECT  'x'
#             FROM    film AS f2 JOIN inventory AS i
#                     ON f.film_id = i.film_id
#                     JOIN rental AS r
#                     ON i.inventory_id = r.inventory_id
#                     JOIN staff AS st
#                     ON st.staff_id = r.staff_id
#             WHERE   rental_date IS NOT NULL
#                     AND f2.film_id = f.film_id
#                     AND st.store_id = s.store_id
#         );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 28 rows affected.
# [('Merge Join  (cost=0.55..49285.18 rows=1000 width=28)',),
#  ('  Merge Cond: (a.city_id = c.city_id)',),
#  ('  ->  Nested Loop  (cost=0.28..49237.90 rows=1000 width=21)',),
#  ('        Join Filter: (NOT (SubPlan 1))',),
#  ('        ->  Nested Loop  (cost=0.28..76.39 rows=2 width=6)',),
#  ('              Join Filter: (s.address_id = a.address_id)',),
#  ('              ->  Index Scan using idx_fk_city_id on address a  (cost=0.28..57.28 rows=603 width=6)',),
#  ('              ->  Materialize  (cost=0.00..1.03 rows=2 width=6)',),
#  ('                    ->  Seq Scan on store s  (cost=0.00..1.02 rows=2 width=6)',),
#  ('        ->  Materialize  (cost=0.00..69.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=19)',),
#  ('        SubPlan 1',),
#  ('          ->  Nested Loop  (cost=4.59..184.09 rows=9 width=0)',),
#  ('                Join Filter: (r.staff_id = st.staff_id)',),
#  ('                ->  Seq Scan on staff st  (cost=0.00..1.02 rows=1 width=4)',),
#  ('                      Filter: (store_id = s.store_id)',),
#  ('                ->  Nested Loop  (cost=4.59..182.84 rows=18 width=2)',),
#  ('                      ->  Nested Loop  (cost=0.28..90.61 rows=5 width=4)',),
#  ('                            ->  Index Only Scan using film_pkey on film f2  (cost=0.28..8.29 rows=1 width=0)',),
#  ('                                  Index Cond: (film_id = f.film_id)',),
#  ('                            ->  Seq Scan on inventory i  (cost=0.00..82.26 rows=5 width=4)',),
#  ('                                  Filter: (film_id = f.film_id)',),
#  ('                      ->  Bitmap Heap Scan on rental r  (cost=4.32..18.41 rows=4 width=6)',),
#  ('                            Recheck Cond: (inventory_id = i.inventory_id)',),
#  ('                            Filter: (rental_date IS NOT NULL)',),
#  ('                            ->  Bitmap Index Scan on idx_fk_inventory_id  (cost=0.00..4.32 rows=4 width=0)',),
#  ('                                  Index Cond: (inventory_id = i.inventory_id)',),
#  ('  ->  Index Scan using city_pkey on city c  (cost=0.28..33.27 rows=600 width=13)',)]

# %%
# %%sql
# SELECT  c.city, s.store_id, f.title
# FROM    store AS s JOIN address AS a
#         ON s.address_id = a.address_id
#         JOIN city AS c
#         ON a.city_id = c.city_id
#         CROSS JOIN film AS f
# WHERE   NOT EXISTS (
#             SELECT  'x'
#             FROM    film AS f2 JOIN inventory AS i
#                     ON f.film_id = i.film_id
#                     JOIN rental AS r
#                     ON i.inventory_id = r.inventory_id
#                     JOIN staff AS st
#                     ON st.staff_id = r.staff_id
#             WHERE   rental_date IS NOT NULL
#                     AND f2.film_id = f.film_id
#                     AND st.store_id = s.store_id
#         );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 88 rows affected.
# [('Lethbridge', 1, 'Alice Fantasia'),
#  ('Lethbridge', 1, 'Apollo Teen'),
#  ('Lethbridge', 1, 'Argonauts Town'),
#  ('Lethbridge', 1, 'Ark Ridgemont'),
#  ('Lethbridge', 1, 'Arsenic Independence'),
#  ('Lethbridge', 1, 'Boondock Ballroom'),
#  ('Lethbridge', 1, 'Butch Panther'),
#  ('Lethbridge', 1, 'Catch Amistad'),
#  ('Lethbridge', 1, 'Chinatown Gladiator'),
#  ('Lethbridge', 1, 'Chocolate Duck'),
#  ('Lethbridge', 1, 'Commandments Express'),
#  ('Lethbridge', 1, 'Crossing Divorce'),
#  ('Lethbridge', 1, 'Crowds Telemark'),
#  ('Lethbridge', 1, 'Crystal Breaking'),
#  ('Lethbridge', 1, 'Dazed Punk'),
#  ('Lethbridge', 1, 'Deliverance Mulholland'),
#  ('Lethbridge', 1, 'Firehouse Vietnam'),
#  ('Lethbridge', 1, 'Floats Garden'),
#  ('Lethbridge', 1, 'Frankenstein Stranger'),
#  ('Lethbridge', 1, 'Gladiator Westward'),
#  ('Lethbridge', 1, 'Gump Date'),
#  ('Lethbridge', 1, 'Hate Handicap'),
#  ('Lethbridge', 1, 'Hocus Frida'),
#  ('Lethbridge', 1, 'Kentuckian Giant'),
#  ('Lethbridge', 1, 'Kill Brotherhood'),
#  ('Lethbridge', 1, 'License Weekend'),
#  ('Lethbridge', 1, 'Muppet Mile'),
#  ('Lethbridge', 1, 'Order Betrayed'),
#  ('Lethbridge', 1, 'Pearl Destiny'),
#  ('Lethbridge', 1, 'Perdition Fargo'),
#  ('Lethbridge', 1, 'Psycho Shrunk'),
#  ('Lethbridge', 1, 'Raiders Antitrust'),
#  ('Lethbridge', 1, 'Rainbow Shock'),
#  ('Lethbridge', 1, 'Roof Champion'),
#  ('Lethbridge', 1, 'Sister Freddy'),
#  ('Lethbridge', 1, 'Sky Miracle'),
#  ('Lethbridge', 1, 'Suicides Silence'),
#  ('Lethbridge', 1, 'Tadpole Park'),
#  ('Lethbridge', 1, 'Train Bunch'),
#  ('Lethbridge', 1, 'Treasure Command'),
#  ('Lethbridge', 1, 'Villain Desperate'),
#  ('Lethbridge', 1, 'Volume House'),
#  ('Lethbridge', 1, 'Wake Jaws'),
#  ('Lethbridge', 1, 'Walls Artist'),
#  ('Woodridge', 2, 'Alice Fantasia'),
#  ('Woodridge', 2, 'Apollo Teen'),
#  ('Woodridge', 2, 'Argonauts Town'),
#  ('Woodridge', 2, 'Ark Ridgemont'),
#  ('Woodridge', 2, 'Arsenic Independence'),
#  ('Woodridge', 2, 'Boondock Ballroom'),
#  ('Woodridge', 2, 'Butch Panther'),
#  ('Woodridge', 2, 'Cassidy Wyoming'),
#  ('Woodridge', 2, 'Catch Amistad'),
#  ('Woodridge', 2, 'Chinatown Gladiator'),
#  ('Woodridge', 2, 'Chocolate Duck'),
#  ('Woodridge', 2, 'Commandments Express'),
#  ('Woodridge', 2, 'Crossing Divorce'),
#  ('Woodridge', 2, 'Crowds Telemark'),
#  ('Woodridge', 2, 'Crystal Breaking'),
#  ('Woodridge', 2, 'Dazed Punk'),
#  ('Woodridge', 2, 'Deliverance Mulholland'),
#  ('Woodridge', 2, 'Firehouse Vietnam'),
#  ('Woodridge', 2, 'Floats Garden'),
#  ('Woodridge', 2, 'Frankenstein Stranger'),
#  ('Woodridge', 2, 'Gladiator Westward'),
#  ('Woodridge', 2, 'Gump Date'),
#  ('Woodridge', 2, 'Hate Handicap'),
#  ('Woodridge', 2, 'Hocus Frida'),
#  ('Woodridge', 2, 'Kentuckian Giant'),
#  ('Woodridge', 2, 'Kill Brotherhood'),
#  ('Woodridge', 2, 'Muppet Mile'),
#  ('Woodridge', 2, 'Order Betrayed'),
#  ('Woodridge', 2, 'Pearl Destiny'),
#  ('Woodridge', 2, 'Perdition Fargo'),
#  ('Woodridge', 2, 'Psycho Shrunk'),
#  ('Woodridge', 2, 'Raiders Antitrust'),
#  ('Woodridge', 2, 'Rainbow Shock'),
#  ('Woodridge', 2, 'Roof Champion'),
#  ('Woodridge', 2, 'Sister Freddy'),
#  ('Woodridge', 2, 'Sky Miracle'),
#  ('Woodridge', 2, 'Suicides Silence'),
#  ('Woodridge', 2, 'Tadpole Park'),
#  ('Woodridge', 2, 'Terminator Club'),
#  ('Woodridge', 2, 'Treasure Command'),
#  ('Woodridge', 2, 'Villain Desperate'),
#  ('Woodridge', 2, 'Volume House'),
#  ('Woodridge', 2, 'Wake Jaws'),
#  ('Woodridge', 2, 'Walls Artist')]

# %% [markdown]
# #### Helpful Hints
#   1. For the first hint watch only the first 5:57 of the video where the conceptual aspects of the task are discussed.
#   1. Then attempt to construct SQL based on the video explanation of the concept.
#   1. If you get stuck again, the remainder of the video after that looks directly at the SQL construction.
#
# [Helpful Hints](https://youtu.be/GyMODTEDfu4)

# %% [markdown]
# # Save your Notebook, then `File > Close and Halt`
