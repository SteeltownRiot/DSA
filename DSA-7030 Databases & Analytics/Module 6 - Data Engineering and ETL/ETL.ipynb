# %% [markdown]
# # Extraction, Transform, and Load
#
# ETL is a common necessity for data engineering and data processing pipelines.
# The source of the data may be other structured databases, unstructured data stores, data APIs, etc.
#
# ETL can be a simple data acquisition task, such as shown below.

# %% [markdown]
# ![AutomatedDataAcquisition.png MISSING](../images/AutomatedDataAcquisition.png)

# %% [markdown]
# **Or, it may be part of larger process to accumulated data and information in support of advanced analytical systems.**
#
# ![AutomatedDataAcquisition_to_Analytics.png MISSING](../images/AutomatedDataAcquisition_to_Analytics.png)

# %% [markdown]
# ---
#
# ## In the context of ETL, you now have the tools to perform this activity.
#
# In the data loading lab, you read in three data files and then massaged the Panda data frame to prepare the data for loading and to understand the semantics of the data.
# You then loaded the database with data from the files.
#
# We just need to understand how to acquire data from a remote resource, such as the web or an API and process it with Pandas.
#
# Additionally, in this notebook we will see how to use the SQLAlchemy library to simplify data loading.
#
# ## Tasks:
#
#  **Consider**:
#  + https://en.wikipedia.org/wiki/Land_use_statistics_by_country
#
# In the cells below,
#
#  1. Define a table for information about the worlds countries.
#  1. Describe some challenges you foresee with the data
#  1. Review and modify code cells that pull down the data from the tables into a data frame
#  1. Load the data into your database
#  1. Test loaded data with SQL queries

# %% [markdown]
# ### 1. Define Tables

# %% [raw]
# CREATE TABLE jch5x8.land_use_statistics (
#     country              varchar(100), -- Character String, varied length
#     rank                 INT NOT NULL, -- Integer
#     cultivated_land_k    INT NOT NULL,
#     cultivated_land_p    REAL NOT NULL, -- Floating point number
#     arable_land_k        INT NOT NULL,
#     arable_land_p        REAL NOT NULL,
#     permanent_crops_k    INT NOT NULL,
#     permanent_crops_p    REAL NOT NULL,
#     other_land_k         REAL NOT NULL,
#     other_land_p         REAL NOT NULL,
#     total_area           REAL NOT NULL,
#     date_yr              INT NOT NULL,
#     CONSTRAINT pk_land_use_statistics
#      PRIMARY KEY (country)
# );

# %% [markdown]
# ### 2. Describe the challenges

# %% [raw]
# ## Add your answer in this cell
# ## ----------------------------
#
# Rank has — listed where there is a tie

# %% [markdown]
# ### 3. Data Scrapping Code

# %%
#import the library to query a website
import requests
# import Beautiful soup library to access functions to parse the data returned from the website
from bs4 import BeautifulSoup

# %%
# specify the url
url = "https://en.wikipedia.org/wiki/Land_use_statistics_by_country"
# Open website URL and return the html to the variable 'response'
response = requests.get(url)
print(response.encoding)
print(response)
# Out:
# UTF-8
# <Response [200]>

# %% [markdown]
# The response we get from web is typically html content.
# We can read the content of the server's response.
# Below, when a `BeautifulSoup` object is created from an html response, we explicitly reference the text format(`response.text`).
#
# The default encoding format is 'UTF-8' as shown below.
#
# [Click here for additional documentations about the response object.](http://docs.python-requests.org/en/master/user/quickstart/#response-content)

# %%
# Parse the html in the 'response' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(response.text, "html")

# %% [markdown]
# #####  Basic Inspection
# Use `prettify` function to print the data in its nested html structured format.

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Land use statistics by country - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"3171f8f5-b2af-4a7a-9afc-35bc955818d6","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Land_use_statistics_by_country","wgTitle":"Land use statistics by country","wgCurRevisionId":1043349551,"wgRevisionId":1043349551,"wgArticleId":20860130,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Agricultural land","Lists by country"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Land_use_statistics_by_country","wgRelevantArticleId":20860130,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,
# "wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":-1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgNoticeProject":"wikipedia","wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q3231439","wgGENewcomerTasksGuidanceEnabled":true,"wgGEAskQuestionEnabled":false,"wgGELinkRecommendationsFrontendEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready",
# "jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.centralauth.centralautologin","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <meta content="MediaWiki 1.38.0-wmf.9" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Land use statistics by country - Wikipedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/Land_use_statistics_by_country" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/w/index.php?title=Land_use_statistics_by_country&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="https://en.wikipedia.org/wiki/Land_use_statistics_by_country" rel="canonical"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Land_use_statistics_by_country rootpage-Land_use_statistics_by_country skin-vector action-view skin-vector-legacy"><div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators">
# </div>
# <h1 class="firstHeading" id="firstHeading">Land use statistics by country</h1>
# <div class="vector-body" id="bodyContent">
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><p>This article includes the table with <b><a href="/wiki/Land_use" title="Land use">land use</a> statistics by country</b>. Countries are ranked by their total cultivated land area, which is the sum of the total <a href="/wiki/Arable_land" title="Arable land">arable land</a> area and total area of <a href="/wiki/Permanent_crop" title="Permanent crop">permanent crops</a>.
# </p><p>Arable land is defined as being cultivated for crops like <a href="/wiki/Wheat" title="Wheat">wheat</a>, <a href="/wiki/Maize" title="Maize">maize</a>, and <a href="/wiki/Rice" title="Rice">rice</a>, all of which are replanted after each harvest.  Permanent cropland is defined as being cultivated for crops like <a href="/wiki/Citrus" title="Citrus">citrus</a>, <a href="/wiki/Coffee" title="Coffee">coffee</a>, and <a class="mw-redirect" href="/wiki/Rubber" title="Rubber">rubber</a>, which are not replanted after each harvest; this also includes land under <a class="mw-redirect" href="/wiki/Flowering" title="Flowering">flowering</a> shrubs, <a href="/wiki/Fruit_tree" title="Fruit tree">fruit trees</a>, <a href="/wiki/Nut_(fruit)" title="Nut (fruit)">nut</a> trees, and <a href="/wiki/Vine" title="Vine">vines</a>, but excludes land under trees grown for <a href="/wiki/Wood" title="Wood">wood</a> or <a class="mw-redirect" href="/wiki/Timber" title="Timber">timber</a>. Other lands include any lands not arable nor under permanent crops; this includes permanent <a href="/wiki/Meadow" title="Meadow">meadows</a> and <a href="/wiki/Pasture" title="Pasture">pastures</a>, <a href="/wiki/Forest" title="Forest">forests</a> and <a href="/wiki/Woodland" title="Woodland">woodlands</a>, <a href="/wiki/Urban_area" title="Urban area">built-on areas</a>, <a href="/wiki/Road" title="Road">roads</a>, <a href="/wiki/Barren_vegetation" title="Barren vegetation">barren land</a>, and so on.
# </p><p>Percentage figures for arable land, permanent crops land and other lands are all taken from the <a href="/wiki/The_World_Factbook" title="The World Factbook">CIA World Factbook</a><sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> as well as total land area figures<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> (Note: the total area of a country is defined as the sum of total land area and total water area together.)  All other figures, including total cultivated land area, are calculated on the basis of this mentioned dataset.
# </p>
# <table class="sortable wikitable">
# <tbody><tr bgcolor="#ececec" valign="top">
# <th data-sort-type="number">Rank</th>
# <th>Country</th>
# <th>Cultivated <br/> land <br/> (km<sup>2</sup>)</th>
# <th>Cultivated <br/> land <br/> (%)</th>
# <th>Arable <br/> land <br/> (km<sup>2</sup>)</th>
# <th>Arable <br/> land <br/> (%)</th>
# <th>Permanent <br/> crops <br/> (km<sup>2</sup>)</th>
# <th>Permanent <br/> crops <br/> (%)</th>
# <th>Other <br/> lands <br/> (km<sup>2</sup>)</th>
# <th>Other <br/> lands <br/> (%)</th>
E0%AE%9F%E0%AF%8D%E0%AE%9F%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D" hreflang="ta" lang="ta" title="நிலப்பாவனை புள்ளிவிபர அடிப்படையில் நாடுகளின் பட்டியல் – Tamil"><span>தமிழ்</span></a></li><li class="interlanguage-link interwiki-uk mw-list-item"><a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BA%D1%80%D0%B0%D1%97%D0%BD_%D0%B7%D0%B0_%D0%B2%D0%B8%D0%BA%D0%BE%D1%80%D0%B8%D1%81%D1%82%D0%B0%D0%BD%D0%BD%D1%8F%D0%BC_%D0%B7%D0%B5%D0%BC%D0%BB%D1%96" hreflang="uk" lang="uk" title="Список країн за використанням землі – Ukrainian"><span>Українська</span></a></li><li class="interlanguage-link interwiki-ur mw-list-item"><a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D8%B4%D9%85%D8%A7%D8%B1%DB%8C%D8%A7%D8%AA_%D8%A7%D8%B3%D8%AA%D8%B9%D9%85%D8%A7%D9%84_%D8%B2%D9%85%DB%8C%D9%86_%D8%A8%D9%84%D8%AD%D8%A7%D8%B8_%D9%85%D9%84%DA%A9" hreflang="ur" lang="ur" title="شماریات استعمال زمین بلحاظ ملک – Urdu"><span>اردو</span></a></li><li class="interlanguage-link interwiki-ug mw-list-item"><a class="interlanguage-link-target" href="https://ug.wikipedia.org/wiki/%D8%AF%DB%87%D9%86%D9%8A%D8%A7_%D8%AA%DB%90%D8%B1%D9%89%D9%84%D8%BA%DB%87_%D9%8A%DB%95%D8%B1_%D8%B3%D9%89%D8%AA%D8%A7%D8%B3%D8%AA%D9%89%D9%83%D9%89%D8%B3%D9%89" hreflang="ug"  ...
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q3231439#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </nav>
# </div>
# </div>
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 9 September 2021, at 16:58<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Land_use_statistics_by_country&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# <li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"1.269","walltime":"1.836","ppvisitednodes":{"value":17231,"limit":1000000},"postexpandincludesize":{"value":109515,"limit":2097152},"templateargumentsize":{"value":32320,"limit":2097152},"expansiondepth":{"value":9,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":3138,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00% 1059.949      1 -total"," 88.87%  941.962    236 Template:Flag"," 16.15%  171.197    236 Template:Flag/core","  4.56%   48.303      1 Template:Reflist","  4.10%   43.405      1 Template:Agriculture_country_lists","  3.80%   40.319      1 Template:Navbox","  1.36%   14.388      1 Template:Country_data_Qatar","  1.21%   12.852      1 Template:Country_data_Isle_of_Man","  1.11%   11.753      1 Template:Country_data_Armenia","  0.91%    9.650      1 Template:Country_data_Sweden"]},"scribunto":{"limitreport-timeusage":{"value":"0.028","limit":"10.000"},"limitreport-memusage":{"value":825770,"limit":52428800}},"cachereport":{"origin":"mw1384","timestamp":"20211120161434","ttl":1814400,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Land use statistics by country","url":"https:\/\/en.wikipedia.org\/wiki\/Land_use_statistics_by_country","sameAs":"http:\/\/www.wikidata.org\/entity\/Q3231439","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q3231439","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2008-12-28T00:48:11Z","dateModified":"2021-09-09T16:58:40Z","headline":"Wikimedia list article"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":148,"wgHostname":"mw1365"});});</script>
# </body>
# </html>>

# %% [markdown]
# We need to extract the table which has list of all baseball world series champions.
#
# This table should be present in one of the html tags.
#
# We can work with the tags to extract data present in them.
# "**soup.tag**": will return the content between opening and closing tag including tag.
#
# Additionally, the `.string` value is the data between the tags.
# Compare the two cells below.

# %%
print(soup.title)
print(soup.title.string)
# Out:
# <title>Land use statistics by country - Wikipedia</title>
# Land use statistics by country - Wikipedia

# %% [markdown]
# **Identify the html tag**:
# The data is in a table.
# You can use inspect element option when you right click the mouse to identify the tag which has the data.
#
#  * [Additional guide on webpage inspection](../resources/AnalyzingHTMLwithTheWebInspector.pdf)
#
#
# <img src="../images/Wikipedia_Inspect_Screen.png">
#
# **If we look at the inspected HTML source for the table,**
# abbreviated here to focus on the top two rows of data.

# %% [markdown]
# ```HTML
# <table class="sortable wikitable jquery-tablesorter">
#
#  <thead>
#      <tr bgcolor="#ececec" valign="top">
#          <th data-sort-type="number" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Rank</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Country</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Cultivated <br> land <br> (km<sup>2</sup>)</th>
# <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Cultivated <br> land <br> (%)</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Arable <br> land <br> (km<sup>2</sup>)</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Arable <br> land <br> (%)</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Permanent <br> crops <br> (km<sup>2</sup>)</th>
# <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Permanent <br> crops <br> (%)</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Other <br> lands <br> (km<sup>2</sup>)</th>
# <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Other <br> lands <br> (%)</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Total <br> area <br> (km<sup>2</sup>)</th>
#          <th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Date
# </th>
#      </tr>
#  </thead>
#  <tbody>
# <tr>
#     <td>—</td>
#     <td><span class="flagicon" style="padding-left:25px;">&nbsp;</span><b><a href="/wiki/World" title="World">World</a></b></td>
#     <td>17,235,800</td>
#     <td>11.6</td>
#     <td>15,749,300</td>
#     <td>10.6</td>
#     <td>1,549,600</td>
#     <td>1</td>
#     <td>131.701.100</td>
#     <td>88.4</td>
#     <td>149,000,000</td>
#     <td>2011
#     </td>
# </tr>
# <tr>
#     <td>1</td>
#     <td><span class="flagicon"><img alt="" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" data-file-width="1350" data-file-height="900">&nbsp;</span><a href="/wiki/India" title="India">India</a></td>
#     <td>1,891,761</td>
#     <td>57</td>
#     <td>1,753,694</td>
#     <td>52.8</td>
#     <td>138,067</td>
#     <td>4.2</td>
#     <td>1,395,502</td>
#     <td>43</td>
#     <td>3,287,263</td>
#     <td>2011
#     </td>
# </tr>
# <tr>
#     <td>2</td>
#     <td><span class="flagicon"><img alt="" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650">&nbsp;</span><a href="/wiki/United_States" title="United States">United States</a></td>
#     <td>1,681,826</td>
#     <td>17.1</td>
#     <td>1,652,028</td>
#     <td>16.8</td>
#     <td>29,798</td>
#     <td>0.3</td>
#     <td>8,151,691</td>
#     <td>82.9</td>
#     <td>9,833,517</td>
#     <td>2011
#     </td>
# </tr>
# <tr>
# ...
# </tr></tbody><tfoot></tfoot></table>
# ```

# %% [markdown]
# We see that the table tag has class settings of:
#  * sortable
#  * wikitable
#  * jquery-tablesorter
#
# ```HTML
# <table class="sortable wikitable jquery-tablesorter">
# ```
#
# We want to focus on the `wikitable`.

# %%
# We can fetch all Tables with a find_all() 
all_tables=soup.find_all('table')
print(type(all_tables))
print(len(all_tables))


# We can find the first (only) occurrence 
right_table=soup.find('table', class_='wikitable')
print(type(right_table))
# Out:
# <class 'bs4.element.ResultSet'>
# 2
# <class 'bs4.element.Tag'>

# %% [markdown]
# The `Tag` element is the table.
#
# **Examining the HTML Table Header, we have these columns**
#
#  * Rank
#  * Country
#  * Cultivated Land km^2
#  * Cultivated Land %
#  * Arable Land km^2
#  * Arable Land %
#  * Permanent Crops km^2
#  * Permanent Crops %
#  * Other lands km^2
#  * Other lands %
#  * Total Area
#  * Date
#
# Therefore, a simple approach is to iterate through the HTML table rows, the `<tr>...</tr>` and process the data elements.
#
# Reviewing the HTML above, we see we need to skip the headers and the "World" row.
#
# Additionally, we will stop when we get out of the ranked rows, that is when Rank is not a number.

# %%
# We will use the locale library so we can use 
# atof and atoi to convert alphanumeric to float and integers, respectively.
import locale
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' ) 

rank=[]
country=[]
cultivated_land_k=[]
cultivated_land_p=[]
arable_land_k=[]
arable_land_p=[]
permanent_crops_k=[]
permanent_crops_p=[]
other_land_k=[]
other_land_p=[]
total_area=[]
date_yr=[]


# skip first iteration as we dont need headers
for row in right_table.findAll("tr")[1:]: 
    # for each row, pull out the td elements.
    cells = row.findAll('td') # To store all other details
    
    if len(cells)>2: # Only extract information if there is table body not heading
        
        
        this_rank = cells[0].find(text=True)
        print("Processing rank {}".format(this_rank))
        
        # If the rank is a number, we can convert it
        if (not this_rank.isnumeric()):
            print("Non-Ranked, skipping")
            continue
        
        rank.append(locale.atoi(this_rank))
        
        # for the country name, we need to find the name (text) in the Country Hyperlink (a)
        countr_cell = cells[1].find('a').find(text=True)
        print(countr_cell)
        
        country.append(countr_cell)
        
        # Adjust the the data from Text to numeric data types
        cultivated_land_k.append(locale.atoi(cells[2].find(text=True)))
        cultivated_land_p.append(locale.atof(cells[3].find(text=True)))
        
        arable_land_k.append(locale.atoi(cells[4].find(text=True)))
        arable_land_p.append(locale.atof(cells[5].find(text=True)))
        
        permanent_crops_k.append(locale.atoi(cells[6].find(text=True)))
        permanent_crops_p.append(locale.atof(cells[7].find(text=True)))
        
        # Note, that this is to float because the vatican row has a non-int value
        other_land_k.append(locale.atof(cells[8].find(text=True)))
        other_land_p.append(locale.atof(cells[9].find(text=True)))
        
        total_area.append(locale.atof(cells[10].find(text=True)))
        date_yr.append(locale.atoi(cells[11].find(text=True)))
# Out:
# Processing rank —
# Non-Ranked, skipping
# Processing rank 1
# India
# Processing rank 2
# United States
# Processing rank 3
# Russia
# Processing rank 4
# China
# Processing rank 5
# Brazil
# Processing rank 6
# Canada
# Processing rank 7
# Australia
# Processing rank 8
# Indonesia
# Processing rank 9
# Nigeria
# Processing rank 10
# Argentina
# Processing rank 11
# Ukraine
# Processing rank 12
# Sudan
# Processing rank 13
# Mexico
# Processing rank 14
# Kazakhstan
# Processing rank 15
# Turkey
# Processing rank 16
# Pakistan
# Processing rank 17
# France
# Processing rank 18
# Thailand
# Processing rank 19
# Iran
# Processing rank 20
# Ethiopia
# Processing rank 21
# Spain
# Processing rank 22
# Tanzania
# Processing rank 23
# Niger
# Processing rank 24
# Myanmar (Burma)
# Processing rank 25
# South Africa
# Processing rank 26
# Germany
# Processing rank 27
# Poland
# Processing rank 28
# Uganda
# Processing rank 29
# Vietnam
# Processing rank 30
# Philippines
# Processing rank 31
# Romania
# Processing rank 32
# Bangladesh
# Processing rank 33
# Italy
# Processing rank 34
# Morocco
# Processing rank 35
# Algeria
# Processing rank 36
# Afghanistan
# Processing rank 37
# Cameroon
# Processing rank 38
# Cote d'Ivoire
# Processing rank 39
# Malaysia
# Processing rank 40
# Mali
# Processing rank 41
# Kenya
# Processing rank 42
# United Kingdom
# Processing rank 43
# Syria
# Processing rank 44
# Belarus
# Processing rank 45
# Paraguay
# Processing rank 46
# Tunisia
# Processing rank 47
# Peru
# Processing rank 48
# Mozambique
# Processing rank 49
# Chad
# Processing rank 50
# Uzbekistan
# Processing rank 51
# Japan
# Processing rank 52
# Hungary
# Processing rank 53
# Malawi
# Processing rank 54
# Ghana
# Processing rank 55
# Burkina Faso
# Processing rank 56
# Cambodia
# Processing rank 57
# Democratic Republic of the Congo
# Processing rank 58
# Bolivia
# Processing rank 59
# Cuba
# Processing rank 60
# Madagascar
# Processing rank 61
# Iraq
# Processing rank 62
# Greece
# Processing rank 63
# Zambia
# Processing rank 64
# Egypt
# Processing rank 65
# Angola
# Processing rank 66
# Guinea
# Processing rank 67
# Venezuela
# Processing rank 68
# Bulgaria
# Processing rank 69
# Senegal
# Processing rank 70
# Saudi Arabia
# Processing rank 71
# Colombia
# Processing rank 72
# Czech Republic
# Processing rank 73
# Serbia
# Processing rank 74
# Benin
# Processing rank 75
# Ecuador
# Processing rank 76
# North Korea
# Processing rank 77
# Sweden
# Processing rank 78
# Togo
# Processing rank 79
# Denmark
# Processing rank 80
# Guatemala
# Processing rank 81
# Finland
# Processing rank 82
# Nepal
# Processing rank 83
# Sri Lanka
# Processing rank 84
# Lithuania
# Processing rank 85
# Azerbaijan
# Processing rank 86
# Moldova
# Processing rank 87
# Kyrgyzstan
# Processing rank 88
# Libya
# Processing rank 89
# Turkmenistan
# Processing rank 90
# Nicaragua
# Processing rank 91
# Sierra Leone
# Processing rank 92
# Central African Republic
# Processing rank 93
# Uruguay
# Processing rank 94
# Portugal
# Processing rank 95
# South Korea
# Processing rank 96
# Yemen
# Processing rank 97
# Laos
# Processing rank 98
# Chile
# Processing rank 99
# Burundi
# Processing rank 100
# Rwanda
# Processing rank 101
# Honduras
# Processing rank 102
# Austria
# Processing rank 103
# Slovakia
# Processing rank 104
# Haiti
# Processing rank 105
# Dominican Republic
# Processing rank 106
# Netherlands
# Processing rank 107
# Latvia
# Processing rank 108
# Somalia
# Processing rank 109
# Bosnia and Herzegovina
# Processing rank 110
# Ireland
# Processing rank 111
# Papua New Guinea
# Processing rank 112
# Tajikistan
# Processing rank 113
# Croatia
# Processing rank 114
# El Salvador
# Processing rank 115
# Belgium
# Processing rank 116
# Namibia
# Processing rank 118
# Liberia
# Processing rank 119
# Eritrea
# Processing rank 120
# Panama
# Processing rank 121
# Albania
# Processing rank 122
# Norway
# Processing rank 123
# Estonia
# Processing rank 124
# Mongolia
# Processing rank 125
# Republic of the Congo
# Processing rank 126
# Costa Rica
# Processing rank 127
# New Zealand
# Processing rank 128
# Guinea-Bissau
# Processing rank 129
# Georgia
# Processing rank 130
# Armenia
# Processing rank 131
# Gabon
# Processing rank 132
# Guyana
# Processing rank 133
# Gambia
# Processing rank 134
# North Macedonia
# Processing rank 135
# Switzerland
# Processing rank 136
# Mauritania
# Processing rank 137
# Israel
# Processing rank 138
# Botswana
# Processing rank 139
# Lesotho
# Processing rank 140
# Jordan
# Processing rank 141
# Lebanon
# Processing rank 142
# Fiji
# Processing rank 143
# Jamaica
# Processing rank 144
# Timor-Leste
# Processing rank 145
# Palestine
# Processing rank 146
# Slovenia
# Processing rank 147
# Montenegro
# Processing rank 148
# Eswatini (Swaziland)
# Processing rank 149
# Equatorial Guinea
# Processing rank 150
# Comoros
# Processing rank —
# Non-Ranked, skipping
# Processing rank 151
# Vanuatu
# Processing rank 152
# Cyprus
# Processing rank 153
# Bhutan
# Processing rank 154
# Belize
# Processing rank 155
# Solomon Islands
# Processing rank 156
# United Arab Emirates
# Processing rank 157
# Mauritius
# Processing rank 158
# Suriname
# Processing rank 159
# Luxembourg
# Processing rank 160
# Oman
# Processing rank 161
# Cape Verde
# Processing rank 162
# São Tomé and Príncipe
# Processing rank 163
# Trinidad and Tobago
# Processing rank 164
# Kiribati
# Processing rank 165
# Micronesia
# Processing rank 166
# Samoa
# Processing rank —
# Non-Ranked, skipping
# Processing rank 167
# Tonga
# Processing rank 168
# Dominica
# Processing rank —
# Non-Ranked, skipping
# Processing rank 169
# Saint Lucia
# Processing rank 170
# Barbados
# Processing rank 171
# Kuwait
# Processing rank 172
# Brunei
# Processing rank 173
# Qatar
# Processing rank 174
# Saint Vincent and the Grenadines
# Processing rank 175
# Maldives
# Processing rank 176
# Grenada
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank 177
# Malta
# Processing rank 178
# Antigua and Barbuda
# Processing rank —
# Non-Ranked, skipping
# Processing rank 179
# Marshall Islands
# Processing rank —
# Non-Ranked, skipping
# Processing rank 180
# Bahamas
# Processing rank —
# Non-Ranked, skipping
# Processing rank 181
# Iceland
# Processing rank —
# Non-Ranked, skipping
# Processing rank 182
# Seychelles
# Processing rank 183
# Palau
# Processing rank —
# Non-Ranked, skipping
# Processing rank 184
# Saint Kitts and Nevis
# Processing rank 185
# Bahrain
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank 186
# Liechtenstein
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank 187
# Singapore
# Processing rank 188
# Tuvalu
# Processing rank —
# Non-Ranked, skipping
# Processing rank 189
# Andorra
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank 190
# San Marino
# Processing rank 191
# Djibouti
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank 192
# Nauru
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank —
# Non-Ranked, skipping
# Processing rank 193
# Monaco
# Processing rank 194
# Vatican City

# %% [markdown]
# ##### Now that we have built all our columns, stack into a data frame!

# %%
import pandas as pd

# Note, in the table definition about, we listed 
# the country name first to use as a primary key

df=pd.DataFrame({'country': country,
                'rank': rank,
                'cultivated_land_k': cultivated_land_k,
                'cultivated_land_p': cultivated_land_p,
                'arable_land_k': arable_land_k,
                'arable_land_p': arable_land_p,
                'permanent_crops_k': permanent_crops_k,
                'permanent_crops_p': permanent_crops_p,
                'other_land_k': other_land_k,
                'other_land_p': other_land_p,
                'total_area': total_area,
                'date_yr': date_yr
                })

# %%
df.head()
# Out:
#          country  rank  cultivated_land_k  cultivated_land_p  arable_land_k  \
# 0          India     1            1891761               57.0        1753694
# 1  United States     2            1681826               17.1        1652028
# 2         Russia     3            1265267                7.4        1248169
# 3          China     4            1238013               12.9        1084461
# 4         Brazil     5             800485                9.4         732359
#
#    arable_land_p  permanent_crops_k  permanent_crops_p  other_land_k  \
# 0           52.8             138067                4.2     1395502.0
# 1           16.8              29798                0.3     8151691.0
# 2            7.3              17098                0.1    15832975.0
# 3           11.3             153552                1.6     8358947.0
# 4            8.6              68126                0.8     7715285.0
#
#    other_land_p  total_area  date_yr
# 0          43.0   3287263.0     2011
# 1          82.9   9833517.0     2011
# 2          92.6  17098242.0     2011
# 3          87.1   9596960.0     2011
# 4          90.6   8515770.0     2011

# %%
df.tail()
# Out:
#           country  rank  cultivated_land_k  cultivated_land_p  arable_land_k  \
# 188    San Marino   190                 10              16.67             10
# 189      Djibouti   191                  9               0.04              9
# 190         Nauru   192                  0               0.00              0
# 191        Monaco   193                  0               0.00              0
# 192  Vatican City   194                  0               0.00              0
#
#      arable_land_p  permanent_crops_k  permanent_crops_p  other_land_k  \
# 188          16.67                  0                0.0         51.00
# 189           0.04                  0                0.0      22971.00
# 190           0.00                  0                0.0         21.00
# 191           0.00                  0                0.0          2.00
# 192           0.00                  0                0.0          0.44
#
#      other_land_p  total_area  date_yr
# 188         83.33       61.00     2005
# 189         99.96    22980.00     2005
# 190        100.00       21.00     2005
# 191        100.00        2.00     2005
# 192        100.00        0.44     2005

# %% [markdown]
# ### Check our column data types!
# Does this match the data types we sketched out in the `CREATE TABLE` statement above?
# If you need to adjust the definition, this would be the time.
# Alternatively, we can adjust the columns using Pandas techniques.

# %%
df.dtypes
# Out:
# country               object
# rank                   int64
# cultivated_land_k      int64
# cultivated_land_p    float64
# arable_land_k          int64
# arable_land_p        float64
# permanent_crops_k      int64
# permanent_crops_p    float64
# other_land_k         float64
# other_land_p         float64
# total_area           float64
# date_yr                int64
# dtype: object

# %% [markdown]
# Once we have our Panda data frame and the SQL table inline, we can load it into the database.
#
# ---

# %% [markdown]
# ### 4. Load the data into your database
#
# This time, instead of the manual loading, we are going to use the SQLAlchemy library.

# %%
import getpass
mypasswd = getpass.getpass()
username = 'jch5x8'
host = 'pgsql.dsa.lan'
database = 'dsa_student'
# Out:
# ········

# %%
# Then connects to the DB
from sqlalchemy.engine.url import URL
from sqlalchemy import create_engine

# SQLAlchemy Connection Parameters
postgres_db = {'drivername': 'postgres',
               'username': username,
               'password': mypasswd,
               'host': host,
               'database' :database}
engine = create_engine(URL(**postgres_db), echo=True)
del mypasswd

# %% [markdown]
# #### When you run the cell below, carefully examine the output so you see what the SQLAlchemy library is doing!

# %%
## Now that SQLAlchemy is loaded, the to_sql function
df.to_sql('land_use_statistics', # The table to load
          engine,             # The engine created above
          schema= username,   # The schema where the table lives, our pawprint
          if_exists='append', # If the table is found, it would keep loading the end of table.
          index=False,        # Recall that panda data frame has a row index, so we need to ignore it
          chunksize=20)       # Do 20 records from the data frame at a time
# Out:
# 2021-11-22 12:33:23,284 INFO sqlalchemy.engine.base.Engine select version()
# 2021-11-22 12:33:23,285 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:33:23,288 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2021-11-22 12:33:23,288 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:33:23,290 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-11-22 12:33:23,291 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:33:23,293 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-11-22 12:33:23,293 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:33:23,294 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2021-11-22 12:33:23,295 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:33:23,296 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where n.nspname=%(schema)s and relname=%(name)s
# 2021-11-22 12:33:23,297 INFO sqlalchemy.engine.base.Engine {'schema': 'jch5x8', 'name': 'land_use_statistics'}
# 2021-11-22 12:33:23,301 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE jch5x8.land_use_statistics (
# 	country TEXT,
# 	rank BIGINT,
# 	cultivated_land_k BIGINT,
# 	cultivated_land_p FLOAT(53),
# 	arable_land_k BIGINT,
# 	arable_land_p FLOAT(53),
# 	permanent_crops_k BIGINT,
# 	permanent_crops_p FLOAT(53),
# 	other_land_k FLOAT(53),
# 	other_land_p FLOAT(53),
# 	total_area FLOAT(53),
# 	date_yr BIGINT
# )
#
#
# 2021-11-22 12:33:23,301 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:33:23,312 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-11-22 12:33:23,316 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-11-22 12:33:23,317 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,318 INFO sqlalchemy.engine.base.Engine ({'country': 'India', 'rank': 1, 'cultivated_land_k': 1891761, 'cultivated_land_p': 57.0, 'arable_land_k': 1753694, 'arable_land_p': 52.8, 'permanent_crops_k': 138067, 'permanent_crops_p': 4.2, 'other_land_k': 1395502.0, 'other_land_p': 43.0, 'total_area': 3287263.0, 'date_yr': 2011}, {'country': 'United States', 'rank': 2, 'cultivated_land_k': 1681826, 'cultivated_land_p': 17.1, 'arable_land_k': 1652028, 'arable_land_p': 16.8, 'permanent_crops_k': 29798, 'permanent_crops_p': 0.3, 'other_land_k': 8151691.0, 'other_land_p': 82.9, 'total_area': 9833517.0, 'date_yr': 2011}, {'country': 'Russia', 'rank': 3, 'cultivated_land_k': 1265267, 'cultivated_land_p': 7.4, 'arable_land_k': 1248169, 'arable_land_p': 7.3, 'permanent_crops_k': 17098, 'permanent_crops_p': 0.1, 'other_land_k': 15832975.0, 'other_land_p': 92.6, 'total_area': 17098242.0, 'date_yr': 2011}, {'country': 'China', 'rank': 4, 'cultivated_land_k': 1238013, 'cultivated_land_p': 12.9, 'arable_land_k': 1084461, 'arable_land_p': 11.3, 'permanent_crops_k': 153552, 'permanent_crops_p': 1.6, 'other_land_k': 8358947.0, 'other_land_p': 87.1, 'total_area': 9596960.0, 'date_yr': 2011}, {'country': 'Brazil', 'rank': 5, 'cultivated_land_k': 800485, 'cultivated_land_p': 9.4, 'arable_land_k': 732359, 'arable_land_p': 8.6, 'permanent_crops_k': 68126, 'permanent_crops_p': 0.8, 'other_land_k': 7715285.0, 'other_land_p': 90.6, 'total_area': 8515770.0, 'date_yr': 2011}, {'country': 'Canada', 'rank': 6, 'cultivated_land_k': 519205, 'cultivated_land_p': 5.2, 'arable_land_k': 469281, 'arable_land_p': 4.7, 'permanent_crops_k': 49924, 'permanent_crops_p': 0.5, 'other_land_k': 9465465.0, 'other_land_p': 94.8, 'total_area': 9984670.0, 'date_yr': 2011}, {'country': 'Australia', 'rank': 7, 'cultivated_land_k': 487695, 'cultivated_land_p': 6.3, 'arable_land_k': 479954, 'arable_land_p': 6.2, 'permanent_crops_k': 7741, 'permanent_crops_p': 0.1, 'other_land_k': 7253525.0, 'other_land_p': 93.7, 'total_area': 7741220.0, 'date_yr': 2011}, {'country': 'Indonesia', 'rank': 8, 'cultivated_land_k': 478055, 'cultivated_land_p': 25.1, 'arable_land_k': 247598, 'arable_land_p': 13.0, 'permanent_crops_k': 230457, 'permanent_crops_p': 12.1, 'other_land_k': 1426514.0, 'other_land_p': 74.9, 'total_area': 1904569.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Iran', 'rank': 19, 'cultivated_land_k': 197794, 'cultivated_land_p': 12.0, 'arable_land_k': 178006, 'arable_land_p': 10.8, 'permanent_crops_k': 19788, 'permanent_crops_p': 1.2, 'other_land_k': 1450401.0, 'other_land_p': 88.0, 'total_area': 1648195.0, 'date_yr': 2011}, {'country': 'Ethiopia', 'rank': 20, 'cultivated_land_k': 180001, 'cultivated_land_p': 16.3, 'arable_land_k': 167854, 'arable_land_p': 15.2, 'permanent_crops_k': 12147, 'permanent_crops_p': 1.1, 'other_land_k': 924299.0, 'other_land_p': 83.7, 'total_area': 1104300.0, 'date_yr': 2011})
# 2021-11-22 12:33:23,328 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,329 INFO sqlalchemy.engine.base.Engine ({'country': 'Spain', 'rank': 21, 'cultivated_land_k': 171836, 'cultivated_land_p': 34.0, 'arable_land_k': 125845, 'arable_land_p': 24.9, 'permanent_crops_k': 45991, 'permanent_crops_p': 9.1, 'other_land_k': 333534.0, 'other_land_p': 66.0, 'total_area': 505370.0, 'date_yr': 2011}, {'country': 'Tanzania', 'rank': 22, 'cultivated_land_k': 157252, 'cultivated_land_p': 16.6, 'arable_land_k': 135464, 'arable_land_p': 14.3, 'permanent_crops_k': 21788, 'permanent_crops_p': 2.3, 'other_land_k': 790048.0, 'other_land_p': 83.4, 'total_area': 947300.0, 'date_yr': 2011}, {'country': 'Niger', 'rank': 23, 'cultivated_land_k': 155968, 'cultivated_land_p': 12.4, 'arable_land_k': 155841, 'arable_land_p': 12.3, 'permanent_crops_k': 127, 'permanent_crops_p': 0.1, 'other_land_k': 1111032.0, 'other_land_p': 87.6, 'total_area': 1267000.0, 'date_yr': 2011}, {'country': 'Myanmar (Burma)', 'rank': 24, 'cultivated_land_k': 126524, 'cultivated_land_p': 18.7, 'arable_land_k': 111639, 'arable_land_p': 16.5, 'permanent_crops_k': 14885, 'permanent_crops_p': 2.2, 'other_land_k': 550054.0, 'other_land_p': 81.3, 'total_area': 676578.0, 'date_yr': 2011}, {'country': 'South Africa', 'rank': 25, 'cultivated_land_k': 124338, 'cultivated_land_p': 10.2, 'arable_land_k': 120691, 'arable_land_p': 9.9, 'permanent_crops_k': 3647, 'permanent_crops_p': 0.3, 'other_land_k': 1094752.0, 'other_land_p': 89.8, 'total_area': 1219090.0, 'date_yr': 2011}, {'country': 'Germany', 'rank': 26, 'cultivated_land_k': 123879, 'cultivated_land_p': 34.7, 'arable_land_k': 121737, 'arable_land_p': 34.1, 'permanent_crops_k': 2142, 'permanent_crops_p': 0.6, 'other_land_k': 233143.0, 'other_land_p': 65.3, 'total_area': 357022.0, 'date_yr': 2011}, {'country': 'Poland', 'rank': 27, 'cultivated_land_k': 117262, 'cultivated_land_p': 37.5, 'arable_land_k': 113197, 'arable_land_p': 36.2, 'permanent_crops_k': 4065, 'permanent_crops_p': 1.3, 'other_land_k': 195423.0, 'other_land_p': 62.5, 'total_area': 312685.0, 'date_yr': 2011}, {'country': 'Uganda', 'rank': 28, 'cultivated_land_k': 109896, 'cultivated_land_p': 45.6, 'arable_land_k': 82663, 'arable_land_p': 34.3, 'permanent_crops_k': 27233, 'permanent_crops_p': 11.3, 'other_land_k': 131148.0, 'other_land_p': 54.4, 'total_area': 241038.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Malaysia', 'rank': 39, 'cultivated_land_k': 73568, 'cultivated_land_p': 22.3, 'arable_land_k': 9567, 'arable_land_p': 2.9, 'permanent_crops_k': 64001, 'permanent_crops_p': 19.4, 'other_land_k': 256279.0, 'other_land_p': 77.7, 'total_area': 329847.0, 'date_yr': 2011}, {'country': 'Mali', 'rank': 40, 'cultivated_land_k': 70691, 'cultivated_land_p': 5.7, 'arable_land_k': 69451, 'arable_land_p': 5.6, 'permanent_crops_k': 1240, 'permanent_crops_p': 0.1, 'other_land_k': 1169501.0, 'other_land_p': 94.3, 'total_area': 1240192.0, 'date_yr': 2011})
# 2021-11-22 12:33:23,337 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,337 INFO sqlalchemy.engine.base.Engine ({'country': 'Kenya', 'rank': 41, 'cultivated_land_k': 62103, 'cultivated_land_p': 10.7, 'arable_land_k': 56879, 'arable_land_p': 9.8, 'permanent_crops_k': 5224, 'permanent_crops_p': 0.9, 'other_land_k': 518264.0, 'other_land_p': 89.3, 'total_area': 580367.0, 'date_yr': 2011}, {'country': 'United Kingdom', 'rank': 42, 'cultivated_land_k': 61631, 'cultivated_land_p': 25.3, 'arable_land_k': 61144, 'arable_land_p': 25.1, 'permanent_crops_k': 487, 'permanent_crops_p': 0.2, 'other_land_k': 181979.0, 'other_land_p': 74.7, 'total_area': 243610.0, 'date_yr': 2011}, {'country': 'Syria', 'rank': 43, 'cultivated_land_k': 57783, 'cultivated_land_p': 31.2, 'arable_land_k': 47041, 'arable_land_p': 25.4, 'permanent_crops_k': 10742, 'permanent_crops_p': 5.8, 'other_land_k': 688651.0, 'other_land_p': 68.8, 'total_area': 185180.0, 'date_yr': 2011}, {'country': 'Belarus', 'rank': 44, 'cultivated_land_k': 57713, 'cultivated_land_p': 27.8, 'arable_land_k': 56467, 'arable_land_p': 27.2, 'permanent_crops_k': 1246, 'permanent_crops_p': 0.6, 'other_land_k': 149887.0, 'other_land_p': 72.2, 'total_area': 207600.0, 'date_yr': 2011}, {'country': 'Paraguay', 'rank': 45, 'cultivated_land_k': 55770, 'cultivated_land_p': 11.0, 'arable_land_k': 54756, 'arable_land_p': 10.8, 'permanent_crops_k': 1014, 'permanent_crops_p': 0.2, 'other_land_k': 350982.0, 'other_land_p': 89.0, 'total_area': 406752.0, 'date_yr': 2011}, {'country': 'Tunisia', 'rank': 46, 'cultivated_land_k': 55133, 'cultivated_land_p': 33.7, 'arable_land_k': 29939, 'arable_land_p': 18.3, 'permanent_crops_k': 25194, 'permanent_crops_p': 15.4, 'other_land_k': 108477.0, 'other_land_p': 66.3, 'total_area': 163610.0, 'date_yr': 2011}, {'country': 'Peru', 'rank': 47, 'cultivated_land_k': 53878, 'cultivated_land_p': 4.2, 'arable_land_k': 39841, 'arable_land_p': 3.1, 'permanent_crops_k': 14137, 'permanent_crops_p': 1.1, 'other_land_k': 1231338.0, 'other_land_p': 95.8, 'total_area': 1285216.0, 'date_yr': 2011}, {'country': 'Mozambique', 'rank': 48, 'cultivated_land_k': 53560, 'cultivated_land_p': 6.7, 'arable_land_k': 51162, 'arable_land_p': 6.4, 'permanent_crops_k': 2398, 'permanent_crops_p': 0.3, 'other_land_k': 745820.0, 'other_land_p': 93.3, 'total_area': 799380.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Cuba', 'rank': 59, 'cultivated_land_k': 41476, 'cultivated_land_p': 37.4, 'arable_land_k': 37484, 'arable_land_p': 33.8, 'permanent_crops_k': 3992, 'permanent_crops_p': 3.6, 'other_land_k': 69384.0, 'other_land_p': 62.6, 'total_area': 110860.0, 'date_yr': 2011}, {'country': 'Madagascar', 'rank': 60, 'cultivated_land_k': 41090, 'cultivated_land_p': 7.0, 'arable_land_k': 35220, 'arable_land_p': 6.0, 'permanent_crops_k': 5870, 'permanent_crops_p': 1.0, 'other_land_k': 545951.0, 'other_land_p': 93.0, 'total_area': 587041.0, 'date_yr': 2011})
# 2021-11-22 12:33:23,344 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,345 INFO sqlalchemy.engine.base.Engine ({'country': 'Iraq', 'rank': 61, 'cultivated_land_k': 39009, 'cultivated_land_p': 8.9, 'arable_land_k': 36817, 'arable_land_p': 8.4, 'permanent_crops_k': 2192, 'permanent_crops_p': 0.5, 'other_land_k': 399308.0, 'other_land_p': 91.1, 'total_area': 438317.0, 'date_yr': 2011}, {'country': 'Greece', 'rank': 62, 'cultivated_land_k': 37752, 'cultivated_land_p': 28.6, 'arable_land_k': 26004, 'arable_land_p': 19.7, 'permanent_crops_k': 11748, 'permanent_crops_p': 8.9, 'other_land_k': 94205.0, 'other_land_p': 71.4, 'total_area': 131957.0, 'date_yr': 2011}, {'country': 'Zambia', 'rank': 63, 'cultivated_land_k': 36125, 'cultivated_land_p': 4.8, 'arable_land_k': 36125, 'arable_land_p': 4.8, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 716493.0, 'other_land_p': 95.2, 'total_area': 752618.0, 'date_yr': 2011}, {'country': 'Egypt', 'rank': 64, 'cultivated_land_k': 36054, 'cultivated_land_p': 3.6, 'arable_land_k': 28042, 'arable_land_p': 2.8, 'permanent_crops_k': 8012, 'permanent_crops_p': 0.8, 'other_land_k': 965396.0, 'other_land_p': 96.4, 'total_area': 1001450.0, 'date_yr': 2011}, {'country': 'Angola', 'rank': 65, 'cultivated_land_k': 52361, 'cultivated_land_p': 4.2, 'arable_land_k': 48621, 'arable_land_p': 3.9, 'permanent_crops_k': 3740, 'permanent_crops_p': 0.3, 'other_land_k': 1194339.0, 'other_land_p': 95.8, 'total_area': 1246700.0, 'date_yr': 2016}, {'country': 'Guinea', 'rank': 66, 'cultivated_land_k': 35901, 'cultivated_land_p': 14.6, 'arable_land_k': 29016, 'arable_land_p': 11.8, 'permanent_crops_k': 6885, 'permanent_crops_p': 2.8, 'other_land_k': 209956.0, 'other_land_p': 85.4, 'total_area': 245857.0, 'date_yr': 2011}, {'country': 'Venezuela', 'rank': 67, 'cultivated_land_k': 35572, 'cultivated_land_p': 3.9, 'arable_land_k': 28275, 'arable_land_p': 3.1, 'permanent_crops_k': 7297, 'permanent_crops_p': 0.8, 'other_land_k': 876478.0, 'other_land_p': 96.1, 'total_area': 912050.0, 'date_yr': 2011}, {'country': 'Bulgaria', 'rank': 68, 'cultivated_land_k': 35323, 'cultivated_land_p': 31.4, 'arable_land_k': 33159, 'arable_land_p': 29.9, 'permanent_crops_k': 2164, 'permanent_crops_p': 1.5, 'other_land_k': 75556.0, 'other_land_p': 68.6, 'total_area': 110879.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Denmark', 'rank': 79, 'cultivated_land_k': 25429, 'cultivated_land_p': 59.0, 'arable_land_k': 25386, 'arable_land_p': 58.9, 'permanent_crops_k': 43, 'permanent_crops_p': 0.1, 'other_land_k': 17665.0, 'other_land_p': 41.0, 'total_area': 43094.0, 'date_yr': 2011}, {'country': 'Guatemala', 'rank': 80, 'cultivated_land_k': 25047, 'cultivated_land_p': 23.0, 'arable_land_k': 15464, 'arable_land_p': 14.2, 'permanent_crops_k': 9583, 'permanent_crops_p': 8.8, 'other_land_k': 83842.0, 'other_land_p': 77.0, 'total_area': 108889.0, 'date_yr': 2011})
# 2021-11-22 12:33:23,352 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,352 INFO sqlalchemy.engine.base.Engine ({'country': 'Finland', 'rank': 81, 'cultivated_land_k': 25019, 'cultivated_land_p': 7.4, 'arable_land_k': 25019, 'arable_land_p': 7.4, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 313126.0, 'other_land_p': 92.6, 'total_area': 338145.0, 'date_yr': 2011}, {'country': 'Nepal', 'rank': 82, 'cultivated_land_k': 23993, 'cultivated_land_p': 16.3, 'arable_land_k': 22227, 'arable_land_p': 15.1, 'permanent_crops_k': 1766, 'permanent_crops_p': 1.2, 'other_land_k': 123188.0, 'other_land_p': 83.7, 'total_area': 147181.0, 'date_yr': 2011}, {'country': 'Sri Lanka', 'rank': 83, 'cultivated_land_k': 23944, 'cultivated_land_p': 36.5, 'arable_land_k': 13579, 'arable_land_p': 20.7, 'permanent_crops_k': 10365, 'permanent_crops_p': 15.8, 'other_land_k': 41666.0, 'other_land_p': 63.5, 'total_area': 65610.0, 'date_yr': 2011}, {'country': 'Lithuania', 'rank': 84, 'cultivated_land_k': 23117, 'cultivated_land_p': 35.4, 'arable_land_k': 22790, 'arable_land_p': 34.9, 'permanent_crops_k': 327, 'permanent_crops_p': 0.5, 'other_land_k': 42183.0, 'other_land_p': 64.6, 'total_area': 65300.0, 'date_yr': 2011}, {'country': 'Azerbaijan', 'rank': 85, 'cultivated_land_k': 22083, 'cultivated_land_p': 25.5, 'arable_land_k': 19745, 'arable_land_p': 22.8, 'permanent_crops_k': 2338, 'permanent_crops_p': 2.7, 'other_land_k': 64517.0, 'other_land_p': 74.5, 'total_area': 86600.0, 'date_yr': 2011}, {'country': 'Moldova', 'rank': 86, 'cultivated_land_k': 21764, 'cultivated_land_p': 64.2, 'arable_land_k': 18679, 'arable_land_p': 55.1, 'permanent_crops_k': 3085, 'permanent_crops_p': 9.1, 'other_land_k': 73514.0, 'other_land_p': 35.8, 'total_area': 33851.0, 'date_yr': 2011}, {'country': 'Kyrgyzstan', 'rank': 87, 'cultivated_land_k': 21400, 'cultivated_land_p': 7.1, 'arable_land_k': 13400, 'arable_land_p': 6.7, 'permanent_crops_k': 8000, 'permanent_crops_p': 0.4, 'other_land_k': 178551.0, 'other_land_p': 92.9, 'total_area': 199951.0, 'date_yr': 2011}, {'country': 'Libya', 'rank': 88, 'cultivated_land_k': 21114, 'cultivated_land_p': 1.2, 'arable_land_k': 17595, 'arable_land_p': 1.0, 'permanent_crops_k': 3519, 'permanent_crops_p': 0.2, 'other_land_k': 1738426.0, 'other_land_p': 98.8, 'total_area': 1759540.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Burundi', 'rank': 99, 'cultivated_land_k': 15151, 'cultivated_land_p': 54.5, 'arable_land_k': 10814, 'arable_land_p': 38.9, 'permanent_crops_k': 4337, 'permanent_crops_p': 15.6, 'other_land_k': 57282.0, 'other_land_p': 45.5, 'total_area': 27830.0, 'date_yr': 2011}, {'country': 'Rwanda', 'rank': 100, 'cultivated_land_k': 15017, 'cultivated_land_p': 57.1, 'arable_land_k': 12361, 'arable_land_p': 47.0, 'permanent_crops_k': 2656, 'permanent_crops_p': 10.1, 'other_land_k': 11321.0, 'other_land_p': 42.9, 'total_area': 26338.0, 'date_yr': 2011})
# 2021-11-22 12:33:23,359 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
permanent_crops_k': 1885, 'permanent_crops_p': 2.5, 'other_land_k': 68031.0, 'other_land_p': 90.2, 'total_area': 75420.0, 'date_yr': 2011}, {'country': 'Albania', 'rank': 121, 'cultivated_land_k': 7359, 'cultivated_land_p': 25.6, 'arable_land_k': 6497, 'arable_land_p': 22.6, 'permanent_crops_k': 862, 'permanent_crops_p': 3.0, 'other_land_k': 21458.0, 'other_land_p': 74.4, 'total_area': 28748.0, 'date_yr': 2016})
# 2021-11-22 12:33:23,368 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,368 INFO sqlalchemy.engine.base.Engine ({'country': 'Norway', 'rank': 122, 'cultivated_land_k': 7124, 'cultivated_land_p': 2.2, 'arable_land_k': 7124, 'arable_land_p': 2.2, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 316678.0, 'other_land_p': 97.8, 'total_area': 323802.0, 'date_yr': 2011}, {'country': 'Estonia', 'rank': 123, 'cultivated_land_k': 6780, 'cultivated_land_p': 15.0, 'arable_land_k': 6735, 'arable_land_p': 14.9, 'permanent_crops_k': 45, 'permanent_crops_p': 0.1, 'other_land_k': 38448.0, 'other_land_p': 85.0, 'total_area': 45228.0, 'date_yr': 2011}, {'country': 'Mongolia', 'rank': 124, 'cultivated_land_k': 6256, 'cultivated_land_p': 0.4, 'arable_land_k': 6256, 'arable_land_p': 0.4, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 1557860.0, 'other_land_p': 99.6, 'total_area': 1564116.0, 'date_yr': 2011}, {'country': 'Republic of the Congo', 'rank': 125, 'cultivated_land_k': 6156, 'cultivated_land_p': 1.8, 'arable_land_k': 5472, 'arable_land_p': 1.6, 'permanent_crops_k': 684, 'permanent_crops_p': 0.2, 'other_land_k': 335844.0, 'other_land_p': 98.2, 'total_area': 342000.0, 'date_yr': 2011}, {'country': 'Costa Rica', 'rank': 126, 'cultivated_land_k': 5928, 'cultivated_land_p': 11.6, 'arable_land_k': 2504, 'arable_land_p': 4.9, 'permanent_crops_k': 3424, 'permanent_crops_p': 6.7, 'other_land_k': 45172.0, 'other_land_p': 88.4, 'total_area': 51100.0, 'date_yr': 2011}, {'country': 'New Zealand', 'rank': 127, 'cultivated_land_k': 5642, 'cultivated_land_p': 2.1, 'arable_land_k': 4838, 'arable_land_p': 1.8, 'permanent_crops_k': 806, 'permanent_crops_p': 0.3, 'other_land_k': 263196.0, 'other_land_p': 97.9, 'total_area': 268838.0, 'date_yr': 2011}, {'country': 'Guinea-Bissau', 'rank': 128, 'cultivated_land_k': 5451, 'cultivated_land_p': 15.1, 'arable_land_k': 2960, 'arable_land_p': 8.2, 'permanent_crops_k': 2491, 'permanent_crops_p': 6.9, 'other_land_k': 30674.0, 'other_land_p': 84.9, 'total_area': 36125.0, 'date_yr': 2011}, {'country': 'Georgia', 'rank': 129, 'cultivated_land_k': 5298, 'cultivated_land_p': 7.6, 'arable_land_k': 4043, 'arable_land_p': 5.8, 'permanent_crops_k': 1255, 'permanent_crops_p': 1.8, 'other_land_k': 64402.0, 'other_land_p': 92.4, 'total_area': 69700.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Jordan', 'rank': 140, 'cultivated_land_k': 2681, 'cultivated_land_p': 3.0, 'arable_land_k': 1787, 'arable_land_p': 2.0, 'permanent_crops_k': 894, 'permanent_crops_p': 1.0, 'other_land_k': 86661.0, 'other_land_p': 97.0, 'total_area': 89342.0, 'date_yr': 2011}, {'country': 'Lebanon', 'rank': 141, 'cultivated_land_k': 2517, 'cultivated_land_p': 24.2, 'arable_land_k': 1238, 'arable_land_p': 11.9, 'permanent_crops_k': 1279, 'permanent_crops_p': 12.3, 'other_land_k': 7883.0, 'other_land_p': 75.8, 'total_area': 10400.0, 'date_yr': 2011})
# 2021-11-22 12:33:23,375 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,376 INFO sqlalchemy.engine.base.Engine ({'country': 'Fiji', 'rank': 142, 'cultivated_land_k': 2507, 'cultivated_land_p': 13.7, 'arable_land_k': 1647, 'arable_land_p': 9.0, 'permanent_crops_k': 860, 'permanent_crops_p': 4.7, 'other_land_k': 15767.0, 'other_land_p': 86.3, 'total_area': 18274.0, 'date_yr': 2011}, {'country': 'Jamaica', 'rank': 143, 'cultivated_land_k': 2233, 'cultivated_land_p': 20.3, 'arable_land_k': 1221, 'arable_land_p': 11.1, 'permanent_crops_k': 1012, 'permanent_crops_p': 9.2, 'other_land_k': 8758.0, 'other_land_p': 79.7, 'total_area': 10991.0, 'date_yr': 2011}, {'country': 'Timor-Leste', 'rank': 144, 'cultivated_land_k': 2231, 'cultivated_land_p': 15.0, 'arable_land_k': 1502, 'arable_land_p': 10.1, 'permanent_crops_k': 729, 'permanent_crops_p': 4.9, 'other_land_k': 12643.0, 'other_land_p': 85.0, 'total_area': 14874.0, 'date_yr': 2011}, {'country': 'Palestine', 'rank': 145, 'cultivated_land_k': 2023, 'cultivated_land_p': 18.4, 'arable_land_k': 953, 'arable_land_p': 7.4, 'permanent_crops_k': 1070, 'permanent_crops_p': 11.0, 'other_land_k': 3617.0, 'other_land_p': 81.6, 'total_area': 5860.0, 'date_yr': 2011}, {'country': 'Slovenia', 'rank': 146, 'cultivated_land_k': 1970, 'cultivated_land_p': 9.7, 'arable_land_k': 1706, 'arable_land_p': 8.4, 'permanent_crops_k': 264, 'permanent_crops_p': 1.3, 'other_land_k': 18303.0, 'other_land_p': 90.3, 'total_area': 20273.0, 'date_yr': 2011}, {'country': 'Montenegro', 'rank': 147, 'cultivated_land_k': 1950, 'cultivated_land_p': 14.1, 'arable_land_k': 1784, 'arable_land_p': 12.9, 'permanent_crops_k': 166, 'permanent_crops_p': 1.2, 'other_land_k': 11862.0, 'other_land_p': 85.9, 'total_area': 13812.0, 'date_yr': 2011}, {'country': 'Eswatini (Swaziland)', 'rank': 148, 'cultivated_land_k': 1840, 'cultivated_land_p': 10.6, 'arable_land_k': 1701, 'arable_land_p': 9.8, 'permanent_crops_k': 139, 'permanent_crops_p': 0.8, 'other_land_k': 15524.0, 'other_land_p': 89.4, 'total_area': 17364.0, 'date_yr': 2011}, {'country': 'Equatorial Guinea', 'rank': 149, 'cultivated_land_k': 1798, 'cultivated_land_p': 5.4, 'arable_land_k': 1208, 'arable_land_p': 4.3, 'permanent_crops_k': 590, 'permanent_crops_p': 2.1, 'other_land_k': 26253.0, 'other_land_p': 94.6, 'total_area': 28051.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Oman', 'rank': 160, 'cultivated_land_k': 619, 'cultivated_land_p': 0.2, 'arable_land_k': 310, 'arable_land_p': 0.1, 'permanent_crops_k': 309, 'permanent_crops_p': 0.1, 'other_land_k': 308881.0, 'other_land_p': 99.8, 'total_area': 309500.0, 'date_yr': 2011}, {'country': 'Cape Verde', 'rank': 161, 'cultivated_land_k': 500, 'cultivated_land_p': 12.4, 'arable_land_k': 472, 'arable_land_p': 11.7, 'permanent_crops_k': 28, 'permanent_crops_p': 0.7, 'other_land_k': 3533.0, 'other_land_p': 87.6, 'total_area': 4033.0, 'date_yr': 2011})
# 2021-11-22 12:33:23,382 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,383 INFO sqlalchemy.engine.base.Engine ({'country': 'São Tomé and Príncipe', 'rank': 162, 'cultivated_land_k': 479, 'cultivated_land_p': 49.7, 'arable_land_k': 87, 'arable_land_p': 9.1, 'permanent_crops_k': 392, 'permanent_crops_p': 40.6, 'other_land_k': 485.0, 'other_land_p': 50.3, 'total_area': 964.0, 'date_yr': 2011}, {'country': 'Trinidad and Tobago', 'rank': 163, 'cultivated_land_k': 471, 'cultivated_land_p': 9.2, 'arable_land_k': 251, 'arable_land_p': 4.9, 'permanent_crops_k': 220, 'permanent_crops_p': 4.3, 'other_land_k': 4657.0, 'other_land_p': 90.8, 'total_area': 5128.0, 'date_yr': 2011}, {'country': 'Kiribati', 'rank': 164, 'cultivated_land_k': 411, 'cultivated_land_p': 50.68, 'arable_land_k': 22, 'arable_land_p': 2.71, 'permanent_crops_k': 389, 'permanent_crops_p': 47.97, 'other_land_k': 400.0, 'other_land_p': 49.32, 'total_area': 811.0, 'date_yr': 2011}, {'country': 'Micronesia', 'rank': 165, 'cultivated_land_k': 361, 'cultivated_land_p': 51.42, 'arable_land_k': 40, 'arable_land_p': 5.71, 'permanent_crops_k': 321, 'permanent_crops_p': 45.71, 'other_land_k': 341.0, 'other_land_p': 48.58, 'total_area': 702.0, 'date_yr': 2011}, {'country': 'Samoa', 'rank': 166, 'cultivated_land_k': 299, 'cultivated_land_p': 10.6, 'arable_land_k': 79, 'arable_land_p': 2.8, 'permanent_crops_k': 220, 'permanent_crops_p': 7.8, 'other_land_k': 2532.0, 'other_land_p': 89.4, 'total_area': 2831.0, 'date_yr': 2011}, {'country': 'Tonga', 'rank': 167, 'cultivated_land_k': 280, 'cultivated_land_p': 37.5, 'arable_land_k': 166, 'arable_land_p': 22.2, 'permanent_crops_k': 115, 'permanent_crops_p': 15.3, 'other_land_k': 467.0, 'other_land_p': 62.5, 'total_area': 747.0, 'date_yr': 2011}, {'country': 'Dominica', 'rank': 168, 'cultivated_land_k': 237, 'cultivated_land_p': 32.0, 'arable_land_k': 57, 'arable_land_p': 8.0, 'permanent_crops_k': 180, 'permanent_crops_p': 24.0, 'other_land_k': 514.0, 'other_land_p': 68.0, 'total_area': 751.0, 'date_yr': 2011}, {'country': 'Saint Lucia', 'rank': 169, 'cultivated_land_k': 176, 'cultivated_land_p': 29.03, 'arable_land_k': 39, 'arable_land_p': 6.45, 'permanent_crops_k': 137, 'permanent_crops_p': 22.58, 'other_land_k': 430.0, 'other_land_p': 70.97, 'total_area': 606.0, 'date_yr': 2011}  ... displaying 10 of 20 total bound parameter sets ...  {'country': 'Bahamas', 'rank': 180, 'cultivated_land_k': 87, 'cultivated_land_p': 0.87, 'arable_land_k': 58, 'arable_land_p': 0.58, 'permanent_crops_k': 29, 'permanent_crops_p': 0.29, 'other_land_k': 9982.0, 'other_land_p': 99.13, 'total_area': 10070.0, 'date_yr': 2005}, {'country': 'Iceland', 'rank': 181, 'cultivated_land_k': 70, 'cultivated_land_p': 0.07, 'arable_land_k': 70, 'arable_land_p': 0.07, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 100180.0, 'other_land_p': 99.93, 'total_area': 100250.0, 'date_yr': 2005})
# 2021-11-22 12:33:23,389 INFO sqlalchemy.engine.base.Engine INSERT INTO jch5x8.land_use_statistics (country, rank, cultivated_land_k, cultivated_land_p, arable_land_k, arable_land_p, permanent_crops_k, permanent_crops_p, other_land_k, other_land_p, total_area, date_yr) VALUES (%(country)s, %(rank)s, %(cultivated_land_k)s, %(cultivated_land_p)s, %(arable_land_k)s, %(arable_land_p)s, %(permanent_crops_k)s, %(permanent_crops_p)s, %(other_land_k)s, %(other_land_p)s, %(total_area)s, %(date_yr)s)
# 2021-11-22 12:33:23,389 INFO sqlalchemy.engine.base.Engine ({'country': 'Seychelles', 'rank': 182, 'cultivated_land_k': 69, 'cultivated_land_p': 15.21, 'arable_land_k': 10, 'arable_land_p': 2.17, 'permanent_crops_k': 59, 'permanent_crops_p': 13.04, 'other_land_k': 386.0, 'other_land_p': 84.79, 'total_area': 455.0, 'date_yr': 2005}, {'country': 'Palau', 'rank': 183, 'cultivated_land_k': 60, 'cultivated_land_p': 13.05, 'arable_land_k': 40, 'arable_land_p': 8.7, 'permanent_crops_k': 20, 'permanent_crops_p': 4.35, 'other_land_k': 398.0, 'other_land_p': 86.95, 'total_area': 458.0, 'date_yr': 2005}, {'country': 'Saint Kitts and Nevis', 'rank': 184, 'cultivated_land_k': 58, 'cultivated_land_p': 22.22, 'arable_land_k': 51, 'arable_land_p': 19.44, 'permanent_crops_k': 7, 'permanent_crops_p': 2.78, 'other_land_k': 203.0, 'other_land_p': 77.78, 'total_area': 261.0, 'date_yr': 2005}, {'country': 'Bahrain', 'rank': 185, 'cultivated_land_k': 56, 'cultivated_land_p': 8.45, 'arable_land_k': 19, 'arable_land_p': 2.82, 'permanent_crops_k': 37, 'permanent_crops_p': 5.63, 'other_land_k': 609.0, 'other_land_p': 91.55, 'total_area': 665.0, 'date_yr': 2005}, {'country': 'Liechtenstein', 'rank': 186, 'cultivated_land_k': 40, 'cultivated_land_p': 25.0, 'arable_land_k': 40, 'arable_land_p': 25.0, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 120.0, 'other_land_p': 75.0, 'total_area': 160.0, 'date_yr': 2005}, {'country': 'Singapore', 'rank': 187, 'cultivated_land_k': 20, 'cultivated_land_p': 2.94, 'arable_land_k': 10, 'arable_land_p': 1.47, 'permanent_crops_k': 10, 'permanent_crops_p': 1.47, 'other_land_k': 663.0, 'other_land_p': 97.06, 'total_area': 683.0, 'date_yr': 2005}, {'country': 'Tuvalu', 'rank': 188, 'cultivated_land_k': 17, 'cultivated_land_p': 66.67, 'arable_land_k': 0, 'arable_land_p': 0.0, 'permanent_crops_k': 17, 'permanent_crops_p': 66.67, 'other_land_k': 9.0, 'other_land_p': 33.33, 'total_area': 26.0, 'date_yr': 2005}, {'country': 'Andorra', 'rank': 189, 'cultivated_land_k': 10, 'cultivated_land_p': 2.13, 'arable_land_k': 10, 'arable_land_p': 2.13, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 458.0, 'other_land_p': 97.87, 'total_area': 468.0, 'date_yr': 2005}  ... displaying 10 of 13 total bound parameter sets ...  {'country': 'Monaco', 'rank': 193, 'cultivated_land_k': 0, 'cultivated_land_p': 0.0, 'arable_land_k': 0, 'arable_land_p': 0.0, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 2.0, 'other_land_p': 100.0, 'total_area': 2.0, 'date_yr': 2005}, {'country': 'Vatican City', 'rank': 194, 'cultivated_land_k': 0, 'cultivated_land_p': 0.0, 'arable_land_k': 0, 'arable_land_p': 0.0, 'permanent_crops_k': 0, 'permanent_crops_p': 0.0, 'other_land_k': 0.44, 'other_land_p': 100.0, 'total_area': 0.44, 'date_yr': 2005})
# 2021-11-22 12:33:23,395 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# ### 5. Test loaded data with SQL queries

# %% [markdown]
# ```SQL
# \x
# select * from SSO.land_use_statistics limit 2;
# ```
#
# ---
#
# ```
# -[ RECORD 1 ]-----+--------------
# country           | India
# rank              | 1
# cultivated_land_k | 1891761
# cultivated_land_p | 57
# arable_land_k     | 1753694
# arable_land_p     | 52.8
# permanent_crops_k | 138067
# permanent_crops_p | 4.2
# other_land_k      | 1.3955e+06
# other_land_p      | 43
# total_area        | 3.28726e+06
# date_yr           | 2011
# -[ RECORD 2 ]-----+--------------
# country           | United States
# rank              | 2
# cultivated_land_k | 1681826
# cultivated_land_p | 17.1
# arable_land_k     | 1652028
# arable_land_p     | 16.8
# permanent_crops_k | 29798
# permanent_crops_p | 0.3
# other_land_k      | 8.15169e+06
# other_land_p      | 82.9
# total_area        | 9.83352e+06
# date_yr           | 2011
# ```
#
# ---

# %% [markdown]
# #### Now that the data is loaded, let's pull it back out!

# %%
df_backout = pd.read_sql_table(
    'land_use_statistics',
    con = engine,             # The engine created above
    schema= username   # The schema where the table lives, our pawprint
)
# Out:
# 2021-11-22 12:34:50,021 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-11-22 12:34:50,022 INFO sqlalchemy.engine.base.Engine {'schema': 'jch5x8'}
# 2021-11-22 12:34:50,037 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind IN ('v', 'm')
# 2021-11-22 12:34:50,037 INFO sqlalchemy.engine.base.Engine {'schema': 'jch5x8'}
# 2021-11-22 12:34:50,043 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (n.nspname = %(schema)s)
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-11-22 12:34:50,043 INFO sqlalchemy.engine.base.Engine {'schema': 'jch5x8', 'table_name': 'land_use_statistics'}
# 2021-11-22 12:34:50,045 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-11-22 12:34:50,045 INFO sqlalchemy.engine.base.Engine {'table_oid': 2032978}
# 2021-11-22 12:34:50,048 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-11-22 12:34:50,048 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:34:50,060 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-11-22 12:34:50,060 INFO sqlalchemy.engine.base.Engine {}
# 2021-11-22 12:34:50,065 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-11-22 12:34:50,066 INFO sqlalchemy.engine.base.Engine {'table_oid': 2032978}
# 2021-11-22 12:34:50,068 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-11-22 12:34:50,068 INFO sqlalchemy.engine.base.Engine {'table_oid': 2032978}
# 2021-11-22 12:34:50,071 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-11-22 12:34:50,071 INFO sqlalchemy.engine.base.Engine {'table': 2032978}
# 2021-11-22 12:34:50,073 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-11-22 12:34:50,073 INFO sqlalchemy.engine.base.Engine {'table_oid': 2032978}
# 2021-11-22 12:34:50,076 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-11-22 12:34:50,076 INFO sqlalchemy.engine.base.Engine {'table_oid': 2032978}
# 2021-11-22 12:34:50,078 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-11-22 12:34:50,078 INFO sqlalchemy.engine.base.Engine {'table_oid': 2032978}
# 2021-11-22 12:34:50,079 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-11-22 12:34:50,080 INFO sqlalchemy.engine.base.Engine {'table_oid': 2032978}
# 2021-11-22 12:34:50,082 INFO sqlalchemy.engine.base.Engine SELECT jch5x8.land_use_statistics.country, jch5x8.land_use_statistics.rank, jch5x8.land_use_statistics.cultivated_land_k, jch5x8.land_use_statistics.cultivated_land_p, jch5x8.land_use_statistics.arable_land_k, jch5x8.land_use_statistics.arable_land_p, jch5x8.land_use_statistics.permanent_crops_k, jch5x8.land_use_statistics.permanent_crops_p, jch5x8.land_use_statistics.other_land_k, jch5x8.land_use_statistics.other_land_p, jch5x8.land_use_statistics.total_area, jch5x8.land_use_statistics.date_yr
# FROM jch5x8.land_use_statistics
# 2021-11-22 12:34:50,082 INFO sqlalchemy.engine.base.Engine {}

# %%
df_backout.head(10)
# Out:
#          country  rank  cultivated_land_k  cultivated_land_p  arable_land_k  \
# 0          India     1            1891761               57.0        1753694
# 1  United States     2            1681826               17.1        1652028
# 2         Russia     3            1265267                7.4        1248169
# 3          China     4            1238013               12.9        1084461
# 4         Brazil     5             800485                9.4         732359
# 5         Canada     6             519205                5.2         469281
# 6      Australia     7             487695                6.3         479954
# 7      Indonesia     8             478055               25.1         247598
# 8        Nigeria     9             412938               44.7         344577
# 9      Argentina    10             397598               14.3         386476
#
#    arable_land_p  permanent_crops_k  permanent_crops_p  other_land_k  \
# 0           52.8             138067                4.2     1395502.0
# 1           16.8              29798                0.3     8151691.0
# 2            7.3              17098                0.1    15832975.0
# 3           11.3             153552                1.6     8358947.0
# 4            8.6              68126                0.8     7715285.0
# 5            4.7              49924                0.5     9465465.0
# 6            6.2               7741                0.1     7253525.0
# 7           13.0             230457               12.1     1426514.0
# 8           37.3              68361                7.4      510830.0
# 9           13.9              11122                0.4     2382802.0
#
#    other_land_p  total_area  date_yr
# 0          43.0   3287263.0     2011
# 1          82.9   9833517.0     2011
# 2          92.6  17098242.0     2011
# 3          87.1   9596960.0     2011
# 4          90.6   8515770.0     2011
# 5          94.8   9984670.0     2011
# 6          93.7   7741220.0     2011
# 7          74.9   1904569.0     2011
# 8          55.3    923768.0     2011
# 9          85.7   2780400.0     2016

# %%
df_backout.tail(10)
# Out:
#            country  rank  cultivated_land_k  cultivated_land_p  arable_land_k  \
# 183        Bahrain   185                 56               8.45             19
# 184  Liechtenstein   186                 40              25.00             40
# 185      Singapore   187                 20               2.94             10
# 186         Tuvalu   188                 17              66.67              0
# 187        Andorra   189                 10               2.13             10
# 188     San Marino   190                 10              16.67             10
# 189       Djibouti   191                  9               0.04              9
# 190          Nauru   192                  0               0.00              0
# 191         Monaco   193                  0               0.00              0
# 192   Vatican City   194                  0               0.00              0
#
#      arable_land_p  permanent_crops_k  permanent_crops_p  other_land_k  \
# 183           2.82                 37               5.63        609.00
# 184          25.00                  0               0.00        120.00
# 185           1.47                 10               1.47        663.00
# 186           0.00                 17              66.67          9.00
# 187           2.13                  0               0.00        458.00
# 188          16.67                  0               0.00         51.00
# 189           0.04                  0               0.00      22971.00
# 190           0.00                  0               0.00         21.00
# 191           0.00                  0               0.00          2.00
# 192           0.00                  0               0.00          0.44
#
#      other_land_p  total_area  date_yr
# 183         91.55      665.00     2005
# 184         75.00      160.00     2005
# 185         97.06      683.00     2005
# 186         33.33       26.00     2005
# 187         97.87      468.00     2005
# 188         83.33       61.00     2005
# 189         99.96    22980.00     2005
# 190        100.00       21.00     2005
# 191        100.00        2.00     2005
# 192        100.00        0.44     2005

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`

# %% [markdown]
# ---
