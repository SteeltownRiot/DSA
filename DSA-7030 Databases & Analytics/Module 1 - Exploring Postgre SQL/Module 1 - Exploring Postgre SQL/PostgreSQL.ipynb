# %% [markdown]
# # PostgreSQL and Query Practice

# %% [markdown]
# This practice uses the DVD Rental database.
#
# Below is the schema (tables and relationships).
# We will address database design and _Entity-Relationship Diagrams_ (ERD) later in the course.
# For now, know that the table names are in the blue heading of the bubbles and the attributes (columns) are listed below.
#
# ![ERD MISSING](../images/PostgreSQL-Sample-Database.png)

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# <span style="background:yellow">The above cell should be run when you (re-)start working on the lab.</span>
#
# **NOTE:** After questions 2-8 are links to helpful hint videos in case you struggle on a question.
#
# # 1
#
# ### Select all the data from the language table.
#
# **HINT** use `SELECT` and the `%sql` or `%%sql` notebook extension.

# %%
# %%sql
# SELECT  *
# FROM    language;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 6 rows affected.
# [(1, 'English             ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (2, 'Italian             ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (3, 'Japanese            ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (4, 'Mandarin            ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (5, 'French              ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (6, 'German              ', datetime.datetime(2006, 2, 15, 10, 2, 19))]

# %% [markdown]
# [Helpful Hints](https://youtu.be/UR15jpl5EK8)
#
# ---
#
# # 2
#
# ### List all the actors who are named a variation of the name John.

# %%
# %%sql
# SELECT  first_name, last_name
# FROM    actor
# WHERE   first_name LIKE 'John%';
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 3 rows affected.
# [('Johnny', 'Lollobrigida'), ('Johnny', 'Cage'), ('John', 'Suvari')]

# %% [markdown]
# [Helpful Hints](https://youtu.be/3NeWY8WHSGU)
#
# ---
#
# # 3
#
#
# ### In a single query, list the `film_id` and `title` of films with a rental duration less than four days and the films with duration greater than six days.

# %%
# %%sql
# SELECT  film_id, title, rental_duration
# FROM    film
# WHERE   rental_duration < 4
#         OR rental_duration > 6;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 394 rows affected.
# [(133, 'Chamber Italian', 7),
#  (2, 'Ace Goldfinger', 3),
#  (3, 'Adaptation Holes', 7),
#  (6, 'Agent Truman', 3),
#  (9, 'Alabama Devil', 3),
#  (17, 'Alone Trip', 3),
#  (21, 'American Circus', 3),
#  (23, 'Anaconda Confessions', 3),
#  (25, 'Angels Life', 3),
#  (26, 'Annie Identity', 3),
#  (27, 'Anonymous Human', 7),
#  (36, 'Argonauts Town', 7),
#  (37, 'Arizona Bang', 3),
#  (46, 'Autumn Crow', 3),
#  (48, 'Backlash Undefeated', 3),
#  (50, 'Baked Cleopatra', 3),
#  (126, 'Casualties Encino', 3),
#  (60, 'Beast Hunchback', 3),
#  (65, 'Behavior Runaway', 3),
#  (69, 'Beverly Outlaw', 3),
#  (70, 'Bikini Borrowers', 7),
#  (71, 'Bilko Anonymous', 3),
#  (78, 'Blackout Private', 7),
#  (80, 'Blanket Beverly', 7),
#  (82, 'Blood Argonauts', 3),
#  (84, 'Boiled Dares', 7),
#  (87, 'Boondock Ballroom', 7),
#  (88, 'Born Spinal', 7),
#  (89, 'Borrowers Bedazzled', 7),
#  (90, 'Boulevard Mob', 3),
#  (92, 'Bowfinger Gables', 7),
#  (94, 'Braveheart Human', 7),
#  (97, 'Bride Intrigue', 7),
#  (99, 'Bringing Hysterical', 7),
#  (100, 'Brooklyn Desert', 7),
#  (101, 'Brotherhood Blanket', 3),
#  (103, 'Bucket Brotherhood', 7),
#  (109, 'Butterfly Chocolat', 3),
#  (111, 'Caddyshack Jedi', 3),
#  (114, 'Camelot Vacation', 3),
#  (118, 'Canyon Stock', 7),
#  (120, 'Caribbean Liberty', 3),
#  (122, 'Carrie Bunch', 7),
#  (124, 'Casper Dragonfly', 3),
#  (128, 'Catch Amistad', 7),
#  (129, 'Cause Date', 3),
#  (130, 'Celebrity Horn', 7),
#  (135, 'Chance Resurrection', 3),
#  (136, 'Chaplin License', 7),
#  (137, 'Charade Duffel', 3),
#  (139, 'Chasing Fight', 7),
#  (142, 'Chicken Hellfighters', 3),
#  (144, 'Chinatown Gladiator', 7),
#  (148, 'Chocolate Duck', 3),
#  (149, 'Christmas Moonshine', 7),
#  (150, 'Cider Desire', 7),
#  (153, 'Citizen Shrek', 7),
#  (156, 'Clerks Angels', 3),
#  (157, 'Clockwork Paradise', 7),
#  (184, 'Core Suit', 3),
#  (165, 'Coldblooded Darling', 7),
#  (169, 'Comforts Rush', 3),
#  (172, 'Coneheads Smoochy', 7),
#  (173, 'Confessions Maguire', 7),
#  (175, 'Confused Candles', 3),
#  (181, 'Contact Anonymous', 7),
#  (182, 'Control Anthem', 7),
#  (185, 'Cowboy Doom', 3),
#  (188, 'Crazy Home', 7),
#  (189, 'Creatures Shakespeare', 3),
#  (195, 'Crowds Telemark', 3),
#  (196, 'Cruelty Unforgiven', 7),
#  (200, 'Curtain Videotape', 7),
#  (201, 'Cyclone Family', 7),
#  (205, 'Dances None', 3),
#  (207, 'Dangerous Uptown', 7),
#  (208, 'Dares Pluto', 7),
#  (210, 'Darko Dorado', 3),
#  (211, 'Darling Breaking', 7),
#  (212, 'Darn Forrester', 7),
#  (214, 'Daughter Madigan', 3),
#  (216, 'Day Unfaithful', 3),
#  (218, 'Deceiver Betrayed', 7),
#  (220, 'Deer Virginian', 7),
#  (223, 'Desire Alien', 7),
#  (224, 'Desperate Trainspotting', 7),
#  (225, 'Destination Jerk', 3),
#  (230, 'Diary Panic', 7),
#  (231, 'Dinosaur Secretary', 7),
#  (232, 'Dirty Ace', 7),
#  (233, 'Disciple Mother', 3),
#  (237, 'Divorce Shining', 3),
#  (240, 'Dolls Rage', 7),
#  (243, 'Doors President', 3),
#  (247, 'Downhill Enough', 3),
#  (249, 'Dracula Crystal', 7),
#  (257, 'Drumline Cyclone', 3),
#  (260, 'Dude Blindness', 3),
#  (269, 'Earring Instinct', 3),
#  (270, 'Earth Vision', 7),
#  (275, 'Egypt Tenenbaums', 3),
#  (279, 'Elizabeth Shane', 7),
#  (280, 'Empire Malkovich', 7),
#  (285, 'English Bulworth', 3),
#  (286, 'Enough Raging', 7),
#  (288, 'Escape Metropolis', 7),
#  (292, 'Excitement Eve', 3),
#  (295, 'Expendable Stallion', 3),
#  (304, 'Fargo Gandhi', 3),
#  (306, 'Feathers Metal', 3),
#  (308, 'Ferris Mother', 3),
#  (314, 'Fight Jawbreaker', 3),
#  (318, 'Firehouse Vietnam', 7),
#  (321, 'Flash Wars', 3),
#  (323, 'Flight Lies', 7),
#  (324, 'Flintstones Happiness', 3),
#  (327, 'Fool Mockingbird', 3),
#  (328, 'Forever Candidate', 7),
#  (330, 'Forrester Comancheros', 7),
#  (332, 'Frankenstein Stranger', 7),
#  (333, 'Freaky Pocus', 7),
#  (342, 'Fugitive Maguire', 7),
#  (344, 'Fury Murder', 3),
#  (345, 'Gables Metropolis', 3),
#  (347, 'Games Bowfinger', 7),
#  (348, 'Gandhi Kwai', 7),
#  (350, 'Garden Island', 3),
#  (355, 'Ghostbusters Elf', 7),
#  (357, 'Gilbert Pelican', 7),
#  (362, 'Glory Tracy', 7),
#  (363, 'Go Purple', 3),
#  (364, 'Godfather Diary', 3),
#  (366, 'Goldfinger Sensibility', 3),
#  (368, 'Gone Trouble', 7),
#  (373, 'Graduate Lord', 7),
#  (374, 'Graffiti Love', 3),
#  (377, 'Grease Youth', 7),
#  (379, 'Greedy Roots', 7),
#  (380, 'Greek Everyone', 7),
#  (381, 'Grinch Massage', 7),
#  (382, 'Grit Clockwork', 3),
#  (386, 'Gump Date', 3),
#  (387, 'Gun Bonnie', 7),
#  (389, 'Gunfighter Mussolini', 3),
#  (394, 'Hamlet Wisdom', 7),
#  (400, 'Hardly Robbers', 7),
#  (402, 'Harper Dying', 3),
#  (409, 'Heartbreakers Bright', 3),
#  (410, 'Heaven Freedom', 7),
#  (413, 'Hedwig Alter', 7),
#  (414, 'Hellfighters Sierra', 3),
#  (415, 'High Encino', 3),
#  (420, 'Holes Brannigan', 7),
#  (421, 'Holiday Games', 7),
#  (422, 'Hollow Jeopardy', 7),
#  (423, 'Hollywood Anonymous', 7),
#  (426, 'Home Pity', 7),
#  (429, 'Honey Ties', 3),
#  (430, 'Hook Chariots', 7),
#  (431, 'Hoosiers Birdcage', 3),
#  (434, 'Horror Reign', 3),
#  (437, 'House Dynamite', 7),
#  (438, 'Human Graffiti', 3),
#  (444, 'Hustler Party', 3),
#  (448, 'Idaho Love', 3),
#  (451, 'Igby Maker', 7),
#  (453, 'Image Princess', 3),
#  (455, 'Impossible Prejudice', 7),
#  (460, 'Innocent Usual', 3),
#  (461, 'Insects Stone', 3),
#  (464, 'Intentions Empire', 3),
#  (469, 'Iron Moon', 7),
#  (471, 'Island Exorcist', 7),
#  (472, 'Italian African', 3),
#  (479, 'Jedi Beneath', 7),
#  (480, 'Jeepers Wedding', 3),
#  (482, 'Jeopardy Encino', 3),
#  (483, 'Jericho Mulan', 3),
#  (484, 'Jerk Paycheck', 3),
#  (486, 'Jet Neighbors', 7),
#  (488, 'Joon Northwest', 3),
#  (496, 'Kick Savannah', 3),
#  (498, 'Killer Innocent', 7),
#  (499, 'King Evolution', 3),
#  (501, 'Kissing Dolls', 3),
#  (503, 'Kramer Chocolate', 3),
#  (753, 'Rush Goodfellas', 3),
#  (511, 'Lawrence Love', 7),
#  (515, 'Legally Secretary', 7),
#  (516, 'Legend Jedi', 7),
#  (517, 'Lesson Cleopatra', 3),
#  (519, 'Liberty Magnificent', 3),
#  (520, 'License Weekend', 7),
#  (521, 'Lies Treatment', 7),
#  (523, 'Lights Deer', 7),
#  (526, 'Lock Rear', 7),
#  (529, 'Lonely Elephant', 3),
#  (531, 'Lose Inch', 3),
#  (536, 'Lovely Jingle', 3),
#  (537, 'Lover Truman', 3),
#  (538, 'Loverboy Attacks', 7),
#  (539, 'Luck Opus', 7),
#  (540, 'Lucky Flying', 7),
#  (542, 'Lust Lock', 3),
#  (546, 'Madre Gables', 7),
#  (547, 'Magic Mallrats', 3),
#  (548, 'Magnificent Chitty', 3),
#  (551, 'Maiden Home', 3),
#  (558, 'Mannequin Worst', 3),
#  (559, 'Married Go', 7),
#  (567, 'Meet Chocolate', 3),
#  (569, 'Menagerie Rushmore', 7),
#  (574, 'Midnight Westward', 3),
#  (575, 'Midsummer Groundhog', 3),
#  (576, 'Mighty Luck', 7),
#  (579, 'Minds Truman', 3),
#  (580, 'Mine Titans', 3),
#  (582, 'Miracle Virtual', 3),
#  (583, 'Mission Zoolander', 3),
#  (589, 'Modern Dorado', 3),
#  (590, 'Money Harold', 3),
#  (595, 'Moon Bunch', 7),
#  (599, 'Mother Oleander', 3),
#  (605, 'Mulholland Beast', 7),
#  (606, 'Mummy Creatures', 3),
#  (609, 'Muscle Bright', 7),
#  (610, 'Music Boondock', 7),
#  (611, 'Musketeers Wait', 7),
#  (618, 'Necklace Outbreak', 3),
#  (619, 'Neighbors Charade', 3),
#  (624, 'Nightmare Chill', 3),
#  (625, 'None Spiking', 3),
#  (629, 'Notorious Reunion', 7),
#  (630, 'Notting Speakeasy', 7),
#  (635, 'Oklahoma Jumanji', 7),
#  (637, 'Open African', 7),
#  (638, 'Operation Operation', 7),
#  (639, 'Opposite Necklace', 7),
#  (642, 'Order Betrayed', 7),
#  (643, 'Orient Closer', 3),
#  (644, 'Oscar Gold', 7),
#  (645, 'Others Soup', 7),
#  (648, 'Outlaw Hanky', 7),
#  (650, 'Pacific Amistad', 3),
#  (651, 'Packer Madigan', 3),
#  (652, 'Pajama Jawbreaker', 3),
#  (653, 'Panic Club', 3),
#  (656, 'Papi Necklace', 3),
#  (658, 'Paris Weekend', 7),
#  (659, 'Park Citizen', 3),
#  (660, 'Party Knock', 7),
#  (662, 'Paths Control', 3),
#  (663, 'Patient Sister', 7),
#  (667, 'Peach Innocent', 3),
#  (668, 'Peak Forever', 7),
#  (669, 'Pearl Destiny', 3),
#  (671, 'Perdition Fargo', 7),
#  (672, 'Perfect Groove', 7),
#  (673, 'Personal Ladybugs', 3),
#  (674, 'Pet Haunting', 3),
#  (676, 'Philadelphia Wife', 7),
#  (678, 'Pickup Driving', 3),
#  (690, 'Pond Seattle', 7),
#  (692, 'Potluck Mixed', 3),
#  (697, 'Primary Glass', 7),
#  (698, 'Princess Giant', 3),
#  (699, 'Private Drop', 7),
#  (704, 'Pure Runner', 3),
#  (709, 'Racer Egg', 7),
#  (713, 'Rainbow Shock', 3),
#  (715, 'Range Moonwalker', 3),
#  (718, 'Rebel Airport', 7),
#  (719, 'Records Zorro', 7),
#  (720, 'Redemption Comforts', 3),
#  (721, 'Reds Pocus', 7),
#  (723, 'Reign Gentlemen', 3),
#  (726, 'Reservoir Adaptation', 7),
#  (728, 'Reunion Witches', 3),
#  (730, 'Ridgemont Submarine', 3),
#  (731, 'Right Cranes', 7),
#  (735, 'Robbers Joon', 7),
#  (738, 'Rocketeer Mother', 3),
#  (741, 'Roman Punk', 7),
#  (742, 'Roof Champion', 7),
#  (743, 'Room Roman', 7),
#  (746, 'Rouge Squad', 3),
#  (750, 'Run Pacific', 3),
#  (756, 'Saddle Antitrust', 7),
#  (761, 'Santa Paris', 7),
#  (763, 'Satisfaction Confidential', 3),
#  (764, 'Saturday Lambs', 3),
#  (765, 'Saturn Name', 7),
#  (768, 'Scarface Bang', 3),
#  (771, 'Scorpion Apollo', 3),
#  (774, 'Searchers Wait', 3),
#  (778, 'Secrets Paradise', 3),
#  (780, 'Sensibility Rear', 7),
#  (784, 'Shanghai Tycoon', 7),
#  (786, 'Shepherd Midsummer', 7),
#  (789, 'Shock Cabin', 7),
#  (791, 'Show Lord', 3),
#  (792, 'Shrek License', 7),
#  (795, 'Siege Madre', 7),
#  (796, 'Sierra Divide', 3),
#  (797, 'Silence Kane', 7),
#  (799, 'Simon North', 3),
#  (800, 'Sinners Atlantis', 7),
#  (802, 'Sky Miracle', 7),
#  (803, 'Slacker Liaisons', 7),
#  (804, 'Sleeping Suspects', 7),
#  (812, 'Smoking Barbarella', 7),
#  (813, 'Smoochy Control', 7),
#  (816, 'Snowman Rollercoaster', 3),
#  (817, 'Soldiers Evolution', 7),
#  (819, 'Song Hedwig', 3),
#  (820, 'Sons Interview', 3),
#  (826, 'Speed Suit', 7),
#  (828, 'Spiking Element', 7),
#  (829, 'Spinal Rocky', 7),
#  (830, 'Spirit Flintstones', 7),
#  (836, 'Squad Fish', 3),
#  (845, 'Stepmom Dream', 7),
#  (846, 'Sting Personal', 3),
#  (847, 'Stock Glass', 7),
#  (848, 'Stone Fire', 3),
#  (850, 'Story Side', 7),
#  (851, 'Straight Hours', 3),
#  (853, 'Stranger Strangers', 3),
#  (855, 'Streak Ridgemont', 7),
#  (857, 'Strictly Scarface', 3),
#  (859, 'Sugar Wonka', 3),
#  (861, 'Suit Walls', 3),
#  (865, 'Sunrise League', 3),
#  (891, 'Timberland Sky', 3),
#  (872, 'Sweet Brotherhood', 3),
#  (873, 'Sweethearts Suspects', 3),
#  (876, 'Tarzan Videotape', 3),
#  (878, 'Teen Apollo', 3),
#  (879, 'Telegraph Voyage', 3),
#  (885, 'Texas Watch', 7),
#  (889, 'Ties Hunger', 3),
#  (892, 'Titanic Boondock', 3),
#  (895, 'Tomorrow Hustler', 3),
#  (896, 'Tootsie Pilot', 3),
#  (897, 'Torque Bound', 3),
#  (899, 'Towers Hurricane', 7),
#  (901, 'Tracy Cider', 3),
#  (904, 'Train Bunch', 3),
#  (905, 'Trainspotting Strangers', 7),
#  (908, 'Trap Guys', 3),
#  (909, 'Treasure Command', 3),
#  (910, 'Treatment Jekyll', 3),
#  (911, 'Trip Newton', 7),
#  (912, 'Trojan Tomorrow', 3),
#  (913, 'Troopers Metal', 3),
#  (915, 'Truman Crazy', 7),
#  (916, 'Turn Star', 3),
#  (917, 'Tuxedo Mile', 3),
#  (919, 'Tycoon Gathering', 3),
#  (920, 'Unbreakable Karate', 3),
#  (921, 'Uncut Suicides', 7),
#  (922, 'Undefeated Dalmations', 7),
#  (923, 'Unfaithful Kill', 7),
#  (924, 'Unforgiven Zoolander', 7),
#  (925, 'United Pilot', 3),
#  (931, 'Valentine Vanishing', 7),
#  (932, 'Valley Packer', 3),
#  (934, 'Vanilla Day', 7),
#  (936, 'Vanishing Rocky', 3),
#  (937, 'Varsity Trip', 7),
#  (938, 'Velvet Terminator', 3),
#  (942, 'Vietnam Smoochy', 7),
#  (946, 'Virtual Spoilers', 3),
#  (950, 'Volume House', 7),
#  (952, 'Wagon Jaws', 7),
#  (953, 'Wait Cider', 3),
#  (954, 'Wake Jaws', 7),
#  (955, 'Walls Artist', 7),
#  (956, 'Wanda Chamber', 7),
#  (957, 'War Notting', 7),
#  (961, 'Wash Heavenly', 7),
#  (962, 'Wasteland Divine', 7),
#  (966, 'Wedding Apollo', 3),
#  (970, 'Westward Seabiscuit', 7),
#  (973, 'Wife Turn', 3),
#  (977, 'Window Side', 3),
#  (978, 'Wisdom Worker', 3),
#  (981, 'Wolves Desire', 7),
#  (983, 'Won Dares', 7),
#  (984, 'Wonderful Drop', 3),
#  (987, 'Words Hunter', 3),
#  (988, 'Worker Tarzan', 7),
#  (990, 'World Leathernecks', 3),
#  (1000, 'Zorro Ark', 3)]

# %% [markdown]
#
# [Helpful Hints](https://youtu.be/qhKW-DrI6FE)
#
# ---
#
# # 4
#
#
# ### Modify the query in Q3 to constrain the films less than 4 days to 0.99 `rental_rate` and the greater than 6 days to 2.99 `rental_rate`.

# %%
# %%sql
# SELECT  film_id, title, rental_duration, rental_rate
# FROM    film
# WHERE   (rental_duration < 4 AND rental_rate = 0.99)
#         OR (rental_duration > 6 AND rental_rate = 2.99);
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 148 rows affected.
# [(3, 'Adaptation Holes', 7, Decimal('2.99')),
#  (17, 'Alone Trip', 3, Decimal('0.99')),
#  (23, 'Anaconda Confessions', 3, Decimal('0.99')),
#  (26, 'Annie Identity', 3, Decimal('0.99')),
#  (78, 'Blackout Private', 7, Decimal('2.99')),
#  (80, 'Blanket Beverly', 7, Decimal('2.99')),
#  (82, 'Blood Argonauts', 3, Decimal('0.99')),
#  (90, 'Boulevard Mob', 3, Decimal('0.99')),
#  (94, 'Braveheart Human', 7, Decimal('2.99')),
#  (99, 'Bringing Hysterical', 7, Decimal('2.99')),
#  (101, 'Brotherhood Blanket', 3, Decimal('0.99')),
#  (109, 'Butterfly Chocolat', 3, Decimal('0.99')),
#  (111, 'Caddyshack Jedi', 3, Decimal('0.99')),
#  (114, 'Camelot Vacation', 3, Decimal('0.99')),
#  (136, 'Chaplin License', 7, Decimal('2.99')),
#  (142, 'Chicken Hellfighters', 3, Decimal('0.99')),
#  (150, 'Cider Desire', 7, Decimal('2.99')),
#  (181, 'Contact Anonymous', 7, Decimal('2.99')),
#  (188, 'Crazy Home', 7, Decimal('2.99')),
#  (189, 'Creatures Shakespeare', 3, Decimal('0.99')),
#  (201, 'Cyclone Family', 7, Decimal('2.99')),
#  (205, 'Dances None', 3, Decimal('0.99')),
#  (208, 'Dares Pluto', 7, Decimal('2.99')),
#  (220, 'Deer Virginian', 7, Decimal('2.99')),
#  (223, 'Desire Alien', 7, Decimal('2.99')),
#  (225, 'Destination Jerk', 3, Decimal('0.99')),
#  (230, 'Diary Panic', 7, Decimal('2.99')),
#  (231, 'Dinosaur Secretary', 7, Decimal('2.99')),
#  (232, 'Dirty Ace', 7, Decimal('2.99')),
#  (233, 'Disciple Mother', 3, Decimal('0.99')),
#  (240, 'Dolls Rage', 7, Decimal('2.99')),
#  (247, 'Downhill Enough', 3, Decimal('0.99')),
#  (257, 'Drumline Cyclone', 3, Decimal('0.99')),
#  (269, 'Earring Instinct', 3, Decimal('0.99')),
#  (275, 'Egypt Tenenbaums', 3, Decimal('0.99')),
#  (285, 'English Bulworth', 3, Decimal('0.99')),
#  (286, 'Enough Raging', 7, Decimal('2.99')),
#  (288, 'Escape Metropolis', 7, Decimal('2.99')),
#  (292, 'Excitement Eve', 3, Decimal('0.99')),
#  (295, 'Expendable Stallion', 3, Decimal('0.99')),
#  (306, 'Feathers Metal', 3, Decimal('0.99')),
#  (314, 'Fight Jawbreaker', 3, Decimal('0.99')),
#  (328, 'Forever Candidate', 7, Decimal('2.99')),
#  (333, 'Freaky Pocus', 7, Decimal('2.99')),
#  (344, 'Fury Murder', 3, Decimal('0.99')),
#  (345, 'Gables Metropolis', 3, Decimal('0.99')),
#  (362, 'Glory Tracy', 7, Decimal('2.99')),
#  (363, 'Go Purple', 3, Decimal('0.99')),
#  (366, 'Goldfinger Sensibility', 3, Decimal('0.99')),
#  (368, 'Gone Trouble', 7, Decimal('2.99')),
#  (373, 'Graduate Lord', 7, Decimal('2.99')),
#  (374, 'Graffiti Love', 3, Decimal('0.99')),
#  (380, 'Greek Everyone', 7, Decimal('2.99')),
#  (382, 'Grit Clockwork', 3, Decimal('0.99')),
#  (394, 'Hamlet Wisdom', 7, Decimal('2.99')),
#  (400, 'Hardly Robbers', 7, Decimal('2.99')),
#  (402, 'Harper Dying', 3, Decimal('0.99')),
#  (410, 'Heaven Freedom', 7, Decimal('2.99')),
#  (413, 'Hedwig Alter', 7, Decimal('2.99')),
#  (429, 'Honey Ties', 3, Decimal('0.99')),
#  (434, 'Horror Reign', 3, Decimal('0.99')),
#  (437, 'House Dynamite', 7, Decimal('2.99')),
#  (461, 'Insects Stone', 3, Decimal('0.99')),
#  (471, 'Island Exorcist', 7, Decimal('2.99')),
#  (482, 'Jeopardy Encino', 3, Decimal('0.99')),
#  (488, 'Joon Northwest', 3, Decimal('0.99')),
#  (496, 'Kick Savannah', 3, Decimal('0.99')),
#  (498, 'Killer Innocent', 7, Decimal('2.99')),
#  (753, 'Rush Goodfellas', 3, Decimal('0.99')),
#  (517, 'Lesson Cleopatra', 3, Decimal('0.99')),
#  (520, 'License Weekend', 7, Decimal('2.99')),
#  (526, 'Lock Rear', 7, Decimal('2.99')),
#  (531, 'Lose Inch', 3, Decimal('0.99')),
#  (539, 'Luck Opus', 7, Decimal('2.99')),
#  (540, 'Lucky Flying', 7, Decimal('2.99')),
#  (546, 'Madre Gables', 7, Decimal('2.99')),
#  (547, 'Magic Mallrats', 3, Decimal('0.99')),
#  (559, 'Married Go', 7, Decimal('2.99')),
#  (569, 'Menagerie Rushmore', 7, Decimal('2.99')),
#  (574, 'Midnight Westward', 3, Decimal('0.99')),
#  (576, 'Mighty Luck', 7, Decimal('2.99')),
#  (589, 'Modern Dorado', 3, Decimal('0.99')),
#  (599, 'Mother Oleander', 3, Decimal('0.99')),
#  (605, 'Mulholland Beast', 7, Decimal('2.99')),
#  (606, 'Mummy Creatures', 3, Decimal('0.99')),
#  (609, 'Muscle Bright', 7, Decimal('2.99')),
#  (618, 'Necklace Outbreak', 3, Decimal('0.99')),
#  (619, 'Neighbors Charade', 3, Decimal('0.99')),
#  (625, 'None Spiking', 3, Decimal('0.99')),
#  (638, 'Operation Operation', 7, Decimal('2.99')),
#  (642, 'Order Betrayed', 7, Decimal('2.99')),
#  (644, 'Oscar Gold', 7, Decimal('2.99')),
#  (645, 'Others Soup', 7, Decimal('2.99')),
#  (650, 'Pacific Amistad', 3, Decimal('0.99')),
#  (651, 'Packer Madigan', 3, Decimal('0.99')),
#  (652, 'Pajama Jawbreaker', 3, Decimal('0.99')),
#  (656, 'Papi Necklace', 3, Decimal('0.99')),
#  (658, 'Paris Weekend', 7, Decimal('2.99')),
#  (660, 'Party Knock', 7, Decimal('2.99')),
#  (672, 'Perfect Groove', 7, Decimal('2.99')),
#  (673, 'Personal Ladybugs', 3, Decimal('0.99')),
#  (674, 'Pet Haunting', 3, Decimal('0.99')),
#  (690, 'Pond Seattle', 7, Decimal('2.99')),
#  (709, 'Racer Egg', 7, Decimal('2.99')),
#  (726, 'Reservoir Adaptation', 7, Decimal('2.99')),
#  (728, 'Reunion Witches', 3, Decimal('0.99')),
#  (730, 'Ridgemont Submarine', 3, Decimal('0.99')),
#  (735, 'Robbers Joon', 7, Decimal('2.99')),
#  (738, 'Rocketeer Mother', 3, Decimal('0.99')),
#  (746, 'Rouge Squad', 3, Decimal('0.99')),
#  (750, 'Run Pacific', 3, Decimal('0.99')),
#  (756, 'Saddle Antitrust', 7, Decimal('2.99')),
#  (761, 'Santa Paris', 7, Decimal('2.99')),
#  (784, 'Shanghai Tycoon', 7, Decimal('2.99')),
#  (789, 'Shock Cabin', 7, Decimal('2.99')),
#  (792, 'Shrek License', 7, Decimal('2.99')),
#  (796, 'Sierra Divide', 3, Decimal('0.99')),
#  (799, 'Simon North', 3, Decimal('0.99')),
#  (800, 'Sinners Atlantis', 7, Decimal('2.99')),
#  (802, 'Sky Miracle', 7, Decimal('2.99')),
#  (816, 'Snowman Rollercoaster', 3, Decimal('0.99')),
#  (819, 'Song Hedwig', 3, Decimal('0.99')),
#  (828, 'Spiking Element', 7, Decimal('2.99')),
#  (829, 'Spinal Rocky', 7, Decimal('2.99')),
#  (847, 'Stock Glass', 7, Decimal('2.99')),
#  (848, 'Stone Fire', 3, Decimal('0.99')),
#  (851, 'Straight Hours', 3, Decimal('0.99')),
#  (891, 'Timberland Sky', 3, Decimal('0.99')),
#  (873, 'Sweethearts Suspects', 3, Decimal('0.99')),
#  (896, 'Tootsie Pilot', 3, Decimal('0.99')),
#  (901, 'Tracy Cider', 3, Decimal('0.99')),
#  (909, 'Treasure Command', 3, Decimal('0.99')),
#  (910, 'Treatment Jekyll', 3, Decimal('0.99')),
#  (913, 'Troopers Metal', 3, Decimal('0.99')),
#  (920, 'Unbreakable Karate', 3, Decimal('0.99')),
#  (921, 'Uncut Suicides', 7, Decimal('2.99')),
#  (923, 'Unfaithful Kill', 7, Decimal('2.99')),
#  (925, 'United Pilot', 3, Decimal('0.99')),
#  (932, 'Valley Packer', 3, Decimal('0.99')),
#  (937, 'Varsity Trip', 7, Decimal('2.99')),
#  (952, 'Wagon Jaws', 7, Decimal('2.99')),
#  (953, 'Wait Cider', 3, Decimal('0.99')),
#  (962, 'Wasteland Divine', 7, Decimal('2.99')),
#  (966, 'Wedding Apollo', 3, Decimal('0.99')),
#  (978, 'Wisdom Worker', 3, Decimal('0.99')),
#  (983, 'Won Dares', 7, Decimal('2.99')),
#  (988, 'Worker Tarzan', 7, Decimal('2.99')),
#  (990, 'World Leathernecks', 3, Decimal('0.99'))]

# %% [markdown]
# [Helpful Hints](https://youtu.be/C-2ASERLE_Q)
#
# ---
#
# # 5
#
# ###  List the unique values for `rental_rate` from the `film` table.

# %%
# %%sql
# SELECT  DISTINCT(rental_rate)
# FROM    film;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 3 rows affected.
# [(Decimal('2.99'),), (Decimal('4.99'),), (Decimal('0.99'),)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/xurTFkJ5S0g)
#
# ---
#
# # 6
#
#
# ###  List the `first_name` and `last_name` of actors whose last name start with the letter N, listed in reverse alphabetical order by last name

# %%
# %%sql
# SELECT  first_name, last_name
# FROM    actor
# WHERE   last_name LIKE 'N%'
# ORDER BY last_name DESC;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 7 rows affected.
# [('Warren', 'Nolte'),
#  ('Salma', 'Nolte'),
#  ('Albert', 'Nolte'),
#  ('Jayne', 'Nolte'),
#  ('Bette', 'Nicholson'),
#  ('Christian', 'Neeson'),
#  ('Jayne', 'Neeson')]

# %% [markdown]
# [Helpful Hints](https://youtu.be/uK2I4mrnJQ8)
#
#
# ---
#
# # 7
#
# ### List the top 8 `payment`s that have been made, along with the payment dates.

# %%
# %%sql
# SELECT  amount, payment_date
# FROM    payment
# ORDER BY amount DESC
# LIMIT   8;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 8 rows affected.
# [(Decimal('11.99'), datetime.datetime(2007, 3, 23, 20, 47, 59, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 4, 6, 21, 26, 57, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 22, 22, 17, 22, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 21, 22, 2, 26, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 2, 20, 46, 39, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 4, 7, 19, 14, 17, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 21, 21, 57, 24, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 4, 29, 21, 6, 7, 996577))]

# %% [markdown]
# [Helpful Hints](https://youtu.be/nV5P5h2x1SA)
#
# ---
#
# # 8
#
# ### List the top 20 `return_date`, `rental_date`, `rental_id`  from the rentals where a value exists for the return date; showing these in order of latest return date, then rental_date.

# %%
# %%sql
# SELECT  return_date, rental_date, rental_id
# FROM    rental
# WHERE   return_date IS NOT NULL
# ORDER BY return_date DESC, rental_date
# LIMIT   20;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 20 rows affected.
# [(datetime.datetime(2005, 9, 2, 2, 35, 22), datetime.datetime(2005, 8, 23, 21, 0, 22), 16005),
#  (datetime.datetime(2005, 9, 2, 2, 19, 33), datetime.datetime(2005, 8, 23, 22, 19, 33), 16040),
#  (datetime.datetime(2005, 9, 2, 1, 28, 33), datetime.datetime(2005, 8, 23, 19, 59, 33), 15971),
#  (datetime.datetime(2005, 9, 1, 23, 43, 24), datetime.datetime(2005, 8, 23, 18, 23, 24), 15928),
#  (datetime.datetime(2005, 9, 1, 22, 27, 31), datetime.datetime(2005, 8, 23, 18, 7, 31), 15922),
#  (datetime.datetime(2005, 9, 1, 22, 12, 10), datetime.datetime(2005, 8, 23, 20, 7, 10), 15977),
#  (datetime.datetime(2005, 9, 1, 21, 51, 31), datetime.datetime(2005, 8, 23, 20, 13, 31), 15982),
#  (datetime.datetime(2005, 9, 1, 20, 8, 41), datetime.datetime(2005, 8, 23, 20, 4, 41), 15973),
#  (datetime.datetime(2005, 9, 1, 19, 31, 50), datetime.datetime(2005, 8, 23, 15, 23, 50), 15834),
#  (datetime.datetime(2005, 9, 1, 19, 14, 53), datetime.datetime(2005, 8, 23, 17, 44, 53), 15911),
#  (datetime.datetime(2005, 9, 1, 18, 39, 40), datetime.datetime(2005, 8, 23, 18, 48, 40), 15942),
#  (datetime.datetime(2005, 9, 1, 18, 17, 33), datetime.datetime(2005, 8, 23, 21, 34, 33), 16020),
#  (datetime.datetime(2005, 9, 1, 17, 25, 21), datetime.datetime(2005, 8, 23, 18, 44, 21), 15939),
#  (datetime.datetime(2005, 9, 1, 16, 56, 44), datetime.datetime(2005, 8, 23, 13, 25, 44), 15775),
#  (datetime.datetime(2005, 9, 1, 16, 14, 27), datetime.datetime(2005, 8, 23, 15, 25, 27), 15835),
#  (datetime.datetime(2005, 9, 1, 15, 44, 31), datetime.datetime(2005, 8, 23, 16, 44, 31), 15882),
#  (datetime.datetime(2005, 9, 1, 14, 6, 38), datetime.datetime(2005, 8, 23, 12, 41, 38), 15752),
#  (datetime.datetime(2005, 9, 1, 13, 48, 24), datetime.datetime(2005, 8, 23, 16, 24, 24), 15871),
#  (datetime.datetime(2005, 9, 1, 13, 24, 29), datetime.datetime(2005, 8, 23, 11, 16, 29), 15722),
#  (datetime.datetime(2005, 9, 1, 13, 8, 40), datetime.datetime(2005, 8, 23, 8, 42, 40), 15657)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/H_biSct9Imw)
#
# ---

# %% [markdown]
# # SAVE YOUR NOTEBOOK, then `File > Close and Halt`

# %% [markdown]
# ---
