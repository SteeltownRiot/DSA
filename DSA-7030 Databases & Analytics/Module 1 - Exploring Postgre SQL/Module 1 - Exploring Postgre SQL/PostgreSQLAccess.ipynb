# %% [markdown]
# # PostgreSQL Access with Jupyter SQL Magic Tags
#
# ## Topics Covered in this Activity
#
# 1. Basic Queries in SQL
#     - This part will discuss some basic query samples and what they do
#         1. [Select syntax](http://www.tutorialspoint.com/sql/sql-select-query.htm)
#         1. [Where clause syntax](http://www.tutorialspoint.com/sql/sql-where-clause.htm)
#         1. [And & Or clauses syntax](http://www.tutorialspoint.com/sql/sql-and-or-clauses.htm)
# 1. Updating / Read-Only Status
#     1. We again show you the syntax for updating data
#     1. We explain the read-only status you have on postgres and what that means.

# %% [markdown]
# ## Connecting to PostgreSQL
#
# ### Using command line tools
#
# The Last time we connected to the PostgreSQL database we used the following command on the terminal. This time we will show you how to connect and run commands directly from the notebook.
#
#         psql -U dsa_ro_user -h dbase dsa_ro
#
# ### Using Jupyter Notebook
# We will use the extension loading framework, then use the SQL command qualifier: %sql
#
# This will allow us to run SQL commands directly from this notebook without the need of a terminal for PostgreSQL
#
# The below commands load the extension, and then connect to the database.

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dsa_ro
# Out:
# 'Connected: dsa_ro_user@dsa_ro'

# %% [markdown]
# <span style="background:yellow">The above cell should be run when you (re-)start working on the lab.</span>
# Then, SQL statements can be executed using %sql preceding a single-line command, or %%sql for a multi-line command:
#
# ## Basic Queries in SQL
#
# First, we will discuss the basic Select statement again.
#
# ```SQL
# SELECT * FROM cities;
# ```
#
# This statement will return all of the data from the given table (`cities`).
# This is true in all SQL select statements, that `*` means return all the attributes of a table(s).
#
# The above statement, and others below, can be run from the command line client, a notebook, or an graphical user interface (GUI) for database connectivity.
#
# The `%sql` part is used to control the Jupyter Notebook extensions.
#
# **Note:** When the below cell is run, you can click just under the `Out[#]` spot to turn the output scroll on.

# %%
# %sql SELECT * FROM cities;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 352 rows affected.
# [('Shanghai', 'China', 22315500),
#  ('Karachi', 'Pakistan', 13052000),
#  ('Mumbai', 'India', 12691800),
#  ('Beijing', 'China', 11716600),
#  ('Istanbul', 'Turkey', 11174300),
#  ('Guangzhou', 'China', 11071400),
#  ('Delhi', 'India', 10928000),
#  ('Lagos', 'Nigeria', 10404100),
#  ('Moscow', 'Russia', 10381200),
#  ('Shenzhen', 'China', 10358400),
#  ('Seoul', 'South Korea', 10349300),
#  ('São Paulo', 'Brazil', 10021300),
#  ('Jakarta', 'Indonesia', 9588200),
#  ('Kinshasa', 'Democratic Republic of the Congo', 9463800),
#  ('Mexico City', 'Mexico', 8851100),
#  ('Tokyo', 'Japan', 8336600),
#  ('New York City', 'United States', 8175100),
#  ('Dongguan', 'China', 8000000),
#  ('Cairo', 'Egypt', 7734600),
#  ('Lima', 'Peru', 7605800),
#  ('London', 'United Kingdom', 7556900),
#  ('Nanjing', 'China', 7165300),
#  ('Tehran', 'Iran', 7153300),
#  ('Nanchong', 'China', 7150000),
#  ('Hong Kong', 'Hong Kong', 7097600),
#  ('Lahore', 'Pakistan', 7092000),
#  ('Bogotá', 'Colombia', 6840200),
#  ('Dhaka', 'Bangladesh', 6725000),
#  ('Hanoi', 'Vietnam', 6448800),
#  ('Rio de Janeiro', 'Brazil', 6430000),
#  ('Shenyang', 'China', 6255900),
#  ('Hangzhou', 'China', 6242000),
#  ('Ho Chi Minh City', 'Vietnam', 6117300),
#  ('Caracas', 'Venezuela', 5808900),
#  ('Riyadh', 'Saudi Arabia', 5700000),
#  ('Ahmedabad', 'India', 5570600),
#  ('Baghdad', 'Iraq', 5514000),
#  ('Tai’an', 'China', 5499000),
#  ('Singapore', 'Singapore', 5399200),
#  ('Suzhou', 'China', 5346000),
#  ('Shantou', 'China', 5329000),
#  ('Bangkok', 'Thailand', 5104500),
#  ('Bangalore', 'India', 5104000),
#  ('Saint Petersburg', 'Russia', 5028000),
#  ('Santiago', 'Chile', 4837300),
#  ('Kolkata', 'India', 4631400),
#  ('Sydney', 'Australia', 4627300),
#  ('Chengdu', 'China', 4522000),
#  ('Harbin', 'China', 4517500),
#  ('Rangoon', 'Burma', 4477600),
#  ('Abidjan', 'Ivory Coast', 4477000),
#  ('Dar es Salaam', 'Tanzania', 4364500),
#  ('Ankara', 'Turkey', 4338600),
#  ('Jinan', 'China', 4335900),
#  ('Chennai', 'India', 4328100),
#  ('Chongqing', 'China', 4321500),
#  ('Wuhan', 'China', 4263000),
#  ('Zhengzhou', 'China', 4253900),
#  ('Melbourne', 'Australia', 4250000),
#  ('Taiyuan', 'China', 4201600),
#  ('Pyongyang', 'North Korea', 4138200),
#  ('Xi’an', 'China', 4052500),
#  ('Chittagong', 'Bangladesh', 3920200),
#  ('Alexandria', 'Egypt', 3811500),
#  ('Los Angeles', 'United States', 3792600),
#  ('Tianjin', 'China', 3756000),
#  ('Cape Town', 'South Africa', 3740000),
#  ('Qingdao', 'China', 3718800),
#  ('Busan', 'South Korea', 3678600),
#  ('Al Jizah', 'Egypt', 3628100),
#  ('Changsha', 'China', 3617500),
#  ('Foshan', 'China', 3600000),
#  ('Hyderabad', 'India', 3597800),
#  ('Puyang', 'China', 3590000),
#  ('Dalian', 'China', 3578500),
#  ('Yokohama', 'Japan', 3574400),
#  ('Ibadan', 'Nigeria', 3565100),
#  ('Wuxi', 'China', 3543700),
#  ('Xiamen', 'China', 3531300),
#  ('Changchun', 'China', 3530100),
#  ('Tianshui', 'China', 3500000),
#  ('Ningbo', 'China', 3491600),
#  ('Kunming', 'China', 3470000),
#  ('Shiyan', 'China', 3460000),
#  ('Durban', 'South Africa', 3425800),
#  ('Berlin', 'Germany', 3419700),
#  ('Izmir', 'Turkey', 3402000),
#  ('Tangshan', 'China', 3372100),
#  ('Hefei', 'China', 3310300),
#  ('Kabul', 'Afghanistan', 3290000),
#  ('Madrid', 'Spain', 3255900),
#  ('Casablanca', 'Morocco', 3144900),
#  ('Zibo', 'China', 3129200),
#  ('Zhongshan', 'China', 3121300),
#  ('Ürümqi', 'China', 3112600),
#  ('Santo Domingo', 'Dominican Republic', 2987000),
#  ('Pune', 'India', 2935700),
#  ('Surat', 'India', 2894500),
#  ('Buenos Aires', 'Argentina', 2890200),
#  ('Jeddah', 'Saudi Arabia', 2867400),
#  ('Rome', 'Italy', 2863300),
#  ('Omdurman', 'Sudan', 2840000),
#  ('Shijiazhuang', 'China', 2834900),
#  ('Kanpur', 'India', 2823200),
#  ('Kiev', 'Ukraine', 2797600),
#  ('Faisalabad', 'Pakistan', 2793700),
#  ('Brasília', 'Brazil', 2789800),
#  ('Luanda', 'Angola', 2776200),
#  ('Quezon City', 'Philippines', 2761700),
#  ('Addis Ababa', 'Ethiopia', 2757700),
#  ('Nairobi', 'Kenya', 2750500),
#  ('Jaipur', 'India', 2711800),
#  ('Chicago', 'United States', 2695600),
#  ('Taipei', 'Taiwan', 2693700),
#  ('Khartoum', 'Sudan', 2682500),
#  ('Salvador', 'Brazil', 2676600),
#  ('Osaka', 'Japan', 2666400),
#  ('Lanzhou', 'China', 2628400),
#  ('Incheon', 'South Korea', 2628000),
#  ('Yunfu', 'China', 2612800),
#  ('Al Basrah', 'Iraq', 2600000),
#  ('Toronto', 'Canada', 2600000),
#  ('Daegu', 'South Korea', 2566500),
#  ('Belo Horizonte', 'Brazil', 2479200),
#  ('Dakar', 'Senegal', 2476400),
#  ('Lucknow', 'India', 2472000),
#  ('Fortaleza', 'Brazil', 2400000),
#  ('Cali', 'Colombia', 2392900),
#  ('Surabaya', 'Indonesia', 2374700),
#  ('Nanchang', 'China', 2357800),
#  ('Grand Dakar', 'Senegal', 2352100),
#  ('Mashhad', 'Iran', 2307200),
#  ('Brooklyn', 'United States', 2300700),
#  ('Nagoya-shi', 'Japan', 2276600),
#  ('Borough of Queens', 'United States', 2272800),
#  ('Quito', 'Ecuador', 2239200),
#  ('Brisbane', 'Australia', 2238400),
#  ('Nagpur', 'India', 2228000),
#  ('Maracaibo', 'Venezuela', 2225000),
#  ('Kano', 'Nigeria', 2163200),
#  ('Tashkent', 'Uzbekistan', 2140500),
#  ('Paris', 'France', 2138600),
#  ('Dubai', 'United Arab Emirates', 2106200),
#  ('Havana', 'Cuba', 2106100),
#  ('Houston', 'United States', 2099500),
#  ('Beirut', 'Lebanon', 2060400),
#  ('Johannesburg', 'South Africa', 2026500),
#  ('Kowloon', 'Hong Kong', 2019500),
#  ('Almaty', 'Kazakhstan', 2000900),
#  ('Medellín', 'Colombia', 2000000),
#  ('Manaus', 'Brazil', 1982200),
#  ('Algiers', 'Algeria', 1977700),
#  ('Perth', 'Australia', 1972400),
#  ('Accra', 'Ghana', 1963300),
#  ('Guayaquil', 'Ecuador', 1952000),
#  ('Ordos', 'China', 1940700),
#  ('Sanaa', 'Yemen', 1937500),
#  ('Minsk', 'Belarus', 1921900),
#  ('Amman', 'Jordan', 1919000),
#  ('Bucharest', 'Romania', 1883400),
#  ('Sapporo', 'Japan', 1883000),
#  ('Jilin', 'China', 1882000),
#  ('Camayenne', 'Guinea', 1871200),
#  ('Vancouver', 'Canada', 1838000),
#  ('Indore', 'India', 1837000),
#  ('Damascus', 'Syria', 1834700),
#  ('Iztapalapa', 'Mexico', 1820900),
#  ('Antananarivo', 'Madagascar', 1816000),
#  ('Tripoli', 'Libya', 1780000),
#  ('Conakry', 'Guinea', 1767200),
#  ('Maracay', 'Venezuela', 1754300),
#  ('Curitiba', 'Brazil', 1751900),
#  ('Hamburg', 'Germany', 1751800),
#  ('Medan', 'Indonesia', 1751000),
#  ('Rawalpindi', 'Pakistan', 1743100),
#  ('Budapest', 'Hungary', 1741000),
#  ('Mosul', 'Iraq', 1739800),
#  ('Pimpri-Chinchwad', 'India', 1729400),
#  ('Warsaw', 'Poland', 1702100),
#  ('Bandung', 'Indonesia', 1699700),
#  ('Soweto', 'South Africa', 1695000),
#  ('Vienna', 'Austria', 1691500),
#  ('Rabat', 'Morocco', 1655800),
#  ('Ecatepec', 'Mexico', 1655000),
#  ('Manila', 'Philippines', 1652200),
#  ('Montréal', 'Canada', 1649500),
#  ('Guadalajara', 'Mexico', 1640600),
#  ('Pretoria', 'South Africa', 1619400),
#  ('Barcelona', 'Spain', 1611800),
#  ('Aleppo', 'Syria', 1602300),
#  ('Patna', 'India', 1599900),
#  ('Bhopal', 'India', 1599900),
#  ('Puebla', 'Mexico', 1590300),
#  ('Kaduna', 'Nigeria', 1582100),
#  ('Abuja', 'Nigeria', 1568900),
#  ('Isfahan', 'Iran', 1547200),
#  ('Kobe', 'Japan', 1545400),
#  ('Ludhiana', 'India', 1545400),
#  ('Harare', 'Zimbabwe', 1542800),
#  ('Philadelphia', 'United States', 1526000),
#  ('Bekasi', 'Indonesia', 1520100),
#  ('Kaohsiung', 'Taiwan', 1519700),
#  ('Ciudad Juárez', 'Mexico', 1512400),
#  ('Phnom Penh', 'Cambodia', 1501700),
#  ('Manhattan', 'United States', 1487500),
#  ('Asunción', 'Paraguay', 1482200),
#  ('Recife', 'Brazil', 1478100),
#  ('Daejeon', 'South Korea', 1475200),
#  ('Kyoto', 'Japan', 1473700),
#  ('Kumasi', 'Ghana', 1468600),
#  ('Kota Bharu', 'Malaysia', 1460000),
#  ('Kuala Lumpur', 'Malaysia', 1454000),
#  ('Karaj', 'Iran', 1448100),
#  ('Phoenix', 'United States', 1445600),
#  ('Kathmandu', 'Nepal', 1442300),
#  ('Palembang', 'Indonesia', 1441500),
#  ('Multan', 'Pakistan', 1437200),
#  ('Kharkiv', 'Ukraine', 1430900),
#  ('Agra', 'India', 1430100),
#  ('Córdoba', 'Argentina', 1428200),
#  ('Tabriz', 'Iran', 1424600),
#  ('Novosibirsk', 'Russia', 1419000),
#  ('Gwangju', 'South Korea', 1416900),
#  ('Lusaka', 'Zambia', 1413000),
#  ('Bursa', 'Turkey', 1412700),
#  ('Vadodara', 'India', 1409500),
#  ('Belém', 'Brazil', 1407700),
#  ('Fushun', 'China', 1400600),
#  ('Fukuoka-shi', 'Japan', 1392300),
#  ('Luoyang', 'China', 1390600),
#  ('Hyderabad', 'Pakistan', 1386300),
#  ('The Bronx', 'United States', 1385100),
#  ('Valencia', 'Venezuela', 1385100),
#  ('Gujranwala', 'Pakistan', 1384500),
#  ('Barranquilla', 'Colombia', 1380400),
#  ('Guankou', 'China', 1380000),
#  ('Tijuana', 'Mexico', 1376500),
#  ('Lubumbashi', 'Democratic Republic of the Congo', 1373800),
#  ('Porto Alegre', 'Brazil', 1372700),
#  ('Tangerang', 'Indonesia', 1372100),
#  ('Santa Cruz de la Sierra', 'Bolivia', 1364400),
#  ('Handan', 'China', 1358300),
#  ('Kampala', 'Uganda', 1353200),
#  ('Mogadishu', 'Somalia', 1353000),
#  ('Yekaterinburg', 'Russia', 1349800),
#  ('Khulna', 'Bangladesh', 1342300),
#  ('Montevideo', 'Uruguay', 1338400),
#  ('Douala', 'Cameroon', 1338100),
#  ('San Antonio', 'United States', 1327400),
#  ('Gorakhpur', 'India', 1324600),
#  ('Mecca', 'Saudi Arabia', 1323600),
#  ('Makassar', 'Indonesia', 1321700),
#  ('San Diego', 'United States', 1307400),
#  ('Kawasaki', 'Japan', 1306800),
#  ('South Tangerang', 'Indonesia', 1303600),
#  ('Baotou', 'China', 1301800),
#  ('Medina', 'Saudi Arabia', 1300000),
#  ('Yaoundé', 'Cameroon', 1299500),
#  ('Bamako', 'Mali', 1297300),
#  ('Xinyang', 'China', 1295800),
#  ('Nashik', 'India', 1289500),
#  ('Semarang', 'Indonesia', 1288100),
#  ('Nizhniy Novgorod', 'Russia', 1284200),
#  ('Port-au-Prince', 'Haiti', 1275000),
#  ('Budta', 'Philippines', 1273700),
#  ('Belgrade', 'Serbia', 1273700),
#  ('Sofia', 'Bulgaria', 1271700),
#  ('Kalyan', 'India', 1262300),
#  ('Thane', 'India', 1261500),
#  ('Munich', 'Germany', 1260400),
#  ('Stockholm', 'Sweden', 1253300),
#  ('Shiraz', 'Iran', 1249900),
#  ('Adana', 'Turkey', 1249000),
#  ('Prague', 'Czech Republic', 1243200),
#  ('Suwon-si', 'South Korea', 1242700),
#  ('León', 'Mexico', 1239000),
#  ('Milano', 'Italy', 1236800),
#  ('Ciudad Nezahualcoyotl', 'Mexico', 1232200),
#  ('Meerut', 'India', 1223200),
#  ('Nowrangapur', 'India', 1220900),
#  ('Faridabad', 'India', 1220200),
#  ('Peshawar', 'Pakistan', 1218800),
#  ('Davao', 'Philippines', 1212500),
#  ('Mandalay', 'Burma', 1208100),
#  ('Santiago de los Caballeros', 'Dominican Republic', 1200000),
#  ('Yueyang', 'China', 1200000),
#  ('Anshan', 'China', 1199300),
#  ('Tongshan', 'China', 1199200),
#  ('Ghaziabad', 'India', 1199200),
#  ('Depok', 'Indonesia', 1198100),
#  ('Dallas', 'United States', 1197800),
#  ('Saitama', 'Japan', 1193400),
#  ('Dombivli', 'India', 1193000),
#  ('Maputo', 'Mozambique', 1191600),
#  ('Gustavo A. Madero', 'Mexico', 1185800),
#  ('Fuzhou', 'China', 1179700),
#  ('Rajkot', 'India', 1177400),
#  ('Rosario', 'Argentina', 1173500),
#  ('Guiyang', 'China', 1171600),
#  ('Goiânia', 'Brazil', 1171200),
#  ('Guarulhos', 'Brazil', 1169600),
#  ('Kigali', 'Rwanda', 1168600),
#  ('Varanasi', 'India', 1164400),
#  ('Tbilisi', 'Georgia', 1162400),
#  ('Adelaide', 'Australia', 1158300),
#  ('Copenhagen', 'Denmark', 1153600),
#  ('Port Harcourt', 'Nigeria', 1148700),
#  ('Hiroshima-shi', 'Japan', 1143800),
#  ('Kazan', 'Russia', 1143600),
#  ('Brussels', 'Belgium', 1138900),
#  ('Lijiang', 'China', 1137600),
#  ('Samara', 'Russia', 1134700),
#  ('Chelyabinsk', 'Russia', 1130100),
#  ('Omsk', 'Russia', 1129300),
#  ('Benin City', 'Nigeria', 1125100),
#  ('Monterrey', 'Mexico', 1122900),
#  ('Malingao', 'Philippines', 1122000),
#  ('Allahabad', 'India', 1117100),
#  ('Baku', 'Azerbaijan', 1116500),
#  ('Brazzaville', 'Republic of the Congo', 1115800),
#  ('Maiduguri', 'Nigeria', 1112400),
#  ('Yerevan', 'Armenia', 1093500),
#  ('Amritsar', 'India', 1092500),
#  ("N'Djamena", 'Chad', 1092000),
#  ('Ouagadougou', 'Burkina Faso', 1086500),
#  ('Yono', 'Japan', 1077700),
#  ('Rostov-na-Donu', 'Russia', 1074500),
#  ('Goyang-si', 'South Korea', 1073100),
#  ('Gaziantep', 'Turkey', 1066000),
#  ('Visakhapatnam', 'India', 1063200),
#  ('Sendai-shi', 'Japan', 1063100),
#  ('Sendai', 'Japan', 1063100),
#  ('Datong', 'China', 1052700),
#  ('Changshu City', 'China', 1047700),
#  ('Taichung', 'Taiwan', 1040700),
#  ('Teni', 'India', 1034700),
#  ('Xianyang', 'China', 1034100),
#  ('Ufa', 'Russia', 1033300),
#  ('Dnipropetrovsk', 'Ukraine', 1032800),
#  ('Seongnam-si', 'South Korea', 1031900),
#  ('Jabalpur', 'India', 1030200),
#  ('Haora', 'India', 1027700),
#  ('Huainan', 'China', 1027700),
#  ('Campinas', 'Brazil', 1024900),
#  ('Donetsk', 'Ukraine', 1024700),
#  ('Dublin', 'Ireland', 1024000),
#  ('Calgary', 'Canada', 1019900),
#  ('Aurangabad', 'India', 1016400),
#  ('Volgograd', 'Russia', 1011400),
#  ('Nova Iguaçu', 'Brazil', 1002100),
#  ('Jieyang', 'China', 1002000),
#  ('Odessa', 'Ukraine', 1001600)]

# %% [markdown]
# Now let's specify the columns that we return from the table.
# This is easily done by replacing the `*` in the select statement with the attributes you want to return separated by commas.
#
# Run the following select statement and see the different between it and the select * statement we ran earlier.
#
# ```SQL
# SELECT city, country FROM cities;
# ```

# %%
# %sql SELECT city, country FROM cities;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 352 rows affected.
# [('Shanghai', 'China'),
#  ('Karachi', 'Pakistan'),
#  ('Mumbai', 'India'),
#  ('Beijing', 'China'),
#  ('Istanbul', 'Turkey'),
#  ('Guangzhou', 'China'),
#  ('Delhi', 'India'),
#  ('Lagos', 'Nigeria'),
#  ('Moscow', 'Russia'),
#  ('Shenzhen', 'China'),
#  ('Seoul', 'South Korea'),
#  ('São Paulo', 'Brazil'),
#  ('Jakarta', 'Indonesia'),
#  ('Kinshasa', 'Democratic Republic of the Congo'),
#  ('Mexico City', 'Mexico'),
#  ('Tokyo', 'Japan'),
#  ('New York City', 'United States'),
#  ('Dongguan', 'China'),
#  ('Cairo', 'Egypt'),
#  ('Lima', 'Peru'),
#  ('London', 'United Kingdom'),
#  ('Nanjing', 'China'),
#  ('Tehran', 'Iran'),
#  ('Nanchong', 'China'),
#  ('Hong Kong', 'Hong Kong'),
#  ('Lahore', 'Pakistan'),
#  ('Bogotá', 'Colombia'),
#  ('Dhaka', 'Bangladesh'),
#  ('Hanoi', 'Vietnam'),
#  ('Rio de Janeiro', 'Brazil'),
#  ('Shenyang', 'China'),
#  ('Hangzhou', 'China'),
#  ('Ho Chi Minh City', 'Vietnam'),
#  ('Caracas', 'Venezuela'),
#  ('Riyadh', 'Saudi Arabia'),
#  ('Ahmedabad', 'India'),
#  ('Baghdad', 'Iraq'),
#  ('Tai’an', 'China'),
#  ('Singapore', 'Singapore'),
#  ('Suzhou', 'China'),
#  ('Shantou', 'China'),
#  ('Bangkok', 'Thailand'),
#  ('Bangalore', 'India'),
#  ('Saint Petersburg', 'Russia'),
#  ('Santiago', 'Chile'),
#  ('Kolkata', 'India'),
#  ('Sydney', 'Australia'),
#  ('Chengdu', 'China'),
#  ('Harbin', 'China'),
#  ('Rangoon', 'Burma'),
#  ('Abidjan', 'Ivory Coast'),
#  ('Dar es Salaam', 'Tanzania'),
#  ('Ankara', 'Turkey'),
#  ('Jinan', 'China'),
#  ('Chennai', 'India'),
#  ('Chongqing', 'China'),
#  ('Wuhan', 'China'),
#  ('Zhengzhou', 'China'),
#  ('Melbourne', 'Australia'),
#  ('Taiyuan', 'China'),
#  ('Pyongyang', 'North Korea'),
#  ('Xi’an', 'China'),
#  ('Chittagong', 'Bangladesh'),
#  ('Alexandria', 'Egypt'),
#  ('Los Angeles', 'United States'),
#  ('Tianjin', 'China'),
#  ('Cape Town', 'South Africa'),
#  ('Qingdao', 'China'),
#  ('Busan', 'South Korea'),
#  ('Al Jizah', 'Egypt'),
#  ('Changsha', 'China'),
#  ('Foshan', 'China'),
#  ('Hyderabad', 'India'),
#  ('Puyang', 'China'),
#  ('Dalian', 'China'),
#  ('Yokohama', 'Japan'),
#  ('Ibadan', 'Nigeria'),
#  ('Wuxi', 'China'),
#  ('Xiamen', 'China'),
#  ('Changchun', 'China'),
#  ('Tianshui', 'China'),
#  ('Ningbo', 'China'),
#  ('Kunming', 'China'),
#  ('Shiyan', 'China'),
#  ('Durban', 'South Africa'),
#  ('Berlin', 'Germany'),
#  ('Izmir', 'Turkey'),
#  ('Tangshan', 'China'),
#  ('Hefei', 'China'),
#  ('Kabul', 'Afghanistan'),
#  ('Madrid', 'Spain'),
#  ('Casablanca', 'Morocco'),
#  ('Zibo', 'China'),
#  ('Zhongshan', 'China'),
#  ('Ürümqi', 'China'),
#  ('Santo Domingo', 'Dominican Republic'),
#  ('Pune', 'India'),
#  ('Surat', 'India'),
#  ('Buenos Aires', 'Argentina'),
#  ('Jeddah', 'Saudi Arabia'),
#  ('Rome', 'Italy'),
#  ('Omdurman', 'Sudan'),
#  ('Shijiazhuang', 'China'),
#  ('Kanpur', 'India'),
#  ('Kiev', 'Ukraine'),
#  ('Faisalabad', 'Pakistan'),
#  ('Brasília', 'Brazil'),
#  ('Luanda', 'Angola'),
#  ('Quezon City', 'Philippines'),
#  ('Addis Ababa', 'Ethiopia'),
#  ('Nairobi', 'Kenya'),
#  ('Jaipur', 'India'),
#  ('Chicago', 'United States'),
#  ('Taipei', 'Taiwan'),
#  ('Khartoum', 'Sudan'),
#  ('Salvador', 'Brazil'),
#  ('Osaka', 'Japan'),
#  ('Lanzhou', 'China'),
#  ('Incheon', 'South Korea'),
#  ('Yunfu', 'China'),
#  ('Al Basrah', 'Iraq'),
#  ('Toronto', 'Canada'),
#  ('Daegu', 'South Korea'),
#  ('Belo Horizonte', 'Brazil'),
#  ('Dakar', 'Senegal'),
#  ('Lucknow', 'India'),
#  ('Fortaleza', 'Brazil'),
#  ('Cali', 'Colombia'),
#  ('Surabaya', 'Indonesia'),
#  ('Nanchang', 'China'),
#  ('Grand Dakar', 'Senegal'),
#  ('Mashhad', 'Iran'),
#  ('Brooklyn', 'United States'),
#  ('Nagoya-shi', 'Japan'),
#  ('Borough of Queens', 'United States'),
#  ('Quito', 'Ecuador'),
#  ('Brisbane', 'Australia'),
#  ('Nagpur', 'India'),
#  ('Maracaibo', 'Venezuela'),
#  ('Kano', 'Nigeria'),
#  ('Tashkent', 'Uzbekistan'),
#  ('Paris', 'France'),
#  ('Dubai', 'United Arab Emirates'),
#  ('Havana', 'Cuba'),
#  ('Houston', 'United States'),
#  ('Beirut', 'Lebanon'),
#  ('Johannesburg', 'South Africa'),
#  ('Kowloon', 'Hong Kong'),
#  ('Almaty', 'Kazakhstan'),
#  ('Medellín', 'Colombia'),
#  ('Manaus', 'Brazil'),
#  ('Algiers', 'Algeria'),
#  ('Perth', 'Australia'),
#  ('Accra', 'Ghana'),
#  ('Guayaquil', 'Ecuador'),
#  ('Ordos', 'China'),
#  ('Sanaa', 'Yemen'),
#  ('Minsk', 'Belarus'),
#  ('Amman', 'Jordan'),
#  ('Bucharest', 'Romania'),
#  ('Sapporo', 'Japan'),
#  ('Jilin', 'China'),
#  ('Camayenne', 'Guinea'),
#  ('Vancouver', 'Canada'),
#  ('Indore', 'India'),
#  ('Damascus', 'Syria'),
#  ('Iztapalapa', 'Mexico'),
#  ('Antananarivo', 'Madagascar'),
#  ('Tripoli', 'Libya'),
#  ('Conakry', 'Guinea'),
#  ('Maracay', 'Venezuela'),
#  ('Curitiba', 'Brazil'),
#  ('Hamburg', 'Germany'),
#  ('Medan', 'Indonesia'),
#  ('Rawalpindi', 'Pakistan'),
#  ('Budapest', 'Hungary'),
#  ('Mosul', 'Iraq'),
#  ('Pimpri-Chinchwad', 'India'),
#  ('Warsaw', 'Poland'),
#  ('Bandung', 'Indonesia'),
#  ('Soweto', 'South Africa'),
#  ('Vienna', 'Austria'),
#  ('Rabat', 'Morocco'),
#  ('Ecatepec', 'Mexico'),
#  ('Manila', 'Philippines'),
#  ('Montréal', 'Canada'),
#  ('Guadalajara', 'Mexico'),
#  ('Pretoria', 'South Africa'),
#  ('Barcelona', 'Spain'),
#  ('Aleppo', 'Syria'),
#  ('Patna', 'India'),
#  ('Bhopal', 'India'),
#  ('Puebla', 'Mexico'),
#  ('Kaduna', 'Nigeria'),
#  ('Abuja', 'Nigeria'),
#  ('Isfahan', 'Iran'),
#  ('Kobe', 'Japan'),
#  ('Ludhiana', 'India'),
#  ('Harare', 'Zimbabwe'),
#  ('Philadelphia', 'United States'),
#  ('Bekasi', 'Indonesia'),
#  ('Kaohsiung', 'Taiwan'),
#  ('Ciudad Juárez', 'Mexico'),
#  ('Phnom Penh', 'Cambodia'),
#  ('Manhattan', 'United States'),
#  ('Asunción', 'Paraguay'),
#  ('Recife', 'Brazil'),
#  ('Daejeon', 'South Korea'),
#  ('Kyoto', 'Japan'),
#  ('Kumasi', 'Ghana'),
#  ('Kota Bharu', 'Malaysia'),
#  ('Kuala Lumpur', 'Malaysia'),
#  ('Karaj', 'Iran'),
#  ('Phoenix', 'United States'),
#  ('Kathmandu', 'Nepal'),
#  ('Palembang', 'Indonesia'),
#  ('Multan', 'Pakistan'),
#  ('Kharkiv', 'Ukraine'),
#  ('Agra', 'India'),
#  ('Córdoba', 'Argentina'),
#  ('Tabriz', 'Iran'),
#  ('Novosibirsk', 'Russia'),
#  ('Gwangju', 'South Korea'),
#  ('Lusaka', 'Zambia'),
#  ('Bursa', 'Turkey'),
#  ('Vadodara', 'India'),
#  ('Belém', 'Brazil'),
#  ('Fushun', 'China'),
#  ('Fukuoka-shi', 'Japan'),
#  ('Luoyang', 'China'),
#  ('Hyderabad', 'Pakistan'),
#  ('The Bronx', 'United States'),
#  ('Valencia', 'Venezuela'),
#  ('Gujranwala', 'Pakistan'),
#  ('Barranquilla', 'Colombia'),
#  ('Guankou', 'China'),
#  ('Tijuana', 'Mexico'),
#  ('Lubumbashi', 'Democratic Republic of the Congo'),
#  ('Porto Alegre', 'Brazil'),
#  ('Tangerang', 'Indonesia'),
#  ('Santa Cruz de la Sierra', 'Bolivia'),
#  ('Handan', 'China'),
#  ('Kampala', 'Uganda'),
#  ('Mogadishu', 'Somalia'),
#  ('Yekaterinburg', 'Russia'),
#  ('Khulna', 'Bangladesh'),
#  ('Montevideo', 'Uruguay'),
#  ('Douala', 'Cameroon'),
#  ('San Antonio', 'United States'),
#  ('Gorakhpur', 'India'),
#  ('Mecca', 'Saudi Arabia'),
#  ('Makassar', 'Indonesia'),
#  ('San Diego', 'United States'),
#  ('Kawasaki', 'Japan'),
#  ('South Tangerang', 'Indonesia'),
#  ('Baotou', 'China'),
#  ('Medina', 'Saudi Arabia'),
#  ('Yaoundé', 'Cameroon'),
#  ('Bamako', 'Mali'),
#  ('Xinyang', 'China'),
#  ('Nashik', 'India'),
#  ('Semarang', 'Indonesia'),
#  ('Nizhniy Novgorod', 'Russia'),
#  ('Port-au-Prince', 'Haiti'),
#  ('Budta', 'Philippines'),
#  ('Belgrade', 'Serbia'),
#  ('Sofia', 'Bulgaria'),
#  ('Kalyan', 'India'),
#  ('Thane', 'India'),
#  ('Munich', 'Germany'),
#  ('Stockholm', 'Sweden'),
#  ('Shiraz', 'Iran'),
#  ('Adana', 'Turkey'),
#  ('Prague', 'Czech Republic'),
#  ('Suwon-si', 'South Korea'),
#  ('León', 'Mexico'),
#  ('Milano', 'Italy'),
#  ('Ciudad Nezahualcoyotl', 'Mexico'),
#  ('Meerut', 'India'),
#  ('Nowrangapur', 'India'),
#  ('Faridabad', 'India'),
#  ('Peshawar', 'Pakistan'),
#  ('Davao', 'Philippines'),
#  ('Mandalay', 'Burma'),
#  ('Santiago de los Caballeros', 'Dominican Republic'),
#  ('Yueyang', 'China'),
#  ('Anshan', 'China'),
#  ('Tongshan', 'China'),
#  ('Ghaziabad', 'India'),
#  ('Depok', 'Indonesia'),
#  ('Dallas', 'United States'),
#  ('Saitama', 'Japan'),
#  ('Dombivli', 'India'),
#  ('Maputo', 'Mozambique'),
#  ('Gustavo A. Madero', 'Mexico'),
#  ('Fuzhou', 'China'),
#  ('Rajkot', 'India'),
#  ('Rosario', 'Argentina'),
#  ('Guiyang', 'China'),
#  ('Goiânia', 'Brazil'),
#  ('Guarulhos', 'Brazil'),
#  ('Kigali', 'Rwanda'),
#  ('Varanasi', 'India'),
#  ('Tbilisi', 'Georgia'),
#  ('Adelaide', 'Australia'),
#  ('Copenhagen', 'Denmark'),
#  ('Port Harcourt', 'Nigeria'),
#  ('Hiroshima-shi', 'Japan'),
#  ('Kazan', 'Russia'),
#  ('Brussels', 'Belgium'),
#  ('Lijiang', 'China'),
#  ('Samara', 'Russia'),
#  ('Chelyabinsk', 'Russia'),
#  ('Omsk', 'Russia'),
#  ('Benin City', 'Nigeria'),
#  ('Monterrey', 'Mexico'),
#  ('Malingao', 'Philippines'),
#  ('Allahabad', 'India'),
#  ('Baku', 'Azerbaijan'),
#  ('Brazzaville', 'Republic of the Congo'),
#  ('Maiduguri', 'Nigeria'),
#  ('Yerevan', 'Armenia'),
#  ('Amritsar', 'India'),
#  ("N'Djamena", 'Chad'),
#  ('Ouagadougou', 'Burkina Faso'),
#  ('Yono', 'Japan'),
#  ('Rostov-na-Donu', 'Russia'),
#  ('Goyang-si', 'South Korea'),
#  ('Gaziantep', 'Turkey'),
#  ('Visakhapatnam', 'India'),
#  ('Sendai-shi', 'Japan'),
#  ('Sendai', 'Japan'),
#  ('Datong', 'China'),
#  ('Changshu City', 'China'),
#  ('Taichung', 'Taiwan'),
#  ('Teni', 'India'),
#  ('Xianyang', 'China'),
#  ('Ufa', 'Russia'),
#  ('Dnipropetrovsk', 'Ukraine'),
#  ('Seongnam-si', 'South Korea'),
#  ('Jabalpur', 'India'),
#  ('Haora', 'India'),
#  ('Huainan', 'China'),
#  ('Campinas', 'Brazil'),
#  ('Donetsk', 'Ukraine'),
#  ('Dublin', 'Ireland'),
#  ('Calgary', 'Canada'),
#  ('Aurangabad', 'India'),
#  ('Volgograd', 'Russia'),
#  ('Nova Iguaçu', 'Brazil'),
#  ('Jieyang', 'China'),
#  ('Odessa', 'Ukraine')]

# %% [markdown]
# Now let's discuss the where clause again. This clause allows us to limit what is returned in the select statement by adding a WHERE on to the end.
#
# The following statement will return only the name of cities that are located in the United States.
#
# ```SQL
# SELECT city FROM cities WHERE country = 'United States';
# ```
#
# `WHERE` clauses are useful when you are looking for certain rows of the data that are located in the table.

# %%
# %sql SELECT city FROM cities WHERE country = 'United States';
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 13 rows affected.
# [('New York City',),
#  ('Los Angeles',),
#  ('Chicago',),
#  ('Brooklyn',),
#  ('Borough of Queens',),
#  ('Houston',),
#  ('Philadelphia',),
#  ('Manhattan',),
#  ('Phoenix',),
#  ('The Bronx',),
#  ('San Antonio',),
#  ('San Diego',),
#  ('Dallas',)]

# %% [markdown]
# But what if we wanted all the cities in the United States OR Canada.
#
# We can implement an OR clause which will allow our WHERE clause to recognize both countries
#
# ```SQL
# SELECT city FROM cities WHERE country = 'United States' OR country = 'Canada';
# ```

# %%
# %sql SELECT city FROM cities WHERE country = 'United States' OR country = 'Canada';
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 17 rows affected.
# [('New York City',),
#  ('Los Angeles',),
#  ('Chicago',),
#  ('Toronto',),
#  ('Brooklyn',),
#  ('Borough of Queens',),
#  ('Houston',),
#  ('Vancouver',),
#  ('Montréal',),
#  ('Philadelphia',),
#  ('Manhattan',),
#  ('Phoenix',),
#  ('The Bronx',),
#  ('San Antonio',),
#  ('San Diego',),
#  ('Dallas',),
#  ('Calgary',)]

# %% [markdown]
# **NOTE** `%sql` Statements can be multiple lines if the line ends in a `\` character.
# However, an erroneous space or other character after the `\` will result in a python error.
# ```
# File "<ipython-input-13-f85a316d8eac>", line 2
#     WHERE country = 'United States' OR country = 'Canada';
#                 ^
# SyntaxError: invalid syntax
# ```

# %%
# %sql SELECT city \
FROM cities \ 
WHERE country = 'United States' OR country = 'Canada';
# Out:
#   File "<ipython-input-6-e957d1cb6291>", line 2
#     WHERE country = 'United States' OR country = 'Canada';
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# This time without the erroneous space after cities \

# %%
# %sql SELECT city \
FROM cities \
WHERE country = 'United States' OR country = 'Canada';
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 17 rows affected.
# [('New York City',),
#  ('Los Angeles',),
#  ('Chicago',),
#  ('Toronto',),
#  ('Brooklyn',),
#  ('Borough of Queens',),
#  ('Houston',),
#  ('Vancouver',),
#  ('Montréal',),
#  ('Philadelphia',),
#  ('Manhattan',),
#  ('Phoenix',),
#  ('The Bronx',),
#  ('San Antonio',),
#  ('San Diego',),
#  ('Dallas',),
#  ('Calgary',)]

# %% [markdown]
# Alternatively, we can use the `%%sql` tag to denote a multiline SQL statement without escaping the end of the lines with the `\`

# %%
# %%sql SELECT city
# FROM cities
# WHERE country = 'United States' OR country = 'Canada';
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 17 rows affected.
# [('New York City',),
#  ('Los Angeles',),
#  ('Chicago',),
#  ('Toronto',),
#  ('Brooklyn',),
#  ('Borough of Queens',),
#  ('Houston',),
#  ('Vancouver',),
#  ('Montréal',),
#  ('Philadelphia',),
#  ('Manhattan',),
#  ('Phoenix',),
#  ('The Bronx',),
#  ('San Antonio',),
#  ('San Diego',),
#  ('Dallas',),
#  ('Calgary',)]

# %% [markdown]
# We can also use an AND clause to see cities in the United States AND has a population that is greater than 2500000.
#
# ```SQL
# SELECT city FROM cities WHERE country = 'United States' AND population > 2500000;
# ```

# %%
# %%sql SELECT city
# FROM cities
# WHERE country = 'United States'
#   AND population > 2500000;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 3 rows affected.
# [('New York City',), ('Los Angeles',), ('Chicago',)]

# %% [markdown]
# You can easily order results from the query by adding an `ORDER BY` condition.
#
# This will allow you to choose an attribute of the table and order the data based on that attribute in ascending (ASC) or descending (DESC) order.
# The default is natural ordering, ascending.
#
# ```SQL
# SELECT city
# FROM cities
# WHERE country = 'United States'
#   AND population > 2500000
# ORDER BY city ASC;
# ```
#
# This query will return the same results as before, but this time the results will be organized by the city name in ascending order.
#
# To change it to descending order simply replace ASC with DESC in the query.
#
# Take some time here to query the data adding simple constraints and learning how the SQL language works.

# %%
# %%sql
# SELECT city
# FROM cities
# WHERE country = 'United States'
#   AND population > 2500000
# ORDER BY city ASC;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 3 rows affected.
# [('Chicago',), ('Los Angeles',), ('New York City',)]

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
# #### 1. Write a SELECT statement that displays all cities in China that have a population greater than 4,000,000

# %%
# %%sql
# SELECT  city
# FROM    cities
# WHERE   country = 'China'
#         AND population > 4000000
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 20 rows affected.
# [('Shanghai',),
#  ('Beijing',),
#  ('Guangzhou',),
#  ('Shenzhen',),
#  ('Dongguan',),
#  ('Nanjing',),
#  ('Nanchong',),
#  ('Shenyang',),
#  ('Hangzhou',),
#  ('Tai’an',),
#  ('Suzhou',),
#  ('Shantou',),
#  ('Chengdu',),
#  ('Harbin',),
#  ('Jinan',),
#  ('Chongqing',),
#  ('Wuhan',),
#  ('Zhengzhou',),
#  ('Taiyuan',),
#  ('Xi’an',)]

# %% [markdown]
# #### 2. Write a SELECT statement that displays the name and population of cities in the United States or United Kingdom that have a population less than 5,000,000

# %%
# %%sql
# SELECT  city, population
# FROM    cities
# WHERE   country IN ('United States', 'United Kingdom')
#         AND population < 5000000
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 12 rows affected.
# [('Los Angeles', 3792600),
#  ('Chicago', 2695600),
#  ('Brooklyn', 2300700),
#  ('Borough of Queens', 2272800),
#  ('Houston', 2099500),
#  ('Philadelphia', 1526000),
#  ('Manhattan', 1487500),
#  ('Phoenix', 1445600),
#  ('The Bronx', 1385100),
#  ('San Antonio', 1327400),
#  ('San Diego', 1307400),
#  ('Dallas', 1197800)]

# %% [markdown]
# ## Modification vs Read Only Status
#
# As you will learn, tables can be populated or modified with the INSERT, UPDATE, or DELETE commands.
#
# Enter the following command:
#
# ```SQL
# UPDATE cities SET country = 'United States'
#  WHERE country = 'Canada';
# ```
#
# This should take all the cities from Canada and add them to United States, but you will receive a error statement that says permission denied.
#
# This is because you are logged into a read only account which allows you to query the data, but not `INSERT`, `DELETE` or `UPDATE` the tables.
#
# You may wonder why accounts like this are necessary.
# It allows different users to query the database, but not be given the right to change the data for risk of someone messing up the data.

# %%
# %sql UPDATE cities SET country = 'United States' WHERE country = 'Canada';
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# (psycopg2.errors.InsufficientPrivilege) permission denied for relation cities
#
# [SQL: UPDATE cities SET country = 'United States' WHERE country = 'Canada';]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# # SAVE YOUR NOTEBOOK, then `File > Close and Halt`

# %% [markdown]
# ---
