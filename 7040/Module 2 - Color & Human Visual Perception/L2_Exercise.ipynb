# %% [markdown]
# # Module 2 Color Exercise
#
# **In these exercises, we will create plots with correct and adequate color schemes similar to the lab and practice.**

# %%
library(ggplot2)
library(RColorBrewer)

# %% [markdown]
# **Activity 1:** Display colormaps with seven colors from RColorBrewer library for a **sequential** data type with **colorblind safe** colors.

# %%
## Your answer for activity 1 goes here ---
display.brewer.all(n = 7, type = "seq", colorblindFriendly = TRUE)
# Out:
# plot without title

# %% [markdown]
# **Activity 2:** Create a **colorblind safe colormap with 100 colors** from the dichromat library, and display their hexadecimal codes.

# %%
library(dichromat)
## Your answer for activity 2 goes here ---
p2 <- colorRampPalette(colorschemes$BluetoDarkOrange.18)(100)

p2
# Out:
#   [1] "#006666" "#006E6E" "#007777" "#008080" "#008989" "#009191" "#009A9A"
#   [8] "#00A3A3" "#00ACAC" "#00B4B4" "#00BDBD" "#00C6C6" "#00CFCF" "#00D7D7"
#  [15] "#00E0E0" "#00E9E9" "#00F2F2" "#00FAFA" "#04FFFF" "#0DFFFF" "#16FFFF"
#  [22] "#1EFFFF" "#27FFFF" "#30FFFF" "#39FFFF" "#41FFFF" "#4AFFFF" "#53FFFF"
#  [29] "#5CFFFF" "#64FFFF" "#6DFFFF" "#76FFFF" "#7FFFFF" "#88FFFF" "#90FFFF"
#  [36] "#99FFFF" "#9DFFFF" "#A1FFFF" "#A6FFFF" "#AAFFFF" "#AEFFFF" "#B3FFFF"
#  [43] "#B7FFFF" "#BBFFFF" "#C0FFFF" "#C4FFFF" "#C9FFFF" "#CDFFFF" "#D2FFFF"
#  [50] "#D6FFFF" "#DBFFFF" "#DFFFFF" "#E4FFFF" "#E8FCF9" "#ECF8F1" "#F1F3E8"
#  [57] "#F5EFDF" "#F9EBD6" "#FDE7CE" "#FFE2C5" "#FFDDBC" "#FFD8B3" "#FFD3AB"
#  [64] "#FFCFA2" "#FFCA99" "#FFC590" "#FFC087" "#FFBB7F" "#FFB676" "#FFB16D"
#  [71] "#FFAC64" "#FFA75C" "#FFA253" "#FF9C4A" "#FF9741" "#FF9239" "#FF8D30"
#  [78] "#FF8727" "#FF811E" "#FF7C16" "#FF760D" "#FF7004" "#FA6B00" "#F26700"
#  [85] "#E96300" "#E05F00" "#D75A00" "#CF5600" "#C65200" "#BD4E00" "#B44A00"
#  [92] "#AC4500" "#A34100" "#9A3D00" "#913900" "#893600" "#803200" "#772E00"
#  [99] "#6E2A00" "#662700"

# %% [markdown]
# **Activity 3:** Use ellipse library to create an elliptical correlation plot for the diamonds data using carat, price, table, and depth variables. Make sure to use a **colorblind safe, diverging** color scheme.

# %%
library(ellipse)
head(diamonds)
data=diamonds[,c("carat","depth","price","table")]
## Your answer for activity 3 goes here ---
cor_data = cor(data)

plotcorr(cor_data)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# plot without title

# %% [markdown]
# **Activity 4:** Create a scatter plot using **all** diamonds data for carat vs. price and encode `clarity` variable with a **sequential** color scheme.

# %%
## Your answer for activity 4 goes here ---
p3 <- (ggplot(diamonds, aes(x=carat, y=price, color = clarity)) + 
    geom_point() +
    scale_colour_brewer(palette = 'YlGnBu'))

p3
# Out:
# plot without title

# %% [markdown]
# **Activity 5:** Repeat Activity 4 with **alpha transparency**. **Is this a better idea? Discuss your answer.**

# %%
## Your answer for activity 5 goes here ---
ggplot(diamonds, aes(x=carat, y=price, color = clarity)) + 
    geom_point(alpha = 0.5) +
    scale_colour_brewer(palette = 'YlGnBu')

# This is not a better solution. It muddies the colors and makes it more difficult to distinguish plots in high density areas
# Out:
# plot without title

# %% [markdown]
# **Activity 6:** Recreate the following plot using `ggplot2` functions and the **mtcars** data set.
#
# Hint: you may have to change attribute characteristics, also look at theme functions in `ggplot2`.
#
# <img src="ex.png">

# %%
## Your answer for activity 6 goes here ---
